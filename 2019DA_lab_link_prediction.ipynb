# %% [markdown]
# # DA lab 6주차 링크프레딕션: networkx 라이브러리의 활용

# %% [markdown]
# ## Link Prediction

# %% [markdown]
# ### Contents
# * 데이터 준비(두 개의 분석구간)
# * 링크 예측
# * 성능 검증

# %% [markdown]
# ### Used Library
# * networkx
# * pandas
# * pickle

# %%
import pandas as pd
import networkx as nx
import pickle

# %% [markdown]
# ### Link Prediction 알고리즘
# * resource_allocation_index
# * jaccard_coefficient
# * adamic_adar_index
# * preferential_attachment
# * cn_soundarajan_hopcroft
# * ra_index_soundarajan_hopcroft
# * within_inter_cluster

# %%
with open('ipc_nx_list(1).pickle','rb') as f:
    data_first=pickle.load(f)
with open('ipc_nx_list(2).pickle','rb') as d:
    data_second=pickle.load(d)

# %% [markdown]
# ### 2가지 분석구간의 데이터 준비

# %%
data_first
# Out:
# [('A61C', 'A61B', 5),
#  ('G01B', 'C08F', 1),
#  ('B65D', 'B43M', 1),
#  ('B65G', 'A01B', 1),
#  ('C12N', 'C11B', 1),
#  ('G01L', 'G01K', 1),
#  ('H04Q', 'G09B', 1),
#  ('G01F', 'F17D', 2),
#  ('C22C', 'B32B', 1),
#  ('A61K', 'A45D', 1),
#  ('F21V', 'A01K', 1),
#  ('A61N', 'A61C', 1),
#  ('A42B', 'A41D', 1),
#  ('G01N', 'A61M', 2),
#  ('H04B', 'G01F', 1),
#  ('G09F', 'G01N', 1),
#  ('H04Q', 'H04B', 1),
#  ('C21D', 'B23K', 2),
#  ('H04N', 'A63B', 2),
#  ('G08B', 'G05D', 1),
#  ('F25D', 'A47G', 1),
#  ('B23K', 'A61L', 2),
#  ('B31B', 'A47G', 1),
#  ('H04N', 'G09F', 1),
#  ('B27B', 'A61B', 1),
#  ('B08B', 'A61M', 1),
#  ('B29C', 'A63B', 3),
#  ('B29C', 'A61F', 2),
#  ('A61M', 'A61J', 1),
#  ('B05C', 'A61F', 2),
#  ('G01M', 'F17D', 1),
#  ('C08F', 'A61L', 1),
#  ('A42B', 'A01M', 1),
#  ('H02N', 'G08B', 1),
#  ('C02F', 'A61L', 1),
#  ('C12Q', 'A61B', 1),
#  ('A47J', 'A23L', 3),
#  ('F02D', 'B01J', 1),
#  ('C12N', 'A01G', 1),
#  ('G03B', 'A63J', 1),
#  ('C23C', 'B23P', 1),
#  ('G08B', 'G06F', 3),
#  ('H01B', 'B82Y', 1),
#  ('G06F', 'A61G', 2),
#  ('B29C', 'A61M', 2),
#  ('B65B', 'B05B', 1),
#  ('H01F', 'B21D', 1),
#  ('A61K', 'A61B', 5),
#  ('A63G', 'A63B', 1),
#  ('G08C', 'A63F', 1),
#  ('C01G', 'B32B', 1),
#  ('G01N', 'C12N', 2),
#  ('B33Y', 'B23K', 1),
#  ('A61K', 'A23L', 3),
#  ('H05B', 'A23L', 1),
#  ('G01N', 'A61N', 1),
#  ('F17C', 'B01D', 1),
#  ('C04B', 'B23K', 1),
#  ('H01M', 'B01J', 2),
#  ('H04B', 'A62C', 1),
#  ('A62B', 'A61M', 1),
#  ('C08F', 'B05D', 1),
#  ('G07C', 'A61G', 1),
#  ('C08J', 'C08F', 1),
#  ('G01M', 'G01F', 1),
#  ('A61L', 'A61B', 5),
#  ('F17D', 'F16K', 1),
#  ('G06F', 'A63B', 5),
#  ('A47J', 'A23D', 1),
#  ('A61H', 'A46B', 1),
#  ('G01K', 'G01C', 1),
#  ('A47L', 'A47F', 1),
#  ('B64D', 'A47B', 1),
#  ('B25D', 'A62B', 1),
#  ('F04B', 'F03C', 1),
#  ('A47G', 'A47F', 1),
#  ('G08B', 'A61G', 1),
#  ('H05B', 'E21B', 1),
#  ('F16J', 'F16C', 1),
#  ('A61N', 'A61K', 5),
#  ('G01L', 'A01C', 1),
#  ('F41H', 'A42B', 1),
#  ('H02K', 'H01F', 1),
#  ('H01L', 'H01B', 1),
#  ('F21Y', 'F16B', 1),
#  ('B01D', 'A47J', 1),
#  ('C07D', 'A01N', 1),
#  ('H04N', 'G02B', 1),
#  ('B32B', 'B29L', 1),
#  ('G01D', 'A61B', 1),
#  ('B24B', 'B08B', 1),
#  ('A61M', 'A61L', 2),
#  ('G06F', 'B60N', 1),
#  ('B21F', 'A61F', 2),
#  ('G01K', 'A61B', 1),
#  ('G06F', 'G01N', 1),
#  ('G09G', 'G06F', 1),
#  ('B65G', 'A47G', 1),
#  ('B01J', 'A61K', 1),
#  ('B29C', 'A47C', 1),
#  ('B65D', 'B31B', 1),
#  ('B29C', 'A24F', 1),
#  ('B32B', 'A47J', 1),
#  ('G01L', 'B33Y', 1),
#  ('B32B', 'B05C', 1),
#  ('C01D', 'B01D', 1),
#  ('B07B', 'B02C', 1),
#  ('G01B', 'C23C', 1),
#  ('C08L', 'C08K', 1),
#  ('G06T', 'A61N', 1),
#  ('H04B', 'E03B', 1),
#  ('B60P', 'A01B', 1),
#  ('E06B', 'A01M', 1),
#  ('G08B', 'B64F', 1),
#  ('G01N', 'B01J', 1),
#  ('H04Q', 'G06K', 1),
#  ('A23K', 'A23D', 1),
#  ('B03D', 'B03B', 1),
#  ('G09F', 'G01F', 2),
#  ('C21D', 'A61L', 2),
#  ('G06Q', 'G01N', 1),
#  ('C07C', 'B01D', 1),
#  ('G07C', 'G06F', 1),
#  ('A01F', 'A01B', 1),
#  ('H04B', 'G06K', 1),
#  ('G01N', 'C07K', 6),
#  ('F02D', 'B01D', 1),
#  ('H04W', 'G06K', 1),
#  ('H01F', 'B23P', 1),
#  ('A61G', 'A61F', 1),
#  ('B23Q', 'B23B', 1),
#  ('H04N', 'B33Y', 1),
#  ('B26D', 'B26B', 1),
#  ('E04B', 'B21K', 1),
#  ('B01L', 'B01J', 1),
#  ('A23L', 'A01H', 1),
#  ('F24J', 'A01K', 1),
#  ('G09B', 'G06K', 1),
#  ('F25B', 'B01D', 1),
#  ('B65D', 'A23L', 1),
#  ('B05D', 'B01F', 1),
#  ('C07C', 'C01D', 1),
#  ('H04N', 'G06K', 2),
#  ('C08F', 'B01J', 1),
#  ('G01S', 'A01C', 1),
#  ('G02B', 'A61B', 5),
#  ('G21G', 'A61N', 1),
#  ('F27B', 'B22D', 1),
#  ('A61M', 'A61G', 1),
#  ('C23C', 'B05B', 1),
#  ('C07C', 'A61K', 1),
#  ('H04N', 'A47B', 1),
#  ('E02B', 'A01G', 1),
#  ('C07K', 'A01K', 1),
#  ('C08L', 'A61B', 1),
#  ('G02B', 'A61N', 1),
#  ('F16L', 'B01D', 1),
#  ('B32B', 'A63B', 1),
#  ('C12M', 'A61N', 1),
#  ('B29D', 'A61M', 1),
#  ('B29C', 'B01J', 1),
#  ('F21Y', 'F21V', 2),
#  ('F16L', 'B65D', 1),
#  ('B65D', 'A61M', 2),
#  ('C25B', 'B29C', 1),
#  ('H04W', 'G08B', 1),
#  ('C08L', 'B29L', 1),
#  ('C12N', 'C07K', 5),
#  ('H02K', 'B23P', 1),
#  ('A61M', 'A61H', 2),
#  ('G01D', 'A61L', 1),
#  ('C08J', 'A61B', 1),
#  ('C12Q', 'B01L', 1),
#  ('E01H', 'A01G', 1),
#  ('A23P', 'A23G', 1),
#  ('B07B', 'B03B', 1),
#  ('B29C', 'A61L', 1),
#  ('B05B', 'A62C', 2),
#  ('F03C', 'C23C', 1),
#  ('C12Q', 'A61K', 3),
#  ('F16D', 'A61B', 1),
#  ('G08G', 'B64D', 1),
#  ('F24F', 'B08B', 1),
#  ('G03B', 'A61B', 2),
#  ('G08G', 'G06F', 1),
#  ('A61L', 'A01N', 1),
#  ('C08B', 'A61K', 2),
#  ('G01D', 'F17D', 1),
#  ('G09F', 'B65D', 2),
#  ('C02F', 'B01D', 5),
#  ('H04W', 'A42B', 1),
#  ('H01L', 'B08B', 1),
#  ('B25H', 'A45F', 1),
#  ('E04B', 'B65D', 1),
#  ('C01B', 'B82Y', 1),
#  ('H04W', 'G01L', 1),
#  ('G01F', 'F04B', 1),
#  ('A01D', 'A01B', 1),
#  ('C12N', 'A23C', 2),
#  ('H01L', 'C09J', 1),
#  ('A46B', 'A45D', 2),
#  ('A63G', 'A63C', 1),
#  ('C08J', 'B29C', 1),
#  ('A47D', 'A47C', 1),
#  ('B82Y', 'A61J', 1),
#  ('F16C', 'F03C', 1),
#  ('B05C', 'B01F', 1),
#  ('F25D', 'A23G', 1),
#  ('B25J', 'A61B', 1),
#  ('A61K', 'A61C', 1),
#  ('H02N', 'H01L', 1),
#  ('B25J', 'B05C', 1),
#  ('H05B', 'H02J', 1),
#  ('B60N', 'A61G', 2),
#  ('C09J', 'B32B', 1),
#  ('G06Q', 'A47G', 1),
#  ('C08J', 'A61L', 2),
#  ('C11B', 'A23K', 1),
#  ('H04N', 'A63F', 1),
#  ('B29L', 'A63B', 3),
#  ('C23F', 'A61L', 2),
#  ('G05D', 'A63H', 1),
#  ('G05D', 'A61G', 1),
#  ('B21D', 'B21C', 1),
#  ('F26B', 'A61L', 1),
#  ('H04N', 'A61B', 6),
#  ('G01B', 'B08B', 1),
#  ('G09F', 'B01L', 1),
#  ('A24F', 'A24B', 2),
#  ('A47G', 'A45F', 2),
#  ('B01F', 'A61J', 1),
#  ('G09B', 'G01L', 1),
#  ('G01N', 'A61K', 10),
#  ('B65G', 'A47B', 1),
#  ('F01M', 'B01D', 1),
#  ('C12P', 'C11B', 1),
#  ('B01J', 'A01N', 1),
#  ('H04W', 'H04L', 1),
#  ('A61G', 'A61B', 1),
#  ('F16M', 'A01K', 1),
#  ('B09B', 'B01J', 1),
#  ('C08L', 'B29C', 1),
#  ('F01B', 'C23C', 1),
#  ('F21W', 'A47L', 1),
#  ('F16N', 'F02C', 1),
#  ('A41F', 'A41D', 1),
#  ('B29L', 'A61L', 1),
#  ('G08B', 'B64D', 1),
#  ('E01H', 'A47L', 1),
#  ('A41D', 'A01M', 1),
#  ('B60T', 'A61G', 1),
#  ('C12N', 'A01N', 2),
#  ('E21B', 'C22C', 1),
#  ('H01C', 'A24F', 1),
#  ('H04Q', 'H02J', 1),
#  ('B65G', 'B21C', 1),
#  ('F16C', 'B22F', 1),
#  ('F16L', 'A47J', 1),
#  ('A23L', 'A01J', 1),
#  ('A62B', 'A61B', 1),
#  ('C08K', 'B01J', 1),
#  ('A01K', 'A01J', 1),
#  ('B23K', 'A24F', 1),
#  ('F16K', 'A62C', 1),
#  ('H04B', 'A63F', 1),
#  ('H04L', 'G06K', 1),
#  ('C12R', 'A61K', 1),
#  ('B29C', 'A61B', 1),
#  ('F16H', 'A47C', 1),
#  ('G09B', 'A63F', 1),
#  ('E04B', 'B01D', 1),
#  ('H04L', 'G08C', 2),
#  ('G06Q', 'A61M', 1),
#  ('F04D', 'A47J', 1),
#  ('F16J', 'C23C', 1),
#  ('A47J', 'A47F', 1),
#  ('A42B', 'A24F', 1),
#  ('A23C', 'A01J', 1),
#  ('A01G', 'A01B', 1),
#  ('H04B', 'F16K', 1),
#  ('D04H', 'A61F', 1),
#  ('C03C', 'B01J', 1),
#  ('G01F', 'A24F', 2),
#  ('H01B', 'C08L', 1),
#  ('F04B', 'C23C', 1),
#  ('G01L', 'A61B', 3),
#  ('H05B', 'H01R', 1),
#  ('C08B', 'A23L', 1),
#  ('G01N', 'B04B', 1),
#  ('H04Q', 'G08C', 2),
#  ('B65D', 'A47G', 4),
#  ('B65D', 'A24F', 4),
#  ('B29L', 'B29D', 2),
#  ('H04B', 'G01L', 1),
#  ('H05B', 'A47J', 2),
#  ('F16M', 'A47G', 2),
#  ('H01M', 'C25B', 1),
#  ('H01M', 'A24F', 1),
#  ('C07D', 'C07C', 1),
#  ('F16H', 'B23D', 1),
#  ('G05B', 'A61B', 3),
#  ('B25J', 'B05B', 1),
#  ('H04W', 'G09B', 1),
#  ('B29K', 'B29C', 4),
#  ('B65D', 'B01F', 1),
#  ('B25C', 'A61B', 2),
#  ('H04N', 'G06F', 2),
#  ('H01M', 'B29C', 1),
#  ('H02J', 'B65D', 2),
#  ('B05B', 'A61F', 2),
#  ('A45F', 'A44C', 1),
#  ('B60R', 'B25D', 1),
#  ('G07C', 'G05D', 1),
#  ('G06F', 'A61B', 13),
#  ('C12N', 'A61K', 12),
#  ('B26B', 'B23D', 1),
#  ('F24C', 'A21D', 1),
#  ('B32B', 'B29C', 1),
#  ('C12P', 'A23D', 1),
#  ('C03C', 'A61J', 1),
#  ('B04B', 'A61M', 1),
#  ('H04Q', 'G06F', 2),
#  ('H04N', 'H04L', 1),
#  ('G08G', 'B64F', 1),
#  ('A47L', 'A47G', 2),
#  ('H01R', 'A62B', 1),
#  ('B65B', 'A23L', 1),
#  ('A21D', 'A21B', 1),
#  ('H02J', 'G01F', 2),
#  ('H04L', 'G01L', 1),
#  ('A61G', 'A47D', 1),
#  ('A61K', 'A01N', 10),
#  ('G06K', 'B33Y', 1),
#  ('B01F', 'A23L', 1),
#  ('B22D', 'B21D', 2),
#  ('G05B', 'A61H', 1),
#  ('B23K', 'B05B', 1),
#  ('G08G', 'G07C', 1),
#  ('C11B', 'A23D', 1),
#  ('B60K', 'A63B', 1),
#  ('F16C', 'B05D', 1),
#  ('B23K', 'B23B', 1),
#  ('B60N', 'A61M', 1),
#  ('A61N', 'A61F', 7),
#  ('A61K', 'A61F', 5),
#  ('H04W', 'H04Q', 1),
#  ('H04Q', 'A63B', 2),
#  ('E02F', 'B07B', 2),
#  ('B07B', 'A01B', 1),
#  ('C02F', 'B29C', 1),
#  ('C21D', 'B21D', 1),
#  ('B41J', 'A45F', 1),
#  ('B65D', 'A47F', 1),
#  ('C22F', 'C22C', 1),
#  ('F16L', 'A61M', 1),
#  ('G03B', 'A61N', 1),
#  ('B67D', 'A47J', 1),
#  ('A47G', 'A47B', 1),
#  ('H01M', 'C02F', 1),
#  ('G06F', 'A47G', 1),
#  ('H01C', 'A61M', 1),
#  ('C08L', 'B32B', 1),
#  ('G08C', 'G06T', 2),
#  ('A61G', 'A47C', 1),
#  ('B60S', 'B08B', 1),
#  ('C12Q', 'C08L', 1),
#  ('G01F', 'G01D', 1),
#  ('E06B', 'B01D', 1),
#  ('F21W', 'F21V', 1),
#  ('B60P', 'A01F', 1),
#  ('G01F', 'A61M', 3),
#  ('C09J', 'C01G', 1),
#  ('B60R', 'A62B', 1),
#  ('H01L', 'C01G', 1),
#  ('G06T', 'G06K', 3),
#  ('E04B', 'B21D', 1),
#  ('B82Y', 'B22F', 1),
#  ('H05H', 'A61L', 1),
#  ('A61M', 'A47G', 1),
#  ('B04B', 'B03D', 1),
#  ('E21B', 'B22D', 1),
#  ('B21K', 'A47J', 1),
#  ('B60L', 'B60K', 1),
#  ('G06F', 'B64D', 1),
#  ('C08G', 'A61K', 1),
#  ('F21V', 'B25B', 1),
#  ('B08B', 'A47K', 1),
#  ('F16N', 'F01M', 1),
#  ('E03F', 'B25B', 1),
#  ('B23K', 'B21F', 2),
#  ('G01N', 'C08G', 1),
#  ('G06F', 'F25D', 1),
#  ('B01D', 'A61B', 1),
#  ('B65D', 'B32B', 1),
#  ('G06F', 'A61N', 1),
#  ('F24F', 'A01K', 1),
#  ('B60B', 'A61G', 1),
#  ('B08B', 'A61J', 1),
#  ('H05B', 'B21D', 1),
#  ('F16M', 'A61B', 1),
#  ('G01G', 'A61G', 1),
#  ('A61H', 'A61G', 3),
#  ('E04B', 'A47J', 1),
#  ('C08L', 'C08B', 2),
#  ('C08L', 'C08G', 2),
#  ('C01C', 'B01J', 1),
#  ('A45F', 'A01M', 1),
#  ('E02F', 'A01B', 1),
#  ('G06F', 'B60K', 1),
#  ('F25B', 'A23L', 1),
#  ('A61N', 'A41D', 1),
#  ('H04Q', 'G06T', 1),
#  ('C12P', 'C07D', 1),
#  ('B60L', 'A61G', 1),
#  ('A61M', 'A61B', 29),
#  ('A63B', 'A61B', 3),
#  ('G02C', 'F41H', 1),
#  ('H01L', 'G08B', 1),
#  ('H02N', 'A63F', 1),
#  ('C07K', 'A61K', 18),
#  ('C22C', 'B21C', 1),
#  ('B65D', 'A61L', 1),
#  ('D06F', 'A47L', 1),
#  ('C12Q', 'C07K', 1),
#  ('G01N', 'A61B', 6),
#  ('G02B', 'C11D', 1),
#  ('H04L', 'H04B', 1),
#  ('H01L', 'B24B', 1),
#  ('D04H', 'A61L', 1),
#  ('A61F', 'A61B', 47),
#  ('H04L', 'A61B', 2),
#  ('F16N', 'B01D', 1),
#  ('B65B', 'A47J', 1),
#  ('A61M', 'A47L', 1),
#  ('B04B', 'B01D', 1),
#  ('H01J', 'B01J', 1),
#  ('H04L', 'A63F', 5),
#  ('A47L', 'A47K', 1),
#  ('G08G', 'A61G', 1),
#  ('C12P', 'A23L', 1),
#  ('G08B', 'A42B', 1),
#  ('G01B', 'B60S', 1),
#  ('B23P', 'B23B', 2),
#  ('G06T', 'A61C', 1),
#  ('G06Q', 'A63F', 1),
#  ('F16K', 'A61M', 1),
#  ('G09F', 'A47B', 1),
#  ('B60K', 'A61B', 1),
#  ('G06T', 'A63F', 3),
#  ('G08B', 'A61B', 2),
#  ('H04W', 'G06T', 1),
#  ('B33Y', 'A61F', 1),
#  ('H02J', 'A61B', 1),
#  ('G01R', 'A61N', 2),
#  ('G06T', 'A63B', 2),
#  ('F25D', 'A47F', 1),
#  ('G06T', 'G01N', 1),
#  ('G08B', 'B60K', 1),
#  ('C12M', 'A61K', 1),
#  ('G08C', 'A61B', 5),
#  ('F16J', 'B05D', 1),
#  ('A61N', 'A43B', 1),
#  ('B23B', 'B21C', 1),
#  ('G01F', 'E03B', 1),
#  ('H04Q', 'G05B', 1),
#  ('F16B', 'B21D', 1),
#  ('G06K', 'G06F', 3),
#  ('B29D', 'A43B', 1),
#  ('G06F', 'A63F', 7),
#  ('G06F', 'A61C', 2),
#  ('A01N', 'A01M', 1),
#  ('G01M', 'F16K', 1),
#  ('C10G', 'B01J', 1),
#  ('F02C', 'F01D', 1),
#  ('B60S', 'B05B', 1),
#  ('C25D', 'B82Y', 1),
#  ('H01J', 'A61L', 2),
#  ('F16C', 'C22C', 1),
#  ('C12P', 'A61K', 1),
#  ('C01B', 'B01J', 3),
#  ('A61Q', 'A01N', 2),
#  ('B66F', 'A01B', 1),
#  ('B25B', 'A01K', 1),
#  ('C05G', 'A01G', 1),
#  ('F16L', 'B32B', 1),
#  ('F16B', 'A01K', 1),
#  ('B01F', 'A21D', 1),
#  ('B32B', 'A61F', 1),
#  ('G08B', 'A01K', 1),
#  ('B60P', 'A01D', 1),
#  ('B05B', 'B01J', 1),
#  ('B29L', 'A47C', 1),
#  ('B29C', 'A45F', 1),
#  ('B65D', 'A61D', 1),
#  ('C25B', 'C02F', 1),
#  ('A23L', 'A23K', 2),
#  ('C21D', 'B21F', 2),
#  ('D06F', 'B65D', 1),
#  ('B65G', 'A47J', 1),
#  ('H01B', 'C07C', 1),
#  ('G01F', 'B65B', 2),
#  ('H01B', 'B01J', 2),
#  ('B21F', 'A61L', 2),
#  ('G01M', 'E03B', 1),
#  ('B66F', 'A01G', 1),
#  ('A63C', 'A43B', 1),
#  ('B22D', 'B21C', 1),
#  ('G09G', 'A61B', 1),
#  ('B43M', 'A45D', 1),
#  ('G02B', 'A61K', 1),
#  ('H04W', 'B33Y', 1),
#  ('H04Q', 'G08B', 1),
#  ('A63G', 'A43B', 1),
#  ('G01B', 'A63B', 1),
#  ('G02C', 'A61B', 1),
#  ('C08F', 'A61K', 1),
#  ('H04L', 'B33Y', 1),
#  ('B65B', 'B01F', 1),
#  ('H04N', 'F16M', 2),
#  ('B65B', 'A24F', 2),
#  ('B01J', 'B01D', 8),
#  ('H05B', 'B23K', 1),
#  ('A61N', 'A61B', 19),
#  ('B23K', 'A61N', 1),
#  ('C22C', 'A61L', 1),
#  ('A61M', 'A24F', 4),
#  ('A47J', 'A47G', 1),
#  ('G06F', 'B64F', 1),
#  ('B05D', 'A61M', 1),
#  ('C23C', 'B23B', 2),
#  ('B29K', 'A45F', 1),
#  ('B05C', 'B05B', 4),
#  ('A61N', 'A61H', 2),
#  ('B60K', 'B60B', 1),
#  ('A47L', 'A47J', 1),
#  ('F28F', 'F25B', 1),
#  ('G21F', 'C02F', 1),
#  ('C12P', 'A23K', 1),
#  ('B29K', 'A61B', 1),
#  ('C12M', 'B01L', 2),
#  ('F28D', 'B01D', 1),
#  ('E06B', 'B62D', 1),
#  ('G06K', 'A61F', 1),
#  ('F16H', 'A61M', 1),
#  ('B65D', 'A46B', 1),
#  ('G08C', 'G06F', 1),
#  ('G06F', 'A61H', 1),
#  ('H04N', 'G01K', 1),
#  ('B60B', 'A63B', 1),
#  ('A47J', 'A47B', 1),
#  ('F01N', 'B01D', 7),
#  ('F28F', 'F28D', 1),
#  ('A61K', 'A61J', 3),
#  ('G08B', 'A63F', 1),
#  ('F16C', 'F01B', 1),
#  ('A61L', 'A61F', 14),
#  ('B33Y', 'A63B', 1),
#  ('B65G', 'A01D', 1),
#  ('C22F', 'A61L', 3),
#  ('G05B', 'A61L', 1),
#  ('G05B', 'B21D', 1),
#  ('A61N', 'A61M', 7),
#  ('G01R', 'A41D', 1),
#  ('B64D', 'A62B', 1),
#  ('C11D', 'B01J', 1),
#  ('F03C', 'F01B', 1),
#  ('C08L', 'A23G', 1),
#  ('B32B', 'B29D', 1),
#  ('A61M', 'A61D', 1),
#  ('B26F', 'A61J', 1),
#  ('C25D', 'B03C', 1),
#  ('A63F', 'A63B', 2),
#  ('B08B', 'B01F', 1),
#  ('H04N', 'G09B', 1),
#  ('H04N', 'H04B', 1),
#  ('F16M', 'F16B', 1),
#  ('H02J', 'G05B', 1),
#  ('F27B', 'C21C', 1),
#  ('G01N', 'C12Q', 4),
#  ('C07H', 'A61K', 1),
#  ('B29L', 'A61M', 1),
#  ('A47F', 'A47B', 1),
#  ('G21F', 'B01D', 1),
#  ('C03C', 'A61K', 1),
#  ('G09F', 'B65B', 2),
#  ('C05G', 'A01N', 1),
#  ('C08L', 'A61K', 3),
#  ('G01C', 'B02C', 1),
#  ('H05B', 'H01F', 1),
#  ('A47G', 'A46B', 1),
#  ('C12R', 'C12Q', 1),
#  ('A62B', 'A42B', 1),
#  ('B60T', 'A61H', 1),
#  ('G02F', 'C25D', 1),
#  ('B05C', 'A61M', 1),
#  ('G06F', 'G01L', 1),
#  ('G02C', 'A42B', 1),
#  ('B29D', 'A63B', 1),
#  ('B29C', 'A61K', 1),
#  ('F24J', 'F24F', 1),
#  ('B23K', 'A61F', 3),
#  ('B67C', 'B05B', 1),
#  ('B32B', 'B21D', 1),
#  ('A62B', 'A61L', 2),
#  ('C08L', 'B01J', 2),
#  ('G08B', 'A61D', 1),
#  ('F24F', 'A61J', 1),
#  ('H01L', 'A63F', 1),
#  ('B32B', 'A61G', 1),
#  ('C12Q', 'C08G', 1),
#  ('H04Q', 'H04N', 1),
#  ('G01K', 'G01F', 1),
#  ('A61D', 'A01K', 1),
#  ('B60L', 'B60B', 1),
#  ('A45F', 'A41D', 1),
#  ('H02J', 'B23K', 1),
#  ('C08G', 'A61B', 1),
#  ('B65D', 'A61K', 1),
#  ('B65C', 'A47L', 1),
#  ('C12M', 'A61M', 1),
#  ('H04L', 'G06F', 1),
#  ('B05D', 'B05B', 5),
#  ('H04W', 'A61B', 1),
#  ('B01D', 'A47L', 1),
#  ('H02J', 'A24F', 4),
#  ('C12N', 'A01H', 24),
#  ('B29L', 'A45F', 1),
#  ('F16M', 'A46B', 1),
#  ('G01F', 'F16K', 1),
#  ('B05D', 'B01J', 1),
#  ('A01N', 'A01G', 1),
#  ('B60N', 'A61B', 1),
#  ('H04W', 'A63B', 2),
#  ('G01V', 'A61B', 1),
#  ('F21Y', 'F21W', 1),
#  ('C23F', 'C22F', 2),
#  ('H05B', 'C22C', 1),
#  ('G06F', 'G05D', 2),
#  ('G01V', 'G01R', 1),
#  ('C02F', 'B01J', 2),
#  ('H05B', 'B22D', 1),
#  ('B65D', 'B65B', 4),
#  ('G09F', 'G06Q', 1),
#  ('B08B', 'B05B', 1),
#  ('B29K', 'A61F', 1),
#  ('A61Q', 'A45D', 1),
#  ('B65D', 'A47L', 2),
#  ('A61G', 'A47G', 1),
#  ('G09G', 'G08C', 1),
#  ('G02B', 'A61F', 1),
#  ('G01N', 'B08B', 1),
#  ('F16B', 'A47C', 1),
#  ('F17D', 'A62C', 1),
#  ('G01S', 'A63B', 1),
#  ('H01R', 'A47J', 1),
#  ('A61K', 'A24F', 1),
#  ('C01C', 'B01D', 1),
#  ('C08L', 'A63B', 2),
#  ('B65G', 'B65D', 1),
#  ('C08J', 'B29L', 1),
#  ('H01L', 'C08K', 1),
#  ('C12M', 'A61B', 1),
#  ('C21C', 'B22D', 1),
#  ('A61M', 'A61F', 16),
#  ('F16M', 'A47B', 1),
#  ('G02B', 'A62B', 1),
#  ('H04B', 'F17D', 1),
#  ('H04B', 'G01M', 1),
#  ('H04N', 'A61N', 1),
#  ('B29K', 'A61L', 1),
#  ('B05D', 'B05C', 3),
#  ('F25D', 'A23L', 1),
#  ('F02C', 'B01D', 2),
#  ('C22C', 'B22C', 1),
#  ('H04B', 'A63B', 1),
#  ('B67C', 'B65B', 1),
#  ('A61D', 'A61B', 1),
#  ('F16B', 'B29C', 1),
#  ('G09B', 'A63B', 5),
#  ('G09F', 'F16M', 1),
#  ('G06Q', 'A61B', 1),
#  ('A61H', 'A61F', 3),
#  ('G01R', 'A61B', 2),
#  ('C08K', 'A63B', 2),
#  ('F21V', 'A47G', 1),
#  ('H04L', 'G08B', 1),
#  ('A61H', 'A47C', 1),
#  ('H04B', 'B33Y', 1),
#  ('H01R', 'B25D', 1),
#  ('F26B', 'A23L', 2),
#  ('C07K', 'A23J', 1),
#  ('C08F', 'B05B', 1),
#  ('C22F', 'B23K', 2),
#  ('F16M', 'A45F', 1),
#  ('H02J', 'G08C', 1),
#  ('A47L', 'A47B', 1),
#  ('H05B', 'B05B', 1),
#  ('F17D', 'E03B', 1),
#  ('B05B', 'A01G', 1),
#  ('C07F', 'A61K', 1),
#  ('C08J', 'C08G', 1),
#  ('F21V', 'F16B', 1),
#  ('B82Y', 'B01J', 2),
#  ('B65B', 'A21D', 1),
#  ('B23P', 'B21J', 1),
#  ('F04B', 'B05D', 1),
#  ('A61K', 'A23J', 1),
#  ('B04B', 'B01L', 1),
#  ('C08L', 'A61L', 2),
#  ('B65D', 'A47J', 5),
#  ('B65D', 'A47B', 1),
#  ('A47J', 'A21D', 2),
#  ('F27D', 'C21C', 1),
#  ('G06K', 'G01L', 1),
#  ('B29L', 'B29C', 8),
#  ('H01L', 'B32B', 1),
#  ('G01K', 'A61M', 1),
#  ('F16H', 'B26B', 1),
#  ('B29K', 'A63B', 2),
#  ('C23C', 'C08F', 1),
#  ('H04L', 'G05B', 1),
#  ('E04B', 'B32B', 1),
#  ('F01D', 'B01D', 1),
#  ('A01C', 'A01B', 4),
#  ('E04B', 'A47K', 1),
#  ('F21V', 'A45C', 1),
#  ('C09D', 'A61K', 1),
#  ('C22C', 'B22D', 4),
#  ('H02J', 'G09F', 2),
#  ('G02B', 'A63J', 1),
#  ('G08G', 'G05D', 1),
#  ('F17D', 'A61M', 1),
#  ('D04B', 'A61F', 1),
#  ('B32B', 'B01D', 1),
#  ('B25B', 'A47K', 1),
#  ('A63B', 'A01K', 1),
#  ('C01G', 'B01J', 1),
#  ('A61P', 'A61F', 1),
#  ('F21V', 'A01G', 1),
#  ('H05B', 'A61M', 1),
#  ('H02K', 'A47L', 1),
#  ('B65G', 'A22C', 1),
#  ('F24C', 'A47J', 2),
#  ('B62D', 'A01M', 1),
#  ('A61N', 'A61L', 3),
#  ('G02F', 'B03C', 1),
#  ('B08B', 'A61G', 1),
#  ('F21Y', 'A47G', 1),
#  ('B23D', 'B23B', 2),
#  ('H04W', 'H04B', 1),
#  ('H04Q', 'H04L', 2),
#  ('B65D', 'A61B', 1),
#  ('G08G', 'G08B', 1),
#  ('H04N', 'B02C', 1),
#  ('A43C', 'A43B', 4),
#  ('G01F', 'A62C', 1),
#  ('B65D', 'A01K', 1),
#  ('B23K', 'B05D', 1),
#  ('C07C', 'B01J', 4),
#  ('B65G', 'A47F', 1),
#  ('C11B', 'A23L', 1),
#  ('B65G', 'A01F', 1),
#  ('B08B', 'A47L', 3),
#  ('G01F', 'A61B', 1),
#  ('G09G', 'A63F', 1),
#  ('H01R', 'H01F', 1),
#  ('C12N', 'A23K', 1),
#  ('C08J', 'B01J', 1),
#  ('G01N', 'C07D', 1),
#  ('B01J', 'A61L', 2),
#  ('H04N', 'G05B', 1),
#  ('F16N', 'F01D', 1),
#  ('C12N', 'A23L', 2),
#  ('C11D', 'A61K', 2),
#  ('G09G', 'G06T', 1),
#  ('F04B', 'F01B', 1),
#  ('C08L', 'B82Y', 1),
#  ('B41J', 'B05B', 1),
#  ('B32B', 'A61B', 1),
#  ('C01B', 'B01D', 3),
#  ('H04W', 'H04N', 1),
#  ('G07F', 'A47F', 1),
#  ('B21K', 'B01D', 1),
#  ('B29L', 'A24F', 1),
#  ('B24B', 'B21C', 1),
#  ('B29L', 'A47G', 1),
#  ('B32B', 'B22D', 1),
#  ('A61L', 'A61K', 17),
#  ('B23B', 'B06B', 1),
#  ('C12N', 'A61L', 2),
#  ('G09F', 'A24F', 2),
#  ('F25B', 'A23G', 1),
#  ('H01L', 'A61N', 1),
#  ('C23F', 'A61F', 2),
#  ('G06F', 'A45C', 1),
#  ('C09J', 'B01J', 1),
#  ('A43D', 'A43B', 2),
#  ('F04B', 'A61M', 3),
#  ('H02J', 'B65B', 2),
#  ('B24B', 'B23P', 1),
#  ('A61J', 'A61B', 1),
#  ('A61P', 'A61K', 2),
#  ('G09B', 'A61K', 1),
#  ('A63H', 'A01K', 1),
#  ('C08K', 'B32B', 1),
#  ('G05D', 'B64F', 1),
#  ('H05B', 'H01C', 1),
#  ('G10L', 'A63F', 1),
#  ('B65G', 'B60P', 1),
#  ('F02D', 'F01N', 1),
#  ('H01F', 'A47J', 1),
#  ('G05B', 'A61C', 1),
#  ('A63H', 'A63F', 2),
#  ('B33Y', 'B22F', 1),
#  ('F21V', 'A47L', 1),
#  ('B29L', 'A61F', 2),
#  ('B29D', 'A43C', 1),
#  ('B65C', 'B08B', 1),
#  ('H04B', 'G10L', 1),
#  ('G01L', 'A01B', 2),
#  ('F16B', 'A24F', 1),
#  ('B24B', 'B23D', 1),
#  ('G01N', 'G01D', 1),
#  ('H04N', 'G01L', 1),
#  ('B01F', 'A21C', 1),
#  ('B65D', 'A21D', 1),
#  ('G21K', 'A61N', 1),
#  ('G06T', 'G01S', 1),
#  ('H04R', 'A61C', 1),
#  ('G07C', 'B64D', 1),
#  ('F27D', 'F27B', 1),
#  ('B32B', 'A47L', 1),
#  ('G08B', 'G05B', 1),
#  ('H04R', 'A61B', 1),
#  ('C07H', 'A23L', 1),
#  ('G05B', 'A61G', 1),
#  ('H02K', 'F04D', 1),
#  ('F16C', 'C23C', 1),
#  ('B82Y', 'A61Q', 1),
#  ('G06F', 'A61M', 7),
#  ('C11D', 'A01N', 1),
#  ('A47J', 'A21C', 1),
#  ('B65G', 'A01C', 1),
#  ('B04B', 'B03B', 1),
#  ('B23K', 'B22F', 1),
#  ('G06K', 'G01S', 1),
#  ('C23C', 'B05D', 2),
#  ('G01N', 'C12M', 2),
#  ('H04L', 'A63B', 1),
#  ('C08L', 'B29D', 1),
#  ('B01F', 'A47J', 1),
#  ('B24B', 'B23B', 2),
#  ('B60K', 'A61G', 1),
#  ('D04D', 'A44C', 1),
#  ('B26D', 'A47J', 1),
#  ('G05B', 'A61K', 1),
#  ('H01M', 'C01B', 1),
#  ('D04D', 'B65H', 1),
#  ('G01D', 'E03B', 1),
#  ('H04B', 'G01D', 1),
#  ('B65D', 'A63B', 1),
#  ('C01B', 'A61K', 1),
#  ('A61Q', 'A61K', 15),
#  ('B04C', 'A47L', 1),
#  ('B65G', 'A47L', 1),
#  ('A61H', 'A61C', 1),
#  ('B26B', 'A47J', 1),
#  ('B29K', 'A47C', 1),
#  ('G01B', 'B05D', 1),
#  ('F16J', 'F04B', 1),
#  ('F04D', 'A47L', 1),
#  ('B05D', 'A61F', 2),
#  ('H04W', 'G06F', 2),
#  ('H04B', 'G06F', 1),
#  ('H05K', 'A61N', 1),
#  ('C08J', 'A61K', 1),
#  ('C03C', 'B09B', 1),
#  ('G01N', 'B01L', 6),
#  ('A01F', 'A01D', 3),
#  ('A61B', 'A47G', 1),
#  ('H05K', 'A47B', 2),
#  ('C12N', 'A01K', 1),
#  ('G21K', 'A61B', 1),
#  ('A47C', 'A45F', 1),
#  ('C07F', 'C07D', 1),
#  ('G01B', 'B05B', 2),
#  ('B08B', 'A61B', 1),
#  ('G06K', 'A61B', 6),
#  ('A45F', 'A42B', 1),
#  ('A21D', 'A21C', 2),
#  ('G06T', 'G06F', 3),
#  ('H04N', 'G06T', 1),
#  ('C08L', 'C08J', 2),
#  ('A62D', 'A61L', 1),
#  ('C04B', 'A61N', 1),
#  ('A47G', 'A47C', 1),
#  ('B01J', 'A62D', 1),
#  ('C08J', 'A61F', 1),
#  ('G09B', 'B33Y', 1),
#  ('H04N', 'G01S', 2),
#  ('C12P', 'C12N', 1),
#  ('G01N', 'B01D', 1),
#  ('G06K', 'A63B', 2),
#  ('C08L', 'C08F', 1),
#  ('F16J', 'F01B', 1),
#  ('B43M', 'A46B', 1),
#  ('B25J', 'A61M', 1),
#  ('B08B', 'A47G', 1),
#  ('A63C', 'A63B', 1),
#  ('H04N', 'G09G', 1),
#  ('E02B', 'A01N', 1),
#  ('C25B', 'B01J', 1),
#  ('G05B', 'G01D', 1),
#  ('H04N', 'G01C', 1),
#  ('A61B', 'A41D', 1),
#  ('C07K', 'A61M', 1),
#  ('B32B', 'B21K', 1),
#  ('B29C', 'A47G', 1),
#  ('F01M', 'F01D', 1),
#  ('B32B', 'B01J', 1),
#  ('E21B', 'B22C', 1),
#  ('A61H', 'A47K', 1),
#  ('F16C', 'F04B', 1),
#  ('C07D', 'A61K', 14),
#  ('B64F', 'A61G', 1),
#  ('G01K', 'B02C', 1),
#  ('A61B', 'A47L', 1),
#  ('G06F', 'A63H', 1),
#  ('H02J', 'A61M', 1),
#  ('C23F', 'B21F', 2),
#  ('G01S', 'A61B', 2),
#  ('C22C', 'B21D', 2),
#  ('G21F', 'B01J', 1),
#  ('C22F', 'B21F', 2),
#  ('B64F', 'B64D', 1),
#  ('A01H', 'A01G', 1),
#  ('E02B', 'C05G', 1),
#  ('A43D', 'A43C', 1),
#  ('B22D', 'B22C', 1),
#  ('F04D', 'A61M', 1),
#  ('C08G', 'A61Q', 1),
#  ('A61N', 'A24F', 1),
#  ('C12N', 'A23D', 1),
#  ('B65D', 'A45D', 2),
#  ('G09B', 'A61B', 1),
#  ('H05K', 'H01L', 1),
#  ('B65D', 'A61J', 4),
#  ('F03C', 'B05D', 1),
#  ('H01L', 'B01J', 2),
#  ('C08J', 'B29K', 1),
#  ('A61K', 'A23K', 2),
#  ('A61F', 'A41D', 1),
#  ('H04N', 'G03B', 1),
#  ('H04B', 'A61B', 1),
#  ('H02J', 'G08B', 1),
#  ('C08L', 'A61Q', 2),
#  ('B33Y', 'A61B', 1),
#  ('A61M', 'A61K', 6),
#  ('C08B', 'A61L', 1),
#  ('F21Y', 'A47L', 1),
#  ('B01D', 'A61M', 3),
#  ('B65D', 'B01D', 1),
#  ('G01B', 'C08K', 1),
#  ('B29D', 'B29C', 2),
#  ('A61J', 'A47G', 1),
#  ('G06Q', 'G06F', 3),
#  ('G08C', 'G08B', 1),
#  ('G08C', 'G05B', 1),
#  ('F16J', 'F03C', 1),
#  ('G03B', 'G02B', 2),
#  ('C22F', 'A61F', 3),
#  ('G06Q', 'F25D', 1),
#  ('A23L', 'A23C', 1),
#  ('A23L', 'A23G', 2),
#  ('B29K', 'A47G', 1),
#  ('G06T', 'A61B', 11),
#  ('H01R', 'B60R', 1),
#  ('C09D', 'C08B', 1),
#  ('G03B', 'G01S', 1),
#  ('G07C', 'B64F', 1),
#  ('B29L', 'B29K', 4),
#  ('B32B', 'A61M', 1),
#  ('H04L', 'G09B', 2),
#  ('F16L', 'A62C', 1),
#  ('C22C', 'B22F', 1),
#  ('B05B', 'A61M', 1),
#  ('F16L', 'E04B', 1),
#  ('B23P', 'B21D', 1),
#  ('F16L', 'B21K', 1),
#  ('H04Q', 'G01L', 1),
#  ('G01M', 'G01D', 1),
#  ('C23C', 'B23K', 1),
#  ('E03F', 'A47K', 1),
#  ('G02F', 'B82Y', 1),
#  ('C09D', 'C08L', 1),
#  ('B65D', 'B21K', 1),
#  ('C22F', 'C21D', 2),
#  ('F16K', 'E03B', 1),
#  ('C12Q', 'B01J', 1),
#  ('A61K', 'A01K', 1),
#  ...]

# %%
data_second
# Out:
# [('C11B', 'C07D', 1),
#  ('C10B', 'B09B', 1),
#  ('F16L', 'B62D', 1),
#  ('G03F', 'B41C', 1),
#  ('G06F', 'C08C', 1),
#  ('F02B', 'C01B', 1),
#  ('B32B', 'A61F', 1),
#  ('F16C', 'B61F', 1),
#  ('C03B', 'A61J', 1),
#  ('B62K', 'B60Q', 1),
#  ('B64D', 'B60R', 2),
#  ('C07D', 'C04B', 1),
#  ('B60Q', 'A01B', 1),
#  ('C09G', 'B24D', 1),
#  ('G01N', 'B01J', 2),
#  ('G02F', 'B32B', 1),
#  ('B62D', 'B60P', 4),
#  ('G02B', 'B64F', 1),
#  ('G02B', 'C07C', 1),
#  ('G02F', 'C08F', 1),
#  ('B67B', 'B65D', 1),
#  ('F02D', 'C12N', 1),
#  ('G06T', 'B29C', 1),
#  ('G01N', 'B82Y', 2),
#  ('C05C', 'C05B', 1),
#  ('B62D', 'B60R', 10),
#  ('B60J', 'B32B', 2),
#  ('H01B', 'B82Y', 1),
#  ('G02F', 'G02B', 2),
#  ('G06F', 'B29C', 1),
#  ('C07J', 'A61K', 1),
#  ('H01L', 'C08G', 2),
#  ('B65B', 'A61B', 2),
#  ('F16B', 'B30B', 1),
#  ('B62L', 'B62J', 1),
#  ('C04B', 'B23K', 1),
#  ('C08F', 'B05D', 2),
#  ('F16H', 'B60W', 1),
#  ('B60W', 'B60R', 3),
#  ('C10M', 'B32B', 1),
#  ('G01V', 'G01S', 1),
#  ('B62D', 'B60L', 1),
#  ('C10H', 'C07C', 1),
#  ('B61L', 'B61C', 2),
#  ('F16B', 'B23P', 1),
#  ('C22B', 'B01D', 1),
#  ('G02B', 'F21V', 1),
#  ('G05B', 'B29C', 1),
#  ('B44C', 'B30B', 1),
#  ('F28C', 'B01D', 2),
#  ('C07D', 'A01N', 6),
#  ('C08J', 'C04B', 1),
#  ('C09D', 'B63B', 1),
#  ('F16C', 'F04C', 1),
#  ('C09J', 'B44F', 1),
#  ('F02C', 'C10J', 1),
#  ('F02K', 'C06B', 1),
#  ('G06F', 'G01N', 1),
#  ('C05F', 'C02F', 1),
#  ('G07C', 'A01B', 1),
#  ('C07F', 'B01D', 1),
#  ('D21F', 'D04H', 1),
#  ('B23K', 'B23D', 1),
#  ('C04B', 'B60C', 1),
#  ('B65G', 'B21B', 1),
#  ('G02B', 'G01N', 1),
#  ('E04B', 'C09J', 1),
#  ('C22B', 'B29B', 1),
#  ('G09G', 'G01D', 1),
#  ('B60N', 'B29D', 1),
#  ('B29K', 'A44B', 1),
#  ('H01M', 'B62K', 1),
#  ('E21B', 'E02F', 1),
#  ('G10K', 'B41J', 1),
#  ('B26F', 'B25J', 1),
#  ('F16G', 'B29C', 1),
#  ('B64D', 'B60K', 1),
#  ('D06F', 'B41F', 1),
#  ('C09J', 'B29L', 1),
#  ('B44B', 'B30B', 1),
#  ('B63B', 'B60F', 1),
#  ('B60R', 'B60D', 1),
#  ('C40B', 'B01L', 1),
#  ('H01M', 'B60L', 8),
#  ('H01L', 'B81C', 7),
#  ('G01N', 'C09K', 1),
#  ('F16C', 'B27B', 1),
#  ('B32B', 'A61M', 1),
#  ('B60R', 'B60J', 2),
#  ('D21H', 'C09J', 1),
#  ('B65D', 'B23P', 1),
#  ('C11B', 'A61K', 1),
#  ('G07D', 'B41F', 1),
#  ('C23C', 'B21D', 1),
#  ('D21B', 'B29B', 1),
#  ('G06T', 'B25J', 1),
#  ('B65D', 'A62C', 1),
#  ('G05B', 'B23K', 1),
#  ('C07D', 'A61K', 34),
#  ('F28C', 'C01D', 1),
#  ('C08F', 'B01J', 1),
#  ('G10K', 'E04B', 1),
#  ('C08L', 'B29K', 5),
#  ('G08G', 'B64C', 2),
#  ('C07D', 'A61N', 1),
#  ('B64C', 'B32B', 1),
#  ('C05F', 'C05B', 1),
#  ('C07K', 'A01K', 3),
#  ('F16B', 'B44B', 1),
#  ('C02F', 'B05D', 1),
#  ('F25B', 'B60H', 1),
#  ('H02K', 'B60L', 1),
#  ('H02J', 'F02N', 1),
#  ('B65D', 'A61M', 2),
#  ('H01M', 'H01G', 1),
#  ('B42D', 'A45C', 1),
#  ('C08L', 'B29L', 2),
#  ('B62M', 'B62L', 1),
#  ('B29D', 'A43D', 1),
#  ('C12N', 'C08F', 1),
#  ('F16L', 'B60B', 1),
#  ('B60C', 'B32B', 2),
#  ('C12Q', 'A61K', 3),
#  ('D01D', 'C07D', 1),
#  ('D01H', 'B65H', 1),
#  ('A61N', 'A61K', 4),
#  ('G08G', 'G06F', 1),
#  ('G06F', 'B32B', 1),
#  ('C09J', 'B44C', 1),
#  ('C08J', 'A62D', 1),
#  ('C02F', 'B01D', 8),
#  ('H05K', 'H05B', 1),
#  ('F21V', 'C09J', 1),
#  ('C09D', 'C03C', 1),
#  ('C09C', 'B22F', 1),
#  ('H05B', 'B29D', 1),
#  ('B62D', 'B32B', 1),
#  ('B62K', 'B29C', 1),
#  ('B66C', 'B64B', 1),
#  ('B60J', 'A47C', 1),
#  ('C04B', 'B22F', 1),
#  ('C08J', 'B01D', 2),
#  ('B65D', 'B29L', 4),
#  ('B65B', 'B31B', 1),
#  ('B25J', 'A61B', 1),
#  ('C09G', 'B24B', 2),
#  ('G05B', 'B33Y', 1),
#  ('F15B', 'B62D', 1),
#  ('B33Y', 'B29C', 6),
#  ('C08J', 'C03C', 1),
#  ('C08J', 'A61L', 1),
#  ('H05K', 'B32B', 2),
#  ('C09K', 'A62D', 1),
#  ('G05B', 'A61B', 1),
#  ('B65D', 'B44D', 1),
#  ('E04H', 'A47C', 1),
#  ('G06T', 'B23Q', 1),
#  ('G09F', 'B42D', 1),
#  ('F04C', 'B67D', 1),
#  ('B29C', 'B05C', 2),
#  ('B63C', 'B63B', 2),
#  ('G01M', 'F16D', 1),
#  ('B23Q', 'B23D', 1),
#  ('E04C', 'B32B', 1),
#  ('D06M', 'B32B', 1),
#  ('B65H', 'B65G', 1),
#  ('C09K', 'C01F', 1),
#  ('B60B', 'B44C', 1),
#  ('B29C', 'A43D', 1),
#  ('C08G', 'A62D', 1),
#  ('H02G', 'B60R', 1),
#  ('G05D', 'A01B', 1),
#  ('F28F', 'B21D', 1),
#  ('H01L', 'C08F', 2),
#  ('B66F', 'B60P', 1),
#  ('C09K', 'C03C', 1),
#  ('C09K', 'C08J', 4),
#  ('B65D', 'B32B', 1),
#  ('B05D', 'B01J', 1),
#  ('B27B', 'A01G', 1),
#  ('F16L', 'B23K', 1),
#  ('B29K', 'B29D', 2),
#  ('F16B', 'B60N', 1),
#  ('H02J', 'G01S', 1),
#  ('G01R', 'B60L', 1),
#  ('B31B', 'B23P', 1),
#  ('G01J', 'B61L', 1),
#  ('B65D', 'A47G', 1),
#  ('B62J', 'B29L', 1),
#  ('B29L', 'A44B', 1),
#  ('H02J', 'H01Q', 1),
#  ('C08J', 'C02F', 1),
#  ('H01L', 'C07D', 1),
#  ('B30B', 'B28B', 1),
#  ('B29K', 'B29C', 22),
#  ('B65D', 'B01F', 1),
#  ('G06F', 'G01D', 1),
#  ('E04F', 'B65G', 1),
#  ('C10H', 'C10B', 1),
#  ('D04H', 'B29D', 1),
#  ('G01N', 'B65D', 1),
#  ('H04N', 'B25J', 1),
#  ('H05K', 'B60K', 1),
#  ('G06F', 'C09J', 1),
#  ('G01L', 'G01B', 1),
#  ('G06F', 'A61B', 1),
#  ('B28C', 'B01F', 1),
#  ('H01L', 'G01N', 1),
#  ('C12P', 'C08G', 2),
#  ('C09D', 'B41J', 1),
#  ('B64C', 'B60R', 1),
#  ('G01R', 'B60R', 1),
#  ('G07D', 'B65H', 1),
#  ('G01C', 'B60W', 1),
#  ('C09J', 'C08L', 3),
#  ('C07K', 'C07H', 5),
#  ('F01D', 'B22F', 1),
#  ('B25G', 'B25B', 1),
#  ('F16B', 'A44B', 1),
#  ('G01L', 'B81C', 1),
#  ('G01V', 'B60R', 1),
#  ('B62D', 'B61B', 1),
#  ('A61K', 'A01N', 7),
#  ('F16G', 'E02F', 1),
#  ('G01S', 'B60W', 1),
#  ('G01N', 'G01L', 1),
#  ('C12N', 'A01K', 2),
#  ('F01D', 'B64C', 2),
#  ('C08K', 'B60C', 6),
#  ('B63G', 'B62D', 1),
#  ('H05B', 'F26B', 1),
#  ('E04B', 'C08L', 1),
#  ('B44C', 'B23K', 1),
#  ('C08L', 'C08B', 3),
#  ('C08L', 'B60C', 6),
#  ('F21Y', 'C08F', 1),
#  ('B65D', 'B62B', 1),
#  ('B60N', 'A47B', 1),
#  ('C08K', 'A41D', 1),
#  ('H01L', 'C08L', 2),
#  ('B65B', 'A61J', 2),
#  ('B65D', 'B05B', 1),
#  ('G01F', 'B64D', 1),
#  ('F02B', 'B63H', 1),
#  ('D06F', 'B67D', 1),
#  ('E02F', 'B64D', 1),
#  ('F04C', 'F01C', 1),
#  ('B64C', 'B23Q', 2),
#  ('B65D', 'B29C', 4),
#  ('G01C', 'B64D', 1),
#  ('G01V', 'B60L', 1),
#  ('C09J', 'C08G', 5),
#  ('C08G', 'B01J', 2),
#  ('B62D', 'B60H', 1),
#  ('B82Y', 'B29K', 1),
#  ('C08L', 'B32B', 7),
#  ('E06B', 'E05F', 1),
#  ('H01M', 'C01G', 2),
#  ('B64D', 'A62C', 1),
#  ('G10K', 'B60R', 1),
#  ('H05B', 'B60S', 1),
#  ('B60K', 'A01D', 1),
#  ('B25H', 'B23Q', 1),
#  ('C12P', 'C07H', 5),
#  ('C08G', 'B32B', 7),
#  ('G01N', 'A01K', 2),
#  ('G06Q', 'B64C', 1),
#  ('B29C', 'A47L', 1),
#  ('G06T', 'B60R', 1),
#  ('H02H', 'G08B', 1),
#  ('B32B', 'B29C', 14),
#  ('C30B', 'B82Y', 1),
#  ('C08G', 'A61K', 2),
#  ('C07C', 'A61Q', 1),
#  ('C08K', 'B82Y', 1),
#  ('C22C', 'B24D', 1),
#  ('C09J', 'B29C', 3),
#  ('H01F', 'G11B', 1),
#  ('C11B', 'C08J', 1),
#  ('G10K', 'B32B', 1),
#  ('F02K', 'B64G', 1),
#  ('H02J', 'B60R', 3),
#  ('C12N', 'A23G', 1),
#  ('H01M', 'C09D', 1),
#  ('C02F', 'B09C', 1),
#  ('F02C', 'C01B', 1),
#  ('G01C', 'B64G', 1),
#  ('C08F', 'C07F', 2),
#  ('C08K', 'C07D', 3),
#  ('G05D', 'B61L', 2),
#  ('B60C', 'B29C', 1),
#  ('C08L', 'C08G', 12),
#  ('F28F', 'B32B', 1),
#  ('G05D', 'B61C', 1),
#  ('B60R', 'B60N', 5),
#  ('H01L', 'C01B', 1),
#  ('F21V', 'B64D', 1),
#  ('C08F', 'C07C', 2),
#  ('C12P', 'A01N', 1),
#  ('A61M', 'A61B', 1),
#  ('F02B', 'C10L', 1),
#  ('C07K', 'A61K', 44),
#  ('C22C', 'B21C', 1),
#  ('D06F', 'A47L', 2),
#  ('B60K', 'B60H', 1),
#  ('C09D', 'C04B', 3),
#  ('C12P', 'C01B', 1),
#  ('G09F', 'B65C', 2),
#  ('B29D', 'B29B', 1),
#  ('F16B', 'B64C', 1),
#  ('C12M', 'C07D', 1),
#  ('C08K', 'C07B', 1),
#  ('F04D', 'B23C', 1),
#  ('A47L', 'A47K', 1),
#  ('C04B', 'B28B', 1),
#  ('C07J', 'B01J', 1),
#  ('B32B', 'A47L', 1),
#  ('C01G', 'B82Y', 2),
#  ('E21B', 'C04B', 2),
#  ('B23P', 'B22F', 2),
#  ('C22B', 'C10B', 1),
#  ('H04M', 'H04B', 1),
#  ('C08G', 'C03C', 1),
#  ('B29C', 'B28D', 1),
#  ('H01L', 'B24B', 2),
#  ('F01D', 'B64D', 3),
#  ('C09B', 'C07D', 1),
#  ('B44F', 'B32B', 1),
#  ('H01L', 'F21Y', 1),
#  ('B64C', 'B60T', 1),
#  ('C12P', 'A61K', 4),
#  ('B33Y', 'B29L', 1),
#  ('C07J', 'C07F', 1),
#  ('H01B', 'C01G', 1),
#  ('G09G', 'B32B', 1),
#  ('F41H', 'B29C', 1),
#  ('C07K', 'C07F', 1),
#  ('C09D', 'B05D', 2),
#  ('H04W', 'G05D', 1),
#  ('B25H', 'B23B', 1),
#  ('C08K', 'B29D', 1),
#  ('C08G', 'C07F', 1),
#  ('B81B', 'B01J', 1),
#  ('B29C', 'B05D', 1),
#  ('C07F', 'C07B', 4),
#  ('D06F', 'B65D', 1),
#  ('H01F', 'B41M', 1),
#  ('C09J', 'C04B', 2),
#  ('F21V', 'B60Q', 1),
#  ('G08C', 'B60C', 1),
#  ('H01L', 'C09G', 3),
#  ('C08F', 'B29C', 1),
#  ('D06F', 'A47K', 1),
#  ('B67D', 'A47L', 1),
#  ('B33Y', 'B29K', 1),
#  ('G08B', 'B60Q', 2),
#  ('C08K', 'B29K', 3),
#  ('E05F', 'B62D', 1),
#  ('B65G', 'B05C', 1),
#  ('F16K', 'F15B', 1),
#  ('F16D', 'B60K', 1),
#  ('G08B', 'G07C', 1),
#  ('B44C', 'B32B', 1),
#  ('C12Q', 'B01F', 1),
#  ('B65C', 'B60B', 1),
#  ('C08K', 'C08F', 6),
#  ('A61J', 'A61B', 1),
#  ('F21V', 'B60R', 1),
#  ('B29K', 'B23P', 1),
#  ('H01S', 'G01N', 1),
#  ('F02B', 'C23F', 1),
#  ('F01B', 'B60K', 1),
#  ('F16H', 'B66B', 1),
#  ('F16B', 'B25B', 1),
#  ('C22B', 'C10K', 1),
#  ('F16F', 'B60N', 2),
#  ('F41H', 'B29K', 1),
#  ('H01L', 'H01B', 1),
#  ('G02F', 'F21V', 1),
#  ('C12Q', 'C07H', 5),
#  ('D21F', 'D21B', 1),
#  ('G05D', 'B60W', 2),
#  ('C25D', 'C09D', 1),
#  ('H01Q', 'G01V', 1),
#  ('B44C', 'B29C', 2),
#  ('H04L', 'B25J', 1),
#  ('C07F', 'A61M', 1),
#  ('F21V', 'B64F', 1),
#  ('C12P', 'A61L', 1),
#  ('G01P', 'F28D', 1),
#  ('H01F', 'B82Y', 1),
#  ('C07B', 'B01J', 1),
#  ('F04C', 'B27B', 1),
#  ('B44B', 'B41K', 1),
#  ('F01N', 'B60K', 2),
#  ('C40B', 'C12Q', 1),
#  ('G01M', 'B25J', 1),
#  ('H02H', 'H01M', 1),
#  ('F01D', 'B23P', 1),
#  ('C01B', 'B82Y', 1),
#  ('H01Q', 'B60L', 1),
#  ('B25J', 'B05C', 1),
#  ('H02P', 'B65D', 1),
#  ('C07H', 'A61K', 7),
#  ('B32B', 'B29K', 3),
#  ('C11C', 'C10B', 1),
#  ('C09K', 'C01B', 1),
#  ('C08L', 'A61K', 1),
#  ('C12N', 'B09C', 1),
#  ('A61M', 'A61L', 1),
#  ('G01N', 'B25J', 1),
#  ('C09K', 'B82Y', 1),
#  ('B27C', 'B23B', 1),
#  ('G06T', 'G02B', 1),
#  ('B65C', 'B32B', 1),
#  ('H01M', 'H01L', 1),
#  ('F16K', 'B29C', 1),
#  ('B32B', 'B21D', 1),
#  ('C22C', 'B33Y', 1),
#  ('C08K', 'A61K', 1),
#  ('B66D', 'B64D', 1),
#  ('G08B', 'B60R', 1),
#  ('C07B', 'A61K', 2),
#  ('C25D', 'C08G', 1),
#  ('G08G', 'G06K', 1),
#  ('B01J', 'B01F', 2),
#  ('C07C', 'A01N', 1),
#  ('G01N', 'B66C', 1),
#  ('C08L', 'B05D', 3),
#  ('G01N', 'G01B', 1),
#  ('G08G', 'G06Q', 1),
#  ('B60J', 'B25H', 1),
#  ('G09F', 'B32B', 1),
#  ('B26B', 'A61B', 1),
#  ('G02F', 'C08G', 1),
#  ('C10K', 'B29B', 1),
#  ('B63H', 'B60F', 1),
#  ('C12N', 'A01H', 2),
#  ('B65D', 'B64D', 1),
#  ('C08K', 'C04B', 2),
#  ('C08F', 'B60C', 2),
#  ('C01B', 'A01N', 1),
#  ('G06F', 'B65D', 1),
#  ('C01F', 'C01B', 1),
#  ('C09K', 'C08G', 4),
#  ('B67D', 'B05B', 1),
#  ('G06F', 'G05D', 6),
#  ('B29C', 'B28B', 2),
#  ('H04W', 'B60W', 1),
#  ('B41N', 'B41F', 1),
#  ('C09J', 'C09D', 2),
#  ('F04B', 'C12M', 1),
#  ('C23F', 'C09G', 1),
#  ('G09F', 'B60B', 1),
#  ('B64D', 'B25J', 1),
#  ('F21K', 'C09K', 1),
#  ('E04F', 'E04C', 1),
#  ('G05D', 'B25J', 2),
#  ('G09G', 'G06F', 2),
#  ('G07F', 'G06F', 1),
#  ('D04B', 'B65H', 1),
#  ('C08J', 'B29L', 4),
#  ('G09G', 'C08G', 1),
#  ('B60C', 'B29D', 1),
#  ('H02K', 'C09K', 1),
#  ('B66D', 'B63C', 1),
#  ('C10H', 'C01B', 1),
#  ('C08G', 'C08F', 5),
#  ('G01M', 'B23P', 1),
#  ('H02K', 'B60K', 1),
#  ('F16D', 'B60B', 1),
#  ('G05D', 'B60L', 3),
#  ('F21V', 'C08F', 1),
#  ('F16M', 'B42F', 1),
#  ('G05D', 'B60R', 2),
#  ('F25D', 'B29C', 1),
#  ('C08L', 'C07F', 1),
#  ('F02K', 'B64D', 1),
#  ('B66C', 'B63B', 1),
#  ('B60N', 'B29L', 2),
#  ('C07K', 'A23L', 2),
#  ('H05B', 'B41M', 1),
#  ('B42D', 'B41M', 1),
#  ('B60Q', 'B60N', 1),
#  ('G01V', 'B63G', 1),
#  ('H05B', 'B05B', 1),
#  ('G01N', 'C07C', 1),
#  ('B23Q', 'B23C', 2),
#  ('C10M', 'C07C', 1),
#  ('G07C', 'B60W', 1),
#  ('C09D', 'A41D', 1),
#  ('B82Y', 'B01J', 1),
#  ('G08B', 'G01R', 1),
#  ('C23C', 'C22C', 2),
#  ('H01L', 'F21K', 1),
#  ('G05G', 'B25J', 1),
#  ('H04R', 'B81B', 1),
#  ('F41H', 'C08J', 1),
#  ('B42D', 'B05D', 1),
#  ('C12Q', 'C12M', 4),
#  ('B82Y', 'B29L', 1),
#  ('G01L', 'B81B', 1),
#  ('D04H', 'B29B', 1),
#  ('C09D', 'B43L', 1),
#  ('F04C', 'A01G', 1),
#  ('C12P', 'C12M', 4),
#  ('C09D', 'C08K', 12),
#  ('G06T', 'G05B', 2),
#  ('E21F', 'B65G', 1),
#  ('B67D', 'A47K', 2),
#  ('H01L', 'C23F', 1),
#  ('B32B', 'B01D', 1),
#  ('H01M', 'B62J', 1),
#  ('F02N', 'B60Q', 1),
#  ('B63B', 'A47C', 1),
#  ('B29K', 'B28D', 1),
#  ('C11D', 'A47L', 1),
#  ('B29C', 'A61J', 1),
#  ('G08G', 'B60L', 1),
#  ('B60C', 'A61L', 1),
#  ('G01L', 'B66C', 1),
#  ('G05B', 'B25J', 3),
#  ('H01F', 'B05D', 1),
#  ('C12M', 'C07H', 2),
#  ('C09K', 'C04B', 3),
#  ('B65D', 'A61B', 1),
#  ('F16H', 'F16D', 1),
#  ('C08K', 'C08G', 6),
#  ('E02F', 'E02D', 1),
#  ('C09D', 'C07D', 2),
#  ('C10K', 'B01D', 1),
#  ('B63B', 'B60J', 1),
#  ('C08L', 'B65G', 1),
#  ('B60C', 'A61M', 1),
#  ('B62D', 'B25H', 1),
#  ('F16C', 'F15B', 1),
#  ('E21F', 'E21C', 1),
#  ('F01D', 'B23K', 1),
#  ('F16D', 'B66B', 1),
#  ('G01N', 'C07D', 1),
#  ('C07D', 'B01J', 6),
#  ('D06F', 'C11D', 1),
#  ('B60R', 'B60Q', 5),
#  ('C11D', 'A61K', 2),
#  ('F16K', 'F01D', 1),
#  ('B60P', 'B60J', 1),
#  ('C02F', 'B01F', 1),
#  ('G06K', 'B60R', 1),
#  ('D04H', 'B29K', 1),
#  ('F02B', 'B60K', 1),
#  ('F28D', 'C22C', 1),
#  ('C05B', 'C02F', 1),
#  ('C08L', 'B29D', 1),
#  ('A61N', 'A01N', 1),
#  ('F04B', 'B01J', 1),
#  ('F24J', 'B01D', 1),
#  ('B64C', 'B29C', 2),
#  ('H04L', 'B60L', 1),
#  ('B62D', 'B25J', 1),
#  ('A61P', 'A61K', 1),
#  ('B66C', 'B25J', 2),
#  ('D21F', 'B29C', 1),
#  ('F02B', 'C10J', 1),
#  ('G05B', 'B23Q', 1),
#  ('B01F', 'B01D', 1),
#  ('G06F', 'F04C', 1),
#  ('B65G', 'B25J', 1),
#  ('F16C', 'B65H', 1),
#  ('B66C', 'B62D', 1),
#  ('B33Y', 'B22F', 2),
#  ('G09B', 'F16F', 1),
#  ('F16K', 'B23P', 1),
#  ('B64F', 'B60C', 1),
#  ('B64F', 'B23B', 2),
#  ('C12Q', 'C07D', 1),
#  ('B67C', 'B65G', 1),
#  ('B61F', 'B61B', 1),
#  ('B05D', 'B01D', 1),
#  ('B29B', 'B01D', 1),
#  ('B63H', 'B63G', 1),
#  ('B65H', 'B65B', 1),
#  ('C08J', 'B82Y', 1),
#  ('B23K', 'B21D', 1),
#  ('B65G', 'B65B', 1),
#  ('C11D', 'C07C', 1),
#  ('E21B', 'B23P', 1),
#  ('B64D', 'B29L', 1),
#  ('C07H', 'A23L', 1),
#  ('G06K', 'B64D', 2),
#  ('G08G', 'G05D', 2),
#  ('B60N', 'B29C', 2),
#  ('B65G', 'A01C', 1),
#  ('C09K', 'C03B', 1),
#  ('G06K', 'G01S', 1),
#  ('H01R', 'B60R', 1),
#  ('H01M', 'B82Y', 1),
#  ('G05D', 'G05B', 1),
#  ('B29L', 'B23D', 1),
#  ('H02J', 'G01V', 1),
#  ('G05D', 'F15B', 1),
#  ('E02D', 'B66D', 1),
#  ('B64D', 'B29K', 1),
#  ('H01M', 'C01B', 1),
#  ('G05G', 'B60K', 1),
#  ('G02B', 'B60R', 1),
#  ('B29C', 'B29B', 5),
#  ('F02K', 'F01D', 1),
#  ('A61Q', 'A61K', 2),
#  ('H05K', 'B60Q', 1),
#  ('B23Q', 'B23K', 1),
#  ('B66D', 'B66B', 1),
#  ('C08L', 'C08C', 1),
#  ('H05K', 'H02K', 1),
#  ('C08J', 'B32B', 10),
#  ('C12M', 'B01J', 1),
#  ('E02B', 'C02F', 1),
#  ('B60R', 'A44B', 1),
#  ('C09D', 'C01G', 1),
#  ('H02J', 'B60L', 9),
#  ('F16L', 'B60R', 1),
#  ('C10K', 'C10B', 1),
#  ('F17C', 'B32B', 1),
#  ('G01N', 'B01L', 2),
#  ('B65D', 'A61J', 3),
#  ('H05B', 'B41J', 1),
#  ('G01S', 'B60Q', 1),
#  ('H01L', 'B24D', 1),
#  ('H04N', 'B60R', 1),
#  ('F15B', 'B64D', 1),
#  ('B60T', 'B60R', 1),
#  ('B60N', 'A44B', 1),
#  ('B60N', 'B32B', 1),
#  ('C07C', 'A61L', 2),
#  ('F02N', 'B64C', 1),
#  ('C08K', 'C08C', 2),
#  ('C12N', 'C08B', 1),
#  ('F16G', 'B29D', 1),
#  ('E04B', 'C04B', 1),
#  ('C08L', 'C08J', 17),
#  ('B44C', 'A47B', 1),
#  ('B31B', 'B29K', 1),
#  ('B60C', 'B60B', 1),
#  ('F28C', 'F28B', 1),
#  ('F26B', 'B41M', 1),
#  ('C12P', 'C12N', 17),
#  ('C22C', 'B32B', 2),
#  ('F21V', 'C09K', 1),
#  ('F16D', 'B64C', 1),
#  ('G06K', 'B41J', 1),
#  ('C23C', 'C04B', 1),
#  ('G08B', 'G06N', 1),
#  ('C05F', 'C05C', 1),
#  ('F16D', 'B60W', 2),
#  ('D06M', 'C08K', 1),
#  ('D07B', 'B60C', 1),
#  ('D21B', 'B29K', 1),
#  ('C09C', 'C01G', 1),
#  ('C09K', 'B28C', 1),
#  ('C04B', 'B01J', 1),
#  ('H04N', 'H01Q', 1),
#  ('B30B', 'B29C', 1),
#  ('C10G', 'B01D', 1),
#  ('B63C', 'A41D', 1),
#  ('C23F', 'B63H', 1),
#  ('B01L', 'A61M', 1),
#  ('H02H', 'G01R', 1),
#  ('H01L', 'B65G', 1),
#  ('C12N', 'C12M', 4),
#  ('F28F', 'C22C', 1),
#  ('C04B', 'B32B', 3),
#  ('C09K', 'C09G', 2),
#  ('G03F', 'C08F', 1),
#  ('H01L', 'B01J', 2),
#  ('C10B', 'C07C', 1),
#  ('E01B', 'A63G', 1),
#  ('C23C', 'B23H', 1),
#  ('C08K', 'C08J', 11),
#  ('H02J', 'G08B', 1),
#  ('G08B', 'B60W', 2),
#  ('B33Y', 'A61B', 1),
#  ('G06F', 'B60L', 3),
#  ('G01S', 'B60L', 1),
#  ('B64D', 'B60C', 1),
#  ('B65C', 'B44C', 1),
#  ('E02F', 'B66D', 1),
#  ('B29L', 'A61J', 1),
#  ('G06F', 'C08G', 1),
#  ('C09J', 'B05C', 1),
#  ('H01L', 'B29C', 1),
#  ('C08C', 'B32B', 1),
#  ('H04B', 'B60R', 1),
#  ('H01M', 'C10J', 1),
#  ('H02P', 'H02K', 1),
#  ('A23L', 'A23G', 1),
#  ('C22C', 'B23H', 1),
#  ('B65B', 'B01J', 1),
#  ('F16B', 'B42F', 1),
#  ('B01J', 'B01D', 3),
#  ('F15B', 'B23P', 1),
#  ('H04M', 'B60L', 1),
#  ('D04B', 'D01H', 1),
#  ('B62D', 'B60K', 3),
#  ('H01M', 'B60K', 1),
#  ('C08J', 'A43D', 1),
#  ('C01B', 'B01F', 1),
#  ('B23P', 'B21D', 1),
#  ('C10K', 'B09B', 1),
#  ('G05B', 'E05B', 1),
#  ('F16B', 'B60K', 1),
#  ('B64F', 'B29K', 1),
#  ('B64F', 'B29L', 2),
#  ('A61K', 'A01K', 2),
#  ('B23K', 'B23C', 1),
#  ('D21H', 'B32B', 1),
#  ('G06T', 'G05G', 1),
#  ('B62D', 'B60D', 3),
#  ('B32B', 'A61L', 1),
#  ('C08K', 'C01G', 1),
#  ('C08K', 'B29L', 2),
#  ('F02C', 'F02B', 1),
#  ('B65B', 'B01L', 3),
#  ('H01M', 'H01B', 1),
#  ('B64C', 'B29L', 2),
#  ('B29L', 'A61L', 1),
#  ('B26F', 'A61F', 1),
#  ('C08G', 'B29K', 2),
#  ('C09J', 'C08K', 2),
#  ('B29C', 'B01D', 1),
#  ('G01C', 'B60K', 2),
#  ('F15B', 'A62B', 1),
#  ('B61C', 'B60L', 2),
#  ('D01D', 'B01J', 1),
#  ('C08K', 'C07C', 1),
#  ('C09D', 'B01J', 1),
#  ('C05G', 'C05F', 1),
#  ('G11B', 'B82Y', 1),
#  ('F16F', 'B60G', 2),
#  ('B65D', 'A47K', 2),
#  ('C12P', 'C07K', 5),
#  ('D21C', 'C12M', 1),
#  ('B63C', 'B25J', 1),
#  ('H02M', 'B60L', 1),
#  ('F16H', 'F01N', 1),
#  ('C04B', 'B29B', 1),
#  ('G06F', 'B60W', 3),
#  ('F41H', 'B82Y', 1),
#  ('G07C', 'B60C', 1),
#  ('H01F', 'B60L', 1),
#  ('F24J', 'C01D', 1),
#  ('G01H', 'B65H', 1),
#  ('B60Q', 'B60C', 1),
#  ('H04N', 'G05G', 1),
#  ('C09D', 'B60C', 1),
#  ('C08G', 'B29C', 3),
#  ('B01L', 'A61J', 1),
#  ('G08G', 'B60H', 1),
#  ('D04H', 'B29C', 1),
#  ('F15B', 'B25J', 1),
#  ('C03C', 'B65D', 1),
#  ('B60R', 'B60L', 4),
#  ('C08F', 'A61Q', 1),
#  ('B62D', 'B60F', 1),
#  ('B29D', 'B05C', 1),
#  ('C07D', 'C07B', 4),
#  ('H01M', 'G08B', 1),
#  ('B23H', 'B21C', 1),
#  ('C22C', 'B23P', 1),
#  ('B60W', 'B60T', 1),
#  ('D01F', 'B01J', 1),
#  ('B29K', 'A43D', 1),
#  ('B62J', 'B60R', 1),
#  ('B41K', 'B30B', 1),
#  ('H02P', 'H01M', 1),
#  ('B27M', 'B23B', 1),
#  ('B62L', 'B62K', 1),
#  ('C10G', 'B01J', 2),
#  ('C07F', 'C07D', 9),
#  ('C09C', 'C04B', 1),
#  ('C11D', 'A61Q', 2),
#  ('B60K', 'B60G', 1),
#  ('G06F', 'B33Y', 1),
#  ('F16B', 'B29L', 2),
#  ('C03C', 'B32B', 1),
#  ('B41J', 'B26D', 1),
#  ('B28D', 'B23D', 1),
#  ('C12N', 'C07K', 30),
#  ('B67B', 'B01L', 1),
#  ('C12N', 'C11B', 1),
#  ('F04C', 'B65D', 1),
#  ('B67B', 'B65B', 2),
#  ('C08F', 'C07D', 1),
#  ('G01M', 'F04D', 1),
#  ('C12N', 'B81B', 1),
#  ('D06M', 'C04B', 1),
#  ('G02F', 'C08J', 2),
#  ('B25H', 'A47B', 2),
#  ('G01F', 'F28D', 1),
#  ('H05K', 'C08G', 2),
#  ('H01S', 'C09K', 1),
#  ('F16B', 'B29K', 1),
#  ('G09G', 'C08F', 1),
#  ('C08G', 'C07D', 1),
#  ('B65G', 'B65C', 1),
#  ('F02N', 'B60H', 1),
#  ('A61M', 'A61J', 1),
#  ('C09J', 'B32B', 7),
#  ('G09G', 'B60K', 1),
#  ('B29L', 'B29D', 4),
#  ('C08F', 'A61L', 1),
#  ('B41J', 'B41C', 1),
#  ('B66D', 'B25J', 1),
#  ('C08L', 'C04B', 6),
#  ('F25B', 'C09K', 1),
#  ('C12N', 'A61B', 1),
#  ('C03B', 'A61L', 1),
#  ('B26D', 'B25J', 1),
#  ('G02F', 'F21K', 1),
#  ('G08G', 'F02N', 1),
#  ('H02H', 'B60R', 1),
#  ('G01N', 'C12N', 11),
#  ('G06F', 'B25J', 5),
#  ('C08J', 'B29D', 2),
#  ('A61K', 'A23L', 1),
#  ('G01N', 'A61N', 2),
#  ('G06Q', 'B65D', 1),
#  ('C22C', 'C09C', 1),
#  ('B64D', 'B60N', 1),
#  ('C08J', 'C08F', 3),
#  ('E06B', 'B60J', 3),
#  ('B25B', 'B23Q', 1),
#  ('B05B', 'A47K', 1),
#  ('F28C', 'C02F', 2),
#  ('G01C', 'B61C', 1),
#  ('B32B', 'B23K', 5),
#  ('G06F', 'B60R', 2),
#  ('F21S', 'B60Q', 3),
#  ('F28F', 'F28D', 1),
#  ('E21B', 'B28C', 1),
#  ('B29C', 'B23P', 1),
#  ('C07C', 'B01D', 2),
#  ('G01C', 'B60L', 1),
#  ('B32B', 'B29L', 6),
#  ('H05K', 'B60L', 1),
#  ('B60T', 'B60K', 1),
#  ('C08B', 'C07H', 1),
#  ('C10L', 'A61K', 1),
#  ('B60C', 'B05D', 1),
#  ('H01M', 'B60R', 2),
#  ('C08J', 'B60C', 2),
#  ('C08G', 'C07C', 3),
#  ('G01N', 'A61L', 1),
#  ('F24J', 'B63B', 1),
#  ('B60W', 'B60L', 8),
#  ('B65D', 'B31B', 4),
#  ('C07K', 'C07C', 2),
#  ('E04H', 'B60J', 1),
#  ('B61L', 'B61B', 1),
#  ('G01N', 'C09B', 1),
#  ('C01D', 'B01D', 1),
#  ('C02F', 'B08B', 1),
#  ('D21F', 'B29K', 1),
#  ('C23C', 'B32B', 3),
#  ('C07C', 'C01B', 2),
#  ('B81C', 'B81B', 7),
#  ('H01Q', 'G01S', 1),
#  ('G02F', 'C07C', 1),
#  ('F21Y', 'F21S', 1),
#  ('C01G', 'B05D', 1),
#  ('G07C', 'B66B', 1),
#  ('F28D', 'B23K', 1),
#  ('F28D', 'B64D', 1),
#  ('F02K', 'F02C', 1),
#  ('G06F', 'G01C', 2),
#  ('E21B', 'B24D', 1),
#  ('G06Q', 'G05D', 1),
#  ('E21B', 'E02D', 1),
#  ('H01F', 'B42D', 1),
#  ('G01N', 'C07K', 15),
#  ('B66B', 'B65G', 1),
#  ('H01B', 'B60R', 1),
#  ('G01N', 'C07H', 3),
#  ('F28B', 'C02F', 1),
#  ('B23Q', 'B23B', 4),
#  ('C08F', 'B32B', 2),
#  ('B32B', 'A61J', 1),
#  ('B23P', 'B23K', 2),
#  ('B29L', 'B23K', 1),
#  ('C10L', 'C01B', 1),
#  ('C08J', 'B33Y', 1),
#  ('B32B', 'B26F', 1),
#  ('C12Q', 'C12P', 5),
#  ('C08K', 'B05D', 3),
#  ('C07K', 'A01H', 2),
#  ('H01L', 'G02F', 1),
#  ('C12N', 'C08G', 3),
#  ('G08G', 'B60W', 2),
#  ('C04B', 'B29L', 2),
#  ('B41F', 'B30B', 1),
#  ('B60P', 'B60D', 1),
#  ('B65D', 'B25H', 1),
#  ('F28D', 'C23C', 1),
#  ('B64F', 'B23Q', 2),
#  ('F21Y', 'F21K', 1),
#  ('G07C', 'B64F', 1),
#  ('G01C', 'B61L', 2),
#  ('C07C', 'A61K', 6),
#  ('G06K', 'E02F', 1),
#  ('G01N', 'B05D', 1),
#  ('D01F', 'C07D', 1),
#  ('H01S', 'H01L', 1),
#  ('B29C', 'B22F', 1),
#  ('E21B', 'B01F', 1),
#  ('C12M', 'C09B', 1),
#  ('F21Y', 'F21V', 1),
#  ('B25B', 'B23P', 1),
#  ('F16H', 'B60L', 1),
#  ('B67B', 'B29D', 1),
#  ('C03C', 'A61L', 1),
#  ('B32B', 'B29D', 4),
#  ('B65D', 'B29B', 1),
#  ('C04B', 'B23C', 1),
#  ('E21B', 'C08G', 1),
#  ('C04B', 'B29K', 2),
#  ('F02N', 'B60T', 1),
#  ('F16C', 'B41J', 1),
#  ('C09G', 'C01F', 1),
#  ('C12Q', 'B01L', 2),
#  ('B29C', 'A61L', 1),
#  ('B64D', 'B29C', 1),
#  ('G08G', 'B64D', 1),
#  ('B64C', 'B63H', 1),
#  ('C08B', 'A61K', 2),
#  ('G08G', 'B61L', 1),
#  ('G09G', 'C08C', 1),
#  ('G01N', 'B67B', 1),
#  ('H02N', 'B41J', 1),
#  ('B65B', 'B41J', 2),
#  ('F04B', 'B60T', 1),
#  ('B65G', 'B63B', 1),
#  ('H01L', 'C09J', 2),
#  ('H05K', 'C08J', 1),
#  ('B25F', 'B23D', 1),
#  ('B60G', 'A01D', 1),
#  ('H02P', 'B62B', 1),
#  ('F28F', 'C23C', 1),
#  ('F16M', 'F16B', 1),
#  ('H05B', 'B29C', 1),
#  ('C12N', 'A61N', 2),
#  ('D06M', 'C09D', 2),
#  ('C12M', 'C11B', 1),
#  ('B32B', 'B05D', 3),
#  ('F02C', 'C10L', 1),
#  ('B29C', 'B23D', 1),
#  ('E04H', 'B63B', 2),
#  ('C11D', 'C07D', 1),
#  ('C07C', 'C07B', 2),
#  ('B65D', 'B60S', 1),
#  ('B67D', 'B65B', 1),
#  ('G06K', 'G05D', 1),
#  ('H01L', 'C09K', 4),
#  ('G01N', 'A61K', 14),
#  ('H01M', 'C08K', 1),
#  ('C12P', 'A23G', 1),
#  ('C11B', 'A61L', 1),
#  ('C12P', 'C11B', 1),
#  ('F16H', 'B31D', 1),
#  ('C08L', 'B29C', 7),
#  ('F25D', 'B29B', 1),
#  ('E21B', 'B66D', 1),
#  ('C09D', 'B32B', 5),
#  ('B62B', 'B25H', 1),
#  ('C08G', 'C07K', 1),
#  ('C12N', 'A01N', 2),
#  ('E21B', 'C22C', 1),
#  ('G02B', 'C09J', 1),
#  ('G01P', 'B64F', 1),
#  ('C11D', 'C08F', 1),
#  ('H02J', 'G01R', 1),
#  ('H01M', 'C10L', 1),
#  ('H02H', 'B60L', 2),
#  ('A47J', 'A47B', 1),
#  ('C07K', 'C07D', 3),
#  ('C10G', 'B01F', 1),
#  ('F21K', 'C08F', 1),
#  ('C03B', 'B65D', 1),
#  ('B60R', 'B60K', 2),
#  ('A47J', 'A47F', 1),
#  ('C09J', 'B65G', 1),
#  ('C08G', 'A61L', 1),
#  ('C12Q', 'C09B', 2),
#  ('D21F', 'B29D', 1),
#  ('G08G', 'B60R', 1),
#  ('D21F', 'B29B', 1),
#  ('C08J', 'B29C', 9),
#  ('H05K', 'E05B', 1),
#  ('F15B', 'A01G', 1),
#  ('F28F', 'C10B', 1),
#  ('H02P', 'F16H', 1),
#  ('G02B', 'C12Q', 1),
#  ('B65D', 'B05C', 1),
#  ...]

# %% [markdown]
# ### 쌍대노드 간의 링크 강도 예측

# %%
p=nx.Graph()
p.add_weighted_edges_from(data_first)

# %% [markdown]
# ### adamic-adar 알고리즘의 활용

# %%
preds=nx.adamic_adar_index(p)

# %%
result_dic={}
for u,v,p in preds:
    result_dic[(u,v)]=p

# %%
result_dic
# Out:
# {('F16B', 'B02C'): 0,
#  ('G06T', 'B22C'): 0,
#  ('B23K', 'G09G'): 0,
#  ('F16C', 'B65D'): 0,
#  ('C07D', 'G01G'): 0,
#  ('G01V', 'E02B'): 0,
#  ('A47G', 'F01N'): 0,
#  ('B25D', 'C10G'): 0,
#  ('G01G', 'C23F'): 0,
#  ('A43C', 'G06K'): 0,
#  ('E06B', 'F25B'): 0.2969742043733701,
#  ('F04D', 'B32B'): 0.8901140352703812,
#  ('G05B', 'F04B'): 0,
#  ('H01B', 'B66F'): 0,
#  ('G10L', 'B21K'): 0,
#  ('G01D', 'A63J'): 0,
#  ('G21G', 'A24F'): 0.31066746727980593,
#  ('H04R', 'B21K'): 0,
#  ('F16H', 'G02B'): 0,
#  ('B21J', 'H01J'): 0,
#  ('G01F', 'G01G'): 0,
#  ('A43C', 'C09J'): 0,
#  ('G21G', 'B01D'): 0,
#  ('B23K', 'B43K'): 0,
#  ('C21D', 'A23K'): 0,
#  ('A43B', 'B67C'): 0,
#  ('F17D', 'G21F'): 0,
#  ('B22F', 'C21C'): 0,
#  ('H01B', 'F03C'): 0,
#  ('G08G', 'B23D'): 0,
#  ('C12R', 'B03C'): 0,
#  ('B03D', 'F27B'): 0,
#  ('G02B', 'F28D'): 0,
#  ('F16D', 'H04R'): 0.2422988705246811,
#  ('H04L', 'A41F'): 0,
#  ('A22C', 'H01F'): 0,
#  ('B29L', 'A01J'): 0,
#  ('H01M', 'A23K'): 0,
#  ('B07B', 'F21W'): 0,
#  ('B33Y', 'G10L'): 0.33380820069533407,
#  ('G08G', 'F16M'): 0,
#  ('B60K', 'H01R'): 0,
#  ('F17D', 'F21W'): 0,
#  ('B06B', 'A61J'): 0,
#  ('B60K', 'C21D'): 0,
#  ('H02N', 'G06Q'): 0.6298940172736185,
#  ('A21C', 'B26B'): 0.30692767643013485,
#  ('A01C', 'A62B'): 0,
#  ('C23C', 'C11B'): 0,
#  ('C08G', 'G03B'): 0.2422988705246811,
#  ('G08G', 'B66F'): 0,
#  ('H05K', 'C08F'): 0,
#  ('C08L', 'B66F'): 0,
#  ('A45F', 'G01L'): 0,
#  ('B01F', 'G09F'): 0.7006108834755798,
#  ('B01L', 'C07C'): 0.2769378934088574,
#  ('H04N', 'B60L'): 0.28599966750267436,
#  ('G21F', 'B64D'): 0,
#  ('A01M', 'F28D'): 0,
#  ('B26F', 'H01C'): 0,
#  ('C22F', 'B60L'): 0,
#  ('F16D', 'G05D'): 0,
#  ('A47K', 'G01C'): 0,
#  ('F24J', 'B25J'): 0,
#  ('F04B', 'C12M'): 0.26425736993644544,
#  ('A01D', 'A62D'): 0,
#  ('F16H', 'H04W'): 0,
#  ('F02D', 'A61C'): 0,
#  ('F01N', 'B25D'): 0,
#  ('B43M', 'C12C'): 0,
#  ('C09D', 'B33Y'): 0,
#  ('A61D', 'G09B'): 0.2422988705246811,
#  ('B07B', 'A47B'): 0,
#  ('A62B', 'D04H'): 0.28599966750267436,
#  ('F16D', 'B22D'): 0,
#  ('B60P', 'B60N'): 0,
#  ('G02F', 'H01F'): 0,
#  ('G01R', 'H01F'): 0,
#  ('B43K', 'E03F'): 0,
#  ('G21F', 'E03F'): 0,
#  ('F16K', 'B62D'): 0,
#  ('B60B', 'A61K'): 0,
#  ('A01K', 'C08J'): 0.265872585674852,
#  ('B65H', 'G09F'): 0,
#  ('B65C', 'C12M'): 0,
#  ('A24B', 'A47F'): 0,
#  ('A23J', 'H02J'): 0,
#  ('C07F', 'B60P'): 0,
#  ('A24F', 'B64F'): 0,
#  ('C11D', 'C22C'): 0,
#  ('A63B', 'A63H'): 0.9991633903424735,
#  ('G05B', 'B33Y'): 1.551251751657826,
#  ('A41F', 'E04B'): 0,
#  ('H01F', 'B02C'): 0,
#  ('F16L', 'C01D'): 0.2969742043733701,
#  ('B25B', 'E21B'): 0,
#  ('F01M', 'H01R'): 0,
#  ('C07K', 'F27D'): 0,
#  ('H02N', 'F03C'): 0,
#  ('B23B', 'F03C'): 0.40242960438184466,
#  ('F17C', 'A23K'): 0,
#  ('F24F', 'G21K'): 0,
#  ('F16B', 'C08J'): 0.6891324989752919,
#  ('B23K', 'A23P'): 0,
#  ('B41J', 'A45D'): 0,
#  ('A47F', 'C12M'): 0,
#  ('G08B', 'A43B'): 0.28599966750267436,
#  ('C08G', 'G02B'): 0.5081714561995331,
#  ('A63C', 'C01B'): 0,
#  ('A21C', 'H04Q'): 0,
#  ('C08B', 'G09F'): 0,
#  ('G02F', 'H05K'): 0,
#  ('C09D', 'C23C'): 0,
#  ('A01C', 'A61G'): 0,
#  ('H01F', 'B23Q'): 0,
#  ('A01N', 'A61J'): 0.265872585674852,
#  ('H04B', 'B31B'): 0,
#  ('B60S', 'B43M'): 0,
#  ('C12P', 'A01D'): 0,
#  ('B60B', 'A45C'): 0,
#  ('H04B', 'A63G'): 0.28599966750267436,
#  ('B31B', 'G01R'): 0,
#  ('H02N', 'B66F'): 0,
#  ('F02D', 'A61B'): 0.2969742043733701,
#  ('G01D', 'A21B'): 0,
#  ('A23C', 'E02F'): 0,
#  ('B23B', 'A41F'): 0,
#  ('H01B', 'F16M'): 0,
#  ('A01M', 'B31B'): 0,
#  ('F16B', 'F02D'): 0,
#  ('F27D', 'F25B'): 0,
#  ('F02D', 'B33Y'): 0,
#  ('F01B', 'F21V'): 0,
#  ('A47J', 'B66F'): 0,
#  ('B21J', 'A63C'): 0,
#  ('C12P', 'A45C'): 0,
#  ('A63C', 'G03B'): 0,
#  ('A22C', 'B60B'): 0,
#  ('F01D', 'A47G'): 0,
#  ('B60B', 'F28D'): 0,
#  ('F41H', 'B23C'): 0,
#  ('G07F', 'C01C'): 0,
#  ('F17C', 'G06M'): 0,
#  ('B25D', 'A62C'): 0,
#  ('A41D', 'G06K'): 0.5392730748980512,
#  ('G02C', 'B65C'): 0,
#  ('H04N', 'B01F'): 0,
#  ('B82Y', 'G01N'): 0.8712692178367605,
#  ('B26F', 'A23G'): 0,
#  ('A63F', 'A47C'): 0,
#  ('G01C', 'A62D'): 0,
#  ('A61Q', 'E02B'): 0.4170323914242463,
#  ('F27B', 'B65D'): 0,
#  ('A21C', 'C12M'): 0,
#  ('B60K', 'A01N'): 0,
#  ('F21V', 'H04W'): 0,
#  ('F21W', 'A63H'): 0,
#  ('C07D', 'H01F'): 0,
#  ('A01C', 'B05C'): 0,
#  ('B03D', 'F04B'): 0,
#  ('B01L', 'A61F'): 0,
#  ('A47L', 'A21B'): 0.30692767643013485,
#  ('A44C', 'A45D'): 0,
#  ('C12R', 'H05H'): 0,
#  ('A43C', 'B64F'): 0,
#  ('C23C', 'F21W'): 0,
#  ('B27B', 'F26B'): 0,
#  ('G21K', 'B23D'): 0,
#  ('C04B', 'F21V'): 0,
#  ('F16D', 'A01B'): 0,
#  ('A61B', 'C21C'): 0,
#  ('A23D', 'F25B'): 0.3284587387530511,
#  ('F24F', 'A47D'): 0,
#  ('H01B', 'C25D'): 0.4170323914242463,
#  ('A63F', 'E02F'): 0,
#  ('H02N', 'B03B'): 0,
#  ('G01G', 'A01G'): 0,
#  ('F16K', 'H02K'): 0,
#  ('B09B', 'F25D'): 0,
#  ('G02C', 'C12R'): 0,
#  ('G02F', 'B23K'): 0,
#  ('F21Y', 'B21J'): 0,
#  ('C02F', 'G06T'): 0,
#  ('G01S', 'A46B'): 0,
#  ('A24B', 'B41J'): 0,
#  ('B41J', 'F16J'): 0,
#  ('A01N', 'G06Q'): 0,
#  ('A01B', 'B29C'): 0,
#  ('C21C', 'A01J'): 0,
#  ('A23C', 'F02C'): 0,
#  ('G07C', 'G21F'): 0,
#  ('G02C', 'B24B'): 0,
#  ('A43C', 'G02B'): 0,
#  ('F16D', 'C23F'): 0,
#  ('F16H', 'E03F'): 0,
#  ('B60S', 'G21F'): 0,
#  ('B21F', 'A01G'): 0,
#  ('F25D', 'D04B'): 0,
#  ('F27D', 'H01J'): 0,
#  ('A23D', 'B21K'): 0.30692767643013485,
#  ('G08B', 'B03C'): 0,
#  ('A45D', 'H01J'): 0,
#  ('B21D', 'D04H'): 0,
#  ('C12N', 'H02J'): 0,
#  ('G09G', 'B21K'): 0,
#  ('A61D', 'A01F'): 0,
#  ('A24F', 'C08F'): 0.265872585674852,
#  ('A22C', 'C25D'): 0,
#  ('G21K', 'B05D'): 0,
#  ('B05C', 'C08G'): 0,
#  ('G01K', 'G09F'): 0.6636235911445671,
#  ('E02F', 'B23D'): 0,
#  ('G08G', 'A23J'): 0,
#  ('B26F', 'A47C'): 0,
#  ('A23C', 'C12M'): 0,
#  ('F16C', 'C08L'): 0,
#  ('G01D', 'C01D'): 0,
#  ('G09B', 'F04B'): 0,
#  ('C01D', 'A23P'): 0,
#  ('C12R', 'C07C'): 0.265872585674852,
#  ('H04Q', 'B25B'): 0,
#  ('C07C', 'F21W'): 0,
#  ('A01D', 'A63H'): 0,
#  ('A47L', 'A23G'): 0,
#  ('G01D', 'B25D'): 0,
#  ('G07C', 'F01N'): 0,
#  ('E06B', 'A01F'): 0,
#  ('G09G', 'F02C'): 0,
#  ('E06B', 'G03B'): 0,
#  ('A44C', 'B03C'): 0,
#  ('G07F', 'B31B'): 0,
#  ('A43C', 'A61Q'): 0,
#  ('A45D', 'B43K'): 0,
#  ('B25J', 'D04B'): 0,
#  ('B01D', 'B03C'): 0,
#  ('A45F', 'C01B'): 0,
#  ('G21K', 'A23P'): 0,
#  ('H02K', 'F28D'): 0,
#  ('C21D', 'C04B'): 0.35295612386476116,
#  ('C04B', 'F28D'): 0,
#  ('C08F', 'E02F'): 0,
#  ('A24B', 'C21D'): 0,
#  ('A45F', 'B23D'): 0,
#  ('C23C', 'E03F'): 0,
#  ('F01D', 'G01G'): 0,
#  ('C08L', 'B05B'): 0.7320575067222761,
#  ('A47C', 'F17C'): 0,
#  ('B60P', 'G06K'): 0,
#  ('B82Y', 'F28D'): 0,
#  ('F28F', 'C10G'): 0,
#  ('B43M', 'C02F'): 0,
#  ('A47K', 'B64F'): 0,
#  ('H05H', 'A61G'): 0,
#  ('F16C', 'A62C'): 0,
#  ('A47B', 'A43D'): 0,
#  ('B21F', 'C25D'): 0,
#  ('H01B', 'B25D'): 0,
#  ('H04L', 'A24F'): 0.3789231816899512,
#  ('C22C', 'F28D'): 0,
#  ('A01M', 'B22F'): 0,
#  ('A01K', 'B60L'): 0.28599966750267436,
#  ('B60L', 'B25B'): 0,
#  ('A61F', 'A63G'): 0,
#  ('H04L', 'A62B'): 0.2422988705246811,
#  ('C05G', 'A23P'): 0,
#  ('G21G', 'G21K'): 0.31066746727980593,
#  ('G01V', 'A62D'): 0,
#  ('C09J', 'C10G'): 0.2769378934088574,
#  ('G07C', 'B03C'): 0,
#  ('B33Y', 'H01M'): 0,
#  ('C07F', 'B25C'): 0,
#  ('H05B', 'F04D'): 0.5711850463665803,
#  ('B29D', 'F04D'): 0.26425736993644544,
#  ('A63F', 'H04Q'): 3.4639607241709234,
#  ('G02C', 'C23F'): 0.2969742043733701,
#  ('G02C', 'A47B'): 0,
#  ('F01D', 'A44C'): 0,
#  ('A22C', 'E21B'): 0,
#  ('A45F', 'C08L'): 0.6891324989752919,
#  ('C12P', 'G01S'): 0,
#  ('H05K', 'B23C'): 0,
#  ('A01K', 'G10L'): 0,
#  ('G02F', 'B03B'): 0,
#  ('C01G', 'E02F'): 0,
#  ('F04D', 'F25D'): 0,
#  ('H04B', 'B23D'): 0,
#  ('H05B', 'C25B'): 0,
#  ('A23D', 'C08L'): 0,
#  ('F02C', 'G06K'): 0,
#  ('A61B', 'C12R'): 0.7209921989882706,
#  ('B23B', 'A47G'): 0,
#  ('B29L', 'G08G'): 0,
#  ('C07D', 'C09D'): 0.265872585674852,
#  ('B82Y', 'A47C'): 0,
#  ('A61H', 'G02F'): 0,
#  ('B23Q', 'H01J'): 0,
#  ('C07F', 'C08L'): 0.265872585674852,
#  ('H05B', 'G07F'): 0,
#  ('A62D', 'B32B'): 0.2769378934088574,
#  ('G01F', 'E06B'): 0,
#  ('B06B', 'C23C'): 0.45511961331341866,
#  ('B21D', 'C12M'): 0,
#  ('B21F', 'B22D'): 0,
#  ('H01F', 'F25B'): 0,
#  ('G06M', 'C05G'): 0,
#  ('C12P', 'A47C'): 0,
#  ('F04D', 'A24F'): 0.26425736993644544,
#  ('B22F', 'F41H'): 0,
#  ('C22F', 'B65D'): 0.28599966750267436,
#  ('B05C', 'G06T'): 0,
#  ('C07K', 'H02J'): 0.26425736993644544,
#  ('A01K', 'A62C'): 0,
#  ('B03D', 'H01M'): 0,
#  ('E04B', 'F26B'): 0,
#  ('B60S', 'B01D'): 0,
#  ('A47J', 'G02B'): 0,
#  ('A24B', 'B65B'): 0.35295612386476116,
#  ('B29L', 'A22C'): 0,
#  ('B67D', 'B05B'): 0,
#  ('E06B', 'A43D'): 0,
#  ('G10L', 'C10G'): 0,
#  ('A01D', 'B01D'): 0,
#  ('A45F', 'H01J'): 0,
#  ('B65H', 'B03B'): 0,
#  ('A61D', 'B04C'): 0,
#  ('B60R', 'C08B'): 0,
#  ('G07C', 'B29C'): 0,
#  ('B01L', 'H04L'): 0,
#  ('A63C', 'B65C'): 0,
#  ('G05D', 'A61J'): 0,
#  ('F01M', 'E21B'): 0,
#  ('A01B', 'B05B'): 0.40242960438184466,
#  ('F02C', 'A23P'): 0,
#  ('B60R', 'G09B'): 0,
#  ('H04L', 'A47L'): 0.2422988705246811,
#  ('H05B', 'H01B'): 0,
#  ('A61G', 'C10G'): 0,
#  ('A61G', 'B66F'): 0,
#  ('B26D', 'B04B'): 0,
#  ('B60S', 'B25D'): 0,
#  ('B65G', 'A61L'): 0.2835784920513334,
#  ('B43M', 'B60N'): 0,
#  ('G07F', 'A23K'): 0,
#  ('C08L', 'B29K'): 1.9058603088871666,
#  ('F24F', 'A47G'): 0.7699885152890075,
#  ('G09B', 'B65C'): 0,
#  ('E02B', 'B23P'): 0,
#  ('H05B', 'G01G'): 0,
#  ('H01B', 'C21C'): 0,
#  ('A24B', 'A47K'): 0,
#  ('G08G', 'C21C'): 0,
#  ('G05B', 'H05H'): 0.28599966750267436,
#  ('B22F', 'B67D'): 0,
#  ('G01R', 'B22C'): 0,
#  ('B25D', 'C09J'): 0,
#  ('B25H', 'H01F'): 0,
#  ('F41H', 'C01D'): 0,
#  ('F24J', 'B62D'): 0,
#  ('B21C', 'H01F'): 0.40242960438184466,
#  ('B32B', 'B23Q'): 0,
#  ('A61P', 'B29K'): 0.2969742043733701,
#  ('F01N', 'B26F'): 0,
#  ('B25D', 'G06K'): 0,
#  ('A47B', 'F24C'): 0.30692767643013485,
#  ('H05B', 'G01B'): 0.7066500164834344,
#  ('A47B', 'C07C'): 0,
#  ('F21Y', 'A61H'): 0,
#  ('B26F', 'A43C'): 0,
#  ('A47L', 'H04W'): 0.2422988705246811,
#  ('F41H', 'B24B'): 0,
#  ('A21C', 'B60P'): 0,
#  ('A01C', 'A23P'): 0,
#  ('F16C', 'F17D'): 0,
#  ('F17C', 'B62D'): 0,
#  ('G01F', 'F16J'): 0.48089834696298783,
#  ('H01B', 'G09G'): 0,
#  ('H04R', 'G09F'): 0,
#  ('F01B', 'A21B'): 0,
#  ('G21F', 'G09G'): 0,
#  ('A01B', 'H04W'): 0.36067376022224085,
#  ('C12R', 'B05B'): 0,
#  ('F16D', 'C25D'): 0,
#  ('B27B', 'F41H'): 0,
#  ('H05H', 'A62D'): 0.28599966750267436,
#  ('F01N', 'E02B'): 0,
#  ('B60S', 'A43C'): 0,
#  ('C03C', 'C01D'): 0,
#  ('F24F', 'F16B'): 0.36926937306885504,
#  ('B64D', 'A63G'): 0,
#  ('B62D', 'E01H'): 0,
#  ('B65B', 'A45C'): 0,
#  ('G02F', 'F25B'): 0,
#  ('F01D', 'G07F'): 0,
#  ('B64F', 'C07F'): 0,
#  ('A61H', 'A23K'): 0,
#  ('A63C', 'H01J'): 0,
#  ('A61F', 'A01N'): 0.5518722531775264,
#  ('B60B', 'B32B'): 0.5966671347824803,
#  ('A23C', 'H05H'): 0,
#  ('B03B', 'A01J'): 0,
#  ('G01B', 'B03D'): 0,
#  ('F16K', 'A21B'): 0,
#  ('B64D', 'A23G'): 0,
#  ('G01B', 'C04B'): 0,
#  ('B08B', 'C10G'): 0,
#  ('B27B', 'D04B'): 0,
#  ('A47C', 'C01C'): 0,
#  ('A01C', 'G01K'): 0.36067376022224085,
#  ('G03B', 'A23P'): 0,
#  ('A21C', 'B03D'): 0,
#  ('B01L', 'A21B'): 0,
#  ('G01D', 'C12M'): 0.5707576092777322,
#  ('A46B', 'A63H'): 0,
#  ('B60P', 'C11B'): 0,
#  ('A63C', 'A23P'): 0,
#  ('A01F', 'C11B'): 0,
#  ('C08F', 'B25B'): 0,
#  ('C01C', 'B65B'): 0,
#  ('B21F', 'A01D'): 0,
#  ('A61N', 'A62D'): 0.28599966750267436,
#  ('H04Q', 'B65B'): 0.3789231816899512,
#  ('B29L', 'C12N'): 0.28599966750267436,
#  ('C12P', 'F28F'): 0,
#  ('A22C', 'B62D'): 0,
#  ('A24F', 'C23C'): 0.35295612386476116,
#  ('G01D', 'G01B'): 0,
#  ('F24F', 'F24C'): 0,
#  ('H05B', 'B23C'): 0,
#  ('A47C', 'C07F'): 0,
#  ('A22C', 'B03B'): 0,
#  ('A23C', 'H04B'): 0,
#  ('G01S', 'C11B'): 0,
#  ('B21D', 'C08J'): 0,
#  ('B64D', 'A01G'): 0,
#  ('G01N', 'F21V'): 0,
#  ('A63G', 'B65B'): 0,
#  ('F01M', 'C01C'): 0.2969742043733701,
#  ('A61B', 'C09J'): 0.30341307554227914,
#  ('C03C', 'A61C'): 0.265872585674852,
#  ('A01C', 'G09G'): 0,
#  ('A43C', 'B67D'): 0,
#  ('F17C', 'C12C'): 0,
#  ('B64D', 'C08L'): 0,
#  ('C10G', 'C08K'): 0.2769378934088574,
#  ('A61G', 'E01H'): 0.318928988903801,
#  ('A24F', 'C10G'): 0,
#  ('A47J', 'B02C'): 0,
#  ('B60R', 'F16B'): 0,
#  ('C08B', 'C01D'): 0,
#  ('B23B', 'C03C'): 0,
#  ('A47L', 'G09G'): 0.2422988705246811,
#  ('G21G', 'C08K'): 0,
#  ('A21C', 'A01F'): 0,
#  ('B03B', 'B22F'): 0,
#  ('F02D', 'C08F'): 0.2769378934088574,
#  ('F41H', 'C12Q'): 0,
#  ('B27B', 'E04B'): 0,
#  ('B26B', 'G01L'): 0,
#  ('F24F', 'G01M'): 0,
#  ('F02D', 'G02F'): 0,
#  ('B26D', 'B23C'): 0,
#  ('F26B', 'H02J'): 0,
#  ('G21F', 'B32B'): 0.5739120977822274,
#  ('A01K', 'A47K'): 1.004926012495815,
#  ('B66F', 'B29C'): 0,
#  ('B60R', 'B60S'): 0,
#  ('G06T', 'C08F'): 0,
#  ('G01S', 'C12N'): 0,
#  ('H04N', 'G08G'): 0.2769378934088574,
#  ('G09B', 'C01C'): 0,
#  ('B22F', 'H01L'): 0,
#  ('B27B', 'A61N'): 0.2422988705246811,
#  ('F24J', 'A24F'): 0,
#  ('B22D', 'B02C'): 0,
#  ('A47K', 'C21D'): 0,
#  ('B21C', 'G09B'): 0,
#  ('A01G', 'H02J'): 0,
#  ('A61Q', 'B32B'): 0.6053966321619084,
#  ('C23F', 'G09F'): 0,
#  ('B25J', 'C22C'): 0,
#  ('D06F', 'A61M'): 0.6025074809551344,
#  ('A21C', 'B23C'): 0,
#  ('A43C', 'A21D'): 0,
#  ('H04B', 'B65H'): 0,
#  ('C01C', 'B25C'): 0,
#  ('B23K', 'B25C'): 0,
#  ('E06B', 'C25B'): 0,
#  ('D04B', 'A23K'): 0,
#  ('A63F', 'B21D'): 0,
#  ('G01N', 'C10G'): 0.2769378934088574,
#  ('B05C', 'A23P'): 0,
#  ('B60P', 'B23C'): 0,
#  ('F16D', 'A46B'): 0,
#  ('B60S', 'B29K'): 0,
#  ('B04C', 'F02C'): 0,
#  ('G08G', 'F16N'): 0,
#  ('H01B', 'C10G'): 0.2769378934088574,
#  ('G07C', 'B29K'): 0,
#  ('C07C', 'C25B'): 0.2769378934088574,
#  ('C04B', 'G01R'): 0.31066746727980593,
#  ('H02N', 'G05D'): 0.6004533465575299,
#  ('A61J', 'B22D'): 0,
#  ('H04Q', 'F27B'): 0,
#  ('B33Y', 'C21C'): 0,
#  ('C07F', 'B22C'): 0,
#  ('C11D', 'F01D'): 0,
#  ('F01B', 'A61C'): 0,
#  ('C08J', 'A23J'): 0.265872585674852,
#  ('A24B', 'H05K'): 0,
#  ('B23B', 'F16J'): 0.40242960438184466,
#  ('H04R', 'A47F'): 0,
#  ('F03C', 'G06Q'): 0,
#  ('D06F', 'E02F'): 0,
#  ('G01G', 'C12Q'): 0,
#  ('G21K', 'B60L'): 0,
#  ('B21D', 'B64D'): 0,
#  ('H01B', 'F04B'): 0,
#  ('A62B', 'H02K'): 0,
#  ('D04H', 'B65B'): 0,
#  ('A23J', 'H01J'): 0,
#  ('A61M', 'A63G'): 0,
#  ('B22D', 'A01J'): 0,
#  ('B41J', 'F27D'): 0,
#  ('G07C', 'A01D'): 0,
#  ('B64D', 'C23C'): 0,
#  ('F27D', 'C12M'): 0,
#  ('A01K', 'D04B'): 0,
#  ('G01N', 'A61G'): 1.136450257734745,
#  ('A21C', 'B09B'): 0,
#  ('G08B', 'C21D'): 0,
#  ('G21G', 'A61F'): 0.31066746727980593,
#  ('G02C', 'C09D'): 0,
#  ('A01M', 'A01H'): 0,
#  ('B03D', 'B24B'): 0,
#  ('A61M', 'E02B'): 0,
#  ('C03C', 'A01G'): 0,
#  ('A62B', 'A22C'): 0,
#  ('H01B', 'H02N'): 0.36926937306885504,
#  ('A61N', 'C11B'): 0,
#  ('C02F', 'B04B'): 0.2969742043733701,
#  ('B25D', 'F27D'): 0,
#  ('C07F', 'B03B'): 0,
#  ('C07D', 'C23F'): 0,
#  ('D06F', 'B05D'): 0,
#  ('F16B', 'H01M'): 0.6814148626178123,
#  ('G21F', 'G06M'): 0,
#  ('C07H', 'C23F'): 0,
#  ('G21K', 'B60N'): 0.2422988705246811,
#  ('F25D', 'H04W'): 0.2769378934088574,
#  ('B60R', 'B26D'): 0,
#  ('G06Q', 'B67D'): 0,
#  ('F01M', 'A01D'): 0,
#  ('B26D', 'B65G'): 0.30692767643013485,
#  ('B64D', 'C12Q'): 0,
#  ('A41F', 'B64D'): 0,
#  ('F16C', 'C03C'): 0,
#  ('A63J', 'A01F'): 0,
#  ('A61H', 'B04B'): 0.26425736993644544,
#  ('F03C', 'A47F'): 0,
#  ('A63C', 'H01R'): 0,
#  ('B60S', 'G09B'): 0,
#  ('G02C', 'F04B'): 0,
#  ('A42B', 'F26B'): 0.43429448190325176,
#  ('A61Q', 'A63H'): 0,
#  ('C08J', 'E06B'): 0,
#  ('H04N', 'A45D'): 0,
#  ('A47K', 'B03B'): 0,
#  ('B03B', 'B60N'): 0,
#  ('C07D', 'F21V'): 0,
#  ('B60R', 'A23J'): 0,
#  ('A01H', 'B65D'): 0.3284587387530511,
#  ('G01B', 'B65H'): 0,
#  ('B64F', 'F17C'): 0,
#  ('C09D', 'C08G'): 0.5943313244279032,
#  ('B25D', 'C12C'): 0,
#  ('C01G', 'C11B'): 0,
#  ('F16K', 'F01N'): 0,
#  ('C04B', 'C09J'): 0,
#  ('A43D', 'B23Q'): 0,
#  ('G01D', 'E06B'): 0,
#  ('C07H', 'G02B'): 0.265872585674852,
#  ('A23C', 'B60P'): 0,
#  ('H04Q', 'G01V'): 0.2422988705246811,
#  ('G21G', 'B65G'): 0,
#  ('C12C', 'B23C'): 0,
#  ('F01N', 'B33Y'): 0,
#  ('B82Y', 'B23Q'): 0,
#  ('F24F', 'G02F'): 0,
#  ('G05B', 'C09J'): 0,
#  ('D04H', 'C12M'): 0,
#  ('F01N', 'B22D'): 0,
#  ('A47J', 'H04W'): 0,
#  ('B25D', 'A23L'): 0,
#  ('C22C', 'E02B'): 0,
#  ('G07F', 'B25B'): 0,
#  ('B29D', 'A01J'): 0,
#  ('F16J', 'G09F'): 0,
#  ('F16L', 'A21B'): 0.30692767643013485,
#  ('F16K', 'B25B'): 0,
#  ('A61P', 'H01C'): 0,
#  ('C01D', 'E21B'): 0,
#  ('A21B', 'C12M'): 0,
#  ('F16H', 'F02D'): 0,
#  ('H04R', 'B23D'): 0,
#  ('F16K', 'E21B'): 0,
#  ('C25B', 'B22C'): 0,
#  ('A61P', 'B05B'): 0.2969742043733701,
#  ('A01K', 'F25B'): 0,
#  ('A23J', 'A61C'): 0.265872585674852,
#  ('H04L', 'A01N'): 0,
#  ('A46B', 'F28D'): 0,
#  ('B25J', 'B01F'): 0.45511961331341866,
#  ('F16D', 'E04B'): 0,
#  ('B22F', 'C11B'): 0,
#  ('C09D', 'C03C'): 0.265872585674852,
#  ('A61J', 'B65C'): 0.35295612386476116,
#  ('A63G', 'E03B'): 0,
#  ('G06F', 'A45F'): 0.30692767643013485,
#  ('A43B', 'B60N'): 0,
#  ('C07K', 'C21C'): 0,
#  ('F16H', 'C12N'): 0,
#  ('F21W', 'C12Q'): 0,
#  ('A63C', 'B22F'): 0,
#  ('G06F', 'B01F'): 0,
#  ('G08B', 'A61H'): 0.9568747337575183,
#  ('B29D', 'F01M'): 0,
#  ('B26D', 'C22F'): 0,
#  ('A61B', 'B05C'): 1.5859921702965765,
#  ('G09G', 'F24C'): 0,
#  ('C04B', 'H02K'): 0,
#  ('A61D', 'C23C'): 0,
#  ('F17C', 'B21K'): 0.2969742043733701,
#  ('A61G', 'B02C'): 0,
#  ('H01B', 'B60K'): 0,
#  ('A61H', 'F03C'): 0,
#  ('A01K', 'A23J'): 0.7797709280446028,
#  ('B27B', 'F27D'): 0,
#  ('F25D', 'G01C'): 0,
#  ('F24F', 'B21J'): 0,
#  ('G01D', 'B67C'): 0,
#  ('A01K', 'A47L'): 0.7386981053647521,
#  ('G02B', 'F02C'): 0,
#  ('F16C', 'A01J'): 0,
#  ('G21K', 'C12N'): 0,
#  ('A44C', 'C09J'): 0,
#  ('A62B', 'A63J'): 0.45511961331341866,
#  ('A43C', 'B03B'): 0,
#  ('B01L', 'H04N'): 0.4170323914242463,
#  ('B26B', 'F17C'): 0,
#  ('F02D', 'B02C'): 0,
#  ('G08B', 'B67D'): 0,
#  ('A62B', 'A43B'): 0,
#  ('C23F', 'B23Q'): 0,
#  ('G01L', 'A47F'): 0,
#  ('G21F', 'C08L'): 0.2769378934088574,
#  ('A01G', 'E03F'): 0,
#  ('F16C', 'B05C'): 0.36067376022224085,
#  ('G01F', 'A01H'): 0,
#  ('F21Y', 'A61G'): 0.6258566653339359,
#  ('G01M', 'C23F'): 0,
#  ('B26B', 'C12R'): 0,
#  ('B09B', 'A47D'): 0,
#  ('B60T', 'B23C'): 0,
#  ('G01F', 'A62D'): 0,
#  ('G06Q', 'C01C'): 0,
#  ('F21Y', 'E02B'): 0,
#  ('B43M', 'C01C'): 0,
#  ('B05C', 'B24B'): 0,
#  ('G01C', 'C08K'): 0,
#  ('F24F', 'F28F'): 0,
#  ('F17D', 'E01H'): 0,
#  ('E02F', 'H02K'): 0,
#  ('B06B', 'B65H'): 0,
#  ('E02F', 'G02B'): 0,
#  ('A61N', 'E03B'): 0,
#  ('C23C', 'C25D'): 0,
#  ('F16D', 'C09J'): 0,
#  ('G09B', 'C22C'): 0,
#  ('G05B', 'B04B'): 0,
#  ('B65G', 'B60N'): 0,
#  ('F16H', 'F17C'): 0,
#  ('F21W', 'B65B'): 0,
#  ('A01G', 'A63G'): 0,
#  ('B31B', 'B05B'): 0,
#  ('A62C', 'C10G'): 0,
#  ('G06F', 'F24C'): 0,
#  ('F16K', 'C07H'): 0,
#  ('A21C', 'A47F'): 0.30692767643013485,
#  ('G02C', 'B60K'): 0.2422988705246811,
#  ('G02F', 'B33Y'): 0,
#  ('B21D', 'F25D'): 0,
#  ('F25D', 'A01F'): 0,
#  ('F01D', 'A61M'): 0.2969742043733701,
#  ('B60R', 'A61N'): 0,
#  ('D04D', 'B21J'): 0,
#  ('A62C', 'A01F'): 0,
#  ('H01R', 'B01F'): 0.30692767643013485,
#  ('B32B', 'A01G'): 0.318928988903801,
#  ('G05D', 'A47J'): 0,
#  ('F01M', 'E03F'): 0,
#  ('G08B', 'F41H'): 0.45511961331341866,
#  ('G01K', 'H04W'): 0.9136400980267279,
#  ('B43K', 'A21D'): 0,
#  ('F04D', 'B25J'): 0.26425736993644544,
#  ('H01M', 'B04B'): 0,
#  ('B21F', 'C08F'): 0.28599966750267436,
#  ('A61P', 'C21C'): 0,
#  ('H01R', 'B24B'): 0,
#  ('G01F', 'G03B'): 0.2422988705246811,
#  ('A61G', 'C11B'): 0,
#  ('G06T', 'A61K'): 1.3365446898709568,
#  ('C12P', 'F27B'): 0,
#  ('F01M', 'G01M'): 0,
#  ('B27B', 'B33Y'): 0.2422988705246811,
#  ('B43M', 'G08C'): 0,
#  ('B26F', 'B31B'): 0,
#  ('H04Q', 'B23K'): 0.7578463633799024,
#  ('G06F', 'C21C'): 0,
#  ('G01F', 'B05B'): 1.1364093746741104,
#  ('A44C', 'C01G'): 0,
#  ('A47K', 'C10G'): 0,
#  ('H05H', 'A23K'): 0,
#  ('C11D', 'F01M'): 0,
#  ('C12R', 'F41H'): 0,
#  ('C11D', 'A61L'): 1.3768752619322022,
#  ('C04B', 'G08C'): 0,
#  ('A47D', 'F16D'): 0,
#  ('H05H', 'C01D'): 0,
#  ('A44C', 'G01R'): 0,
#  ('B43K', 'C08K'): 0,
#  ('B21J', 'C02F'): 0,
#  ('B62D', 'F26B'): 0,
#  ('A21C', 'B22D'): 0,
#  ('B26F', 'C01C'): 0,
#  ('G10L', 'A23K'): 0,
#  ('A61K', 'H01F'): 0,
#  ('C05G', 'A23D'): 0,
#  ('A47C', 'G08G'): 0.31066746727980593,
#  ('C09J', 'B23Q'): 0,
#  ('A62B', 'C22C'): 0.28599966750267436,
#  ('B29L', 'G06M'): 0.26425736993644544,
#  ('B05D', 'H05H'): 0,
#  ('B29L', 'A63H'): 0,
#  ('B05C', 'B65G'): 0,
#  ('A01C', 'B25J'): 0,
#  ('G07C', 'C25B'): 0,
#  ('B60B', 'F26B'): 0,
#  ('H01C', 'A61C'): 0,
#  ('C23C', 'G10L'): 0,
#  ('B64F', 'C12R'): 0,
#  ('B64F', 'F27D'): 0,
#  ('H04B', 'A61L'): 0.6593312619489274,
#  ('G09F', 'A47F'): 0.7006108834755798,
#  ('C07C', 'C10G'): 0.2769378934088574,
#  ('C12P', 'H05K'): 0,
#  ('A61F', 'C11B'): 0,
#  ('A01D', 'C01C'): 0,
#  ('B22D', 'A63H'): 0,
#  ('A01M', 'G08C'): 0,
#  ('C01B', 'B67D'): 0,
#  ('A62C', 'F25B'): 0,
#  ('A01M', 'A61L'): 0.4170323914242463,
#  ('G01N', 'A45C'): 0.2769378934088574,
#  ('B03D', 'B33Y'): 0,
#  ('B23B', 'G01B'): 0.40242960438184466,
#  ('F25D', 'C21C'): 0,
#  ('B60S', 'F04D'): 0,
#  ('B07B', 'B60N'): 0,
#  ('B33Y', 'G08G'): 0.2769378934088574,
#  ('F27B', 'C10G'): 0,
#  ('H05K', 'E02F'): 0,
#  ('B66F', 'C11B'): 0,
#  ('H02N', 'G10L'): 0.35295612386476116,
#  ('C05G', 'B60P'): 0,
#  ('D06F', 'C05G'): 0,
#  ('E04B', 'C07F'): 0,
#  ('A63F', 'B67D'): 0,
#  ('A61H', 'H02N'): 0.2769378934088574,
#  ('G01N', 'B23Q'): 0,
#  ('F25D', 'B24B'): 0,
#  ('G21K', 'G06T'): 0.552966337804487,
#  ('C12P', 'B21C'): 0,
#  ('E04B', 'H04Q'): 0,
#  ('G05D', 'C12C'): 0,
#  ('B60S', 'B43K'): 0,
#  ('G02C', 'D04B'): 0.2969742043733701,
#  ('A24B', 'F01N'): 0,
#  ('B05C', 'A63H'): 0,
#  ('B26F', 'A23D'): 0,
#  ('B04C', 'C02F'): 0,
#  ('F16M', 'B23Q'): 0,
#  ('B05C', 'C01C'): 0.2769378934088574,
#  ('A01C', 'A46B'): 0,
#  ('A61N', 'C21C'): 0,
#  ('F16H', 'G01F'): 0.26425736993644544,
#  ('A01C', 'C12N'): 0,
#  ('A01K', 'G02F'): 0,
#  ('B09B', 'C01G'): 0.2769378934088574,
#  ('B25C', 'G06K'): 0.2422988705246811,
#  ('A01H', 'A21B'): 0,
#  ('H01B', 'A21D'): 0,
#  ('G06F', 'A47K'): 0.4170323914242463,
#  ('F16H', 'C08F'): 0,
#  ('A61G', 'C12N'): 0,
#  ('A61M', 'G02B'): 1.5501076097559607,
#  ('E06B', 'A45F'): 0.5581106265512472,
#  ('A61N', 'B66F'): 0,
#  ('C05G', 'C08K'): 0,
#  ('H04L', 'H01C'): 0,
#  ('C21D', 'F02C'): 0,
#  ('B07B', 'H04N'): 0.7213475204444817,
#  ('G06M', 'B66F'): 0,
#  ('A41F', 'F28D'): 0,
#  ('A01K', 'B23K'): 0,
#  ('B29D', 'B22C'): 0,
#  ('G01V', 'B60P'): 0,
#  ('B60L', 'F04B'): 0,
#  ('H04L', 'A23K'): 0,
#  ('A63C', 'A01G'): 0,
#  ('B23B', 'H04W'): 0,
#  ('F28D', 'H01L'): 0,
#  ('H01R', 'A62D'): 0,
#  ('H05K', 'F02C'): 0,
#  ('B41J', 'C10G'): 0,
#  ('A43D', 'B03C'): 0,
#  ('B29C', 'C10G'): 0.2769378934088574,
#  ('A23L', 'E03B'): 0,
#  ('A61Q', 'C04B'): 0,
#  ('A01B', 'B65B'): 0,
#  ('B06B', 'H01C'): 0,
#  ('A45D', 'C10G'): 0,
#  ('C01C', 'F27B'): 0,
#  ('B29D', 'G21F'): 0,
#  ('G02F', 'C07C'): 0,
#  ('C12P', 'C12M'): 0.265872585674852,
#  ('B26F', 'A01B'): 0,
#  ('A47B', 'B26D'): 0.30692767643013485,
#  ('H01B', 'B60L'): 0,
#  ('B32B', 'A47F'): 1.216362833815404,
#  ('A61H', 'E02B'): 0,
#  ('A47G', 'B21F'): 0,
#  ('B82Y', 'G08G'): 0,
#  ('F16B', 'A43D'): 0,
#  ('B21D', 'C25D'): 0,
#  ('A01N', 'C07H'): 0.265872585674852,
#  ('A41F', 'A63J'): 0,
#  ('F17D', 'G02B'): 0,
#  ('F01B', 'D04B'): 0,
#  ('C01D', 'B60N'): 0,
#  ('B05C', 'C25B'): 0.2769378934088574,
#  ('B03B', 'B25B'): 0,
#  ('B41J', 'C21D'): 0,
#  ('B60T', 'B60B'): 0.31066746727980593,
#  ('A41F', 'G01V'): 0,
#  ('C04B', 'E21B'): 0,
#  ('C12C', 'F41H'): 0,
#  ('A61M', 'H01L'): 1.2439745600957037,
#  ('H04R', 'B23K'): 0,
#  ('C01B', 'A01J'): 0,
#  ('H02K', 'G02B'): 0,
#  ('G07F', 'F02C'): 0,
#  ('B21C', 'A43D'): 0,
#  ('A01B', 'B22C'): 0,
#  ('B65B', 'B23P'): 0,
#  ('A24B', 'G08C'): 0,
#  ('B22F', 'B60P'): 0,
#  ('C07K', 'H01M'): 0,
#  ('H01B', 'B65B'): 0,
#  ('B21F', 'A21D'): 0,
#  ('A47C', 'C12N'): 0,
#  ('A63F', 'B25J'): 0,
#  ('A22C', 'A21B'): 0,
#  ('F26B', 'B65C'): 0,
#  ('B23K', 'A61J'): 0,
#  ('D06F', 'A63J'): 0,
#  ('A61N', 'A43D'): 0.48089834696298783,
#  ('F25B', 'F02C'): 0.2969742043733701,
#  ('G06F', 'G01V'): 0.2422988705246811,
#  ('A63C', 'F16L'): 0,
#  ('C07D', 'F02D'): 0,
#  ('F01N', 'G07F'): 0,
#  ('A43B', 'C02F'): 0,
#  ('G02C', 'B60L'): 0,
#  ('F16K', 'C09D'): 0,
#  ('G21F', 'F16D'): 0,
#  ('D04B', 'B03C'): 0,
#  ('G09B', 'D04B'): 0,
#  ('B29L', 'F16L'): 0.5676704454787246,
#  ('B21C', 'B62D'): 0,
#  ('A21C', 'D06F'): 0,
#  ('A44C', 'B60B'): 0,
#  ('A61B', 'B23K'): 1.6514877025357528,
#  ('F21W', 'E21B'): 0,
#  ('B26F', 'G01S'): 0,
#  ('A61F', 'G21K'): 0.552966337804487,
#  ('C12C', 'F16N'): 0,
#  ('B05C', 'H01M'): 0.2769378934088574,
#  ('B41J', 'B25H'): 0.3898712452512801,
#  ('G21G', 'B60L'): 0,
#  ('B22F', 'A23K'): 0,
#  ('B43M', 'B60B'): 0,
#  ('B07B', 'B82Y'): 0,
#  ('A61N', 'B23D'): 0,
#  ('F16L', 'C10G'): 0,
#  ('A61L', 'F21W'): 0,
#  ('B65G', 'A41D'): 0,
#  ('F24J', 'F01M'): 0,
#  ('H05K', 'H04Q'): 0,
#  ('F17D', 'A61L'): 0.6812897613606917,
#  ('C09J', 'A23D'): 0,
#  ('B33Y', 'E02B'): 0,
#  ('F16C', 'B32B'): 0.40242960438184466,
#  ('B65B', 'B23D'): 0,
#  ('B27B', 'C07F'): 0,
#  ('B32B', 'E01H'): 0.318928988903801,
#  ('F01D', 'A01H'): 0,
#  ('F41H', 'F26B'): 0,
#  ('A61P', 'F27B'): 0,
#  ('A01F', 'B23Q'): 0,
#  ('G21G', 'G09F'): 0,
#  ('C03C', 'B60N'): 0,
#  ('B07B', 'A01J'): 0,
#  ('B29D', 'H01M'): 0.3284587387530511,
#  ('G02F', 'A21B'): 0,
#  ('A61F', 'C25D'): 0,
#  ('F17C', 'A23D'): 0,
#  ('H02K', 'G08C'): 0,
#  ('F25D', 'B32B'): 0.30692767643013485,
#  ('C11D', 'G21F'): 0.2769378934088574,
#  ('C07H', 'A61P'): 0.265872585674852,
#  ('G01C', 'F16M'): 0.31066746727980593,
#  ('B43M', 'A01H'): 0,
#  ('A42B', 'D04D'): 0,
#  ('B01L', 'B65H'): 0,
#  ('F17D', 'G01L'): 0.9510216944965406,
#  ('A41F', 'C22C'): 0,
#  ('B67C', 'C12M'): 0,
#  ('H05K', 'A23K'): 0,
#  ('H05B', 'A21D'): 0.30692767643013485,
#  ('F16L', 'H01F'): 0.30692767643013485,
#  ('G21K', 'H01R'): 0,
#  ('A24B', 'B23K'): 0.35295612386476116,
#  ('F21Y', 'E21B'): 0,
#  ('F21Y', 'B01J'): 0,
#  ('A63J', 'B02C'): 0,
#  ('A62B', 'H04R'): 0.2422988705246811,
#  ('A01N', 'A61N'): 0.5518722531775264,
#  ('A61P', 'H01M'): 0,
#  ('D04D', 'B26D'): 0,
#  ('F17D', 'A61P'): 0,
#  ('G01N', 'B67C'): 0,
#  ('F16L', 'C22F'): 0,
#  ('H05H', 'B25B'): 0,
#  ('B60B', 'A23P'): 0,
#  ('H04N', 'B31B'): 0,
#  ('H01M', 'C12N'): 0,
#  ('F17D', 'B65C'): 0,
#  ('H04L', 'F21W'): 0,
#  ('A22C', 'C01D'): 0,
#  ('A01N', 'H01R'): 0,
#  ('G01S', 'C23F'): 0,
#  ('C01B', 'B65B'): 0,
#  ('B01J', 'D04B'): 0,
#  ('G01R', 'B05B'): 0,
#  ('F16L', 'A61G'): 0.5676704454787246,
#  ('F21V', 'A23D'): 0,
#  ('A41F', 'A21B'): 0,
#  ('G01R', 'C23F'): 0,
#  ('B03D', 'A01J'): 0,
#  ('B65C', 'H01L'): 0.35295612386476116,
#  ('A01G', 'B02C'): 0,
#  ('C12C', 'G06Q'): 0,
#  ('A47G', 'A44C'): 0.3898712452512801,
#  ('F24C', 'H01L'): 0,
#  ('H04L', 'H01F'): 0,
#  ('A63B', 'F26B'): 0,
#  ('A47L', 'B22C'): 0,
#  ('B21F', 'H01J'): 0.28599966750267436,
#  ('B05C', 'A23K'): 0,
#  ('A62D', 'B67D'): 0,
#  ('B60L', 'A01F'): 0,
#  ('A44C', 'B33Y'): 0,
#  ('G21G', 'A61B'): 0.31066746727980593,
#  ('B27B', 'H04N'): 0.2422988705246811,
#  ('G01R', 'A21D'): 0,
#  ('D06F', 'B25H'): 0,
#  ('F04D', 'A63B'): 0,
#  ('C09J', 'H05H'): 0,
#  ('F21Y', 'C12M'): 0,
#  ('B60K', 'C11B'): 0,
#  ('G07F', 'G08G'): 0,
#  ('G05B', 'F27D'): 0,
#  ('B65H', 'C01B'): 0,
#  ('G07C', 'A62C'): 0,
#  ('G06M', 'H01J'): 0,
#  ('A47K', 'A61B'): 0.9554636048198955,
#  ('B21F', 'A47C'): 0,
#  ('B05D', 'B29C'): 0.8381694677186728,
#  ('H04L', 'F04D'): 0,
#  ('B60K', 'A62C'): 0,
#  ...}

# %% [markdown]
# ### 성능 검증

# %%
compare_dic={}

# %%
for row in data_second:
    if(tmp in result_dic ): ##예측 결과와 데이터2링크 겹치는 거 비교
        if(result_dic[tmp]!=0):
            compare_dic[tmp]=1
        else:
            compare_dic[tmp]=0
    else:
        compare_dic[tmp]=0

# %%
compare_dic
# Out:
# {('A61N', 'A01K'): 1,
#  ('A61N', 'A01N'): 1,
#  ('B01L', 'A61B'): 1,
#  ('B22F', 'B21D'): 1,
#  ('B23P', 'B23C'): 1,
#  ('B23P', 'B23K'): 1,
#  ('B23Q', 'A47B'): 0,
#  ('B23Q', 'B23C'): 1,
#  ('B23Q', 'B23K'): 1,
#  ('B25B', 'B23B'): 0,
#  ('B25B', 'B23Q'): 0,
#  ('B25H', 'A47B'): 0,
#  ('B25J', 'A62B'): 1,
#  ('B26B', 'A61B'): 0,
#  ('B26D', 'B25J'): 0,
#  ('B27B', 'A01G'): 0,
#  ('B29C', 'B05D'): 1,
#  ('B29C', 'B23K'): 1,
#  ('B29C', 'B23P'): 0,
#  ('B29K', 'B05D'): 1,
#  ('B29K', 'B23P'): 0,
#  ('B29K', 'B29B'): 0,
#  ('B29K', 'B29D'): 1,
#  ('B29L', 'A43D'): 0,
#  ('B29L', 'A61J'): 1,
#  ('B29L', 'B05D'): 1,
#  ('B29L', 'B23K'): 1,
#  ('B29L', 'B23P'): 0,
#  ('B32B', 'A61J'): 1,
#  ('B32B', 'A61L'): 1,
#  ('B32B', 'B05D'): 1,
#  ('B32B', 'B22F'): 1,
#  ('B32B', 'B23K'): 1,
#  ('B32B', 'B26F'): 0,
#  ('B32B', 'B29K'): 1,
#  ('B60K', 'A01D'): 0,
#  ('B60N', 'A47B'): 0,
#  ('B60N', 'B29D'): 1,
#  ('B60R', 'A47B'): 0,
#  ('B60S', 'B60P'): 0,
#  ('B62D', 'B25H'): 0,
#  ('B62D', 'B60R'): 0,
#  ('B64D', 'B33Y'): 1,
#  ('B64D', 'B60N'): 1,
#  ('B64D', 'B60R'): 1,
#  ('B64F', 'B23B'): 0,
#  ('B64F', 'B33Y'): 1,
#  ('B65B', 'A61B'): 1,
#  ('B65B', 'A61J'): 1,
#  ('B65B', 'A61L'): 1,
#  ('B65B', 'A61M'): 1,
#  ('B65B', 'B01J'): 1,
#  ('B65B', 'B01L'): 1,
#  ('B65B', 'B29C'): 1,
#  ('B65B', 'B29D'): 0,
#  ('B65B', 'B29L'): 1,
#  ('B65B', 'B31B'): 1,
#  ('B65B', 'B41J'): 1,
#  ('B65C', 'B32B'): 1,
#  ('B65C', 'B41J'): 0,
#  ('B65C', 'B60B'): 0,
#  ('B65D', 'A45F'): 1,
#  ('B65D', 'B01L'): 1,
#  ('B65D', 'B05B'): 1,
#  ('B65D', 'B23P'): 0,
#  ('B65D', 'B25H'): 0,
#  ('B65D', 'B29C'): 1,
#  ('B65D', 'B29K'): 1,
#  ('B65D', 'B60R'): 0,
#  ('B65D', 'B64D'): 1,
#  ('B65G', 'B05D'): 0,
#  ('B67D', 'A47K'): 1,
#  ('B67D', 'B05B'): 0,
#  ('C01B', 'A01N'): 1,
#  ('C01B', 'B01F'): 0,
#  ('C01G', 'B05D'): 1,
#  ('C01G', 'B82Y'): 1,
#  ('C02F', 'B01F'): 0,
#  ('C02F', 'B04C'): 0,
#  ('C02F', 'B05D'): 1,
#  ('C02F', 'C01D'): 1,
#  ('C03C', 'A61L'): 1,
#  ('C07D', 'A61Q'): 1,
#  ('C07D', 'B01J'): 1,
#  ('C07D', 'C04B'): 0,
#  ('C07F', 'C07C'): 1,
#  ('C07H', 'A23G'): 1,
#  ('C07H', 'C07D'): 1,
#  ('C07K', 'A01H'): 1,
#  ('C07K', 'A01N'): 1,
#  ('C07K', 'A23G'): 0,
#  ('C07K', 'A61N'): 1,
#  ('C07K', 'A61P'): 1,
#  ('C07K', 'C07C'): 1,
#  ('C07K', 'C07D'): 1,
#  ('C07K', 'C07F'): 1,
#  ('C08F', 'C07C'): 1,
#  ('C08G', 'A61L'): 1,
#  ('C08G', 'C04B'): 0,
#  ('C08G', 'C07C'): 1,
#  ('C08G', 'C08F'): 1,
#  ('C08J', 'B33Y'): 1,
#  ('C08J', 'C04B'): 0,
#  ('C08K', 'C04B'): 0,
#  ('C08K', 'C07C'): 1,
#  ('C08K', 'C08F'): 1,
#  ('C08L', 'B05D'): 1,
#  ('C08L', 'B33Y'): 1,
#  ('C08L', 'C04B'): 0,
#  ('C08L', 'C07C'): 1,
#  ('C09D', 'A41D'): 0,
#  ('C09D', 'B05D'): 0,
#  ('C09D', 'B41J'): 0,
#  ('C09D', 'C03C'): 1,
#  ('C09D', 'C04B'): 0,
#  ('C09D', 'C08F'): 1,
#  ('C09D', 'C08G'): 1,
#  ('C09D', 'C08J'): 1,
#  ('C09D', 'C08K'): 1,
#  ('C09J', 'B23K'): 0,
#  ('C09J', 'C04B'): 0,
#  ('C09J', 'C08F'): 1,
#  ('C10G', 'B01D'): 1,
#  ('C10G', 'B01F'): 0,
#  ('C10G', 'C01B'): 1,
#  ('C10G', 'C07C'): 1,
#  ('C11B', 'A61K'): 1,
#  ('C11B', 'A61L'): 1,
#  ('C11B', 'A61Q'): 0,
#  ('C11B', 'C07C'): 0,
#  ('C11B', 'C07D'): 1,
#  ('C11B', 'C08J'): 0,
#  ('C11D', 'A47L'): 0,
#  ('C11D', 'C07C'): 1,
#  ('C11D', 'C07D'): 1,
#  ('C11D', 'C08F'): 1,
#  ('C11D', 'C11B'): 0,
#  ('C12N', 'A23G'): 1,
#  ('C12N', 'A61B'): 1,
#  ('C12N', 'A61N'): 1,
#  ('C12N', 'B01J'): 1,
#  ('C12N', 'C02F'): 1,
#  ('C12N', 'C07C'): 1,
#  ('C12N', 'C07H'): 1,
#  ('C12N', 'C08B'): 1,
#  ('C12N', 'C08F'): 1,
#  ('C12N', 'C08G'): 1,
#  ('C12N', 'C12M'): 1,
#  ('C12P', 'A01N'): 1,
#  ('C12P', 'A23G'): 1,
#  ('C12P', 'A61L'): 1,
#  ('C12P', 'B01F'): 1,
#  ('C12P', 'B01J'): 1,
#  ('C12P', 'C01B'): 1,
#  ('C12P', 'C07C'): 1,
#  ('C12P', 'C07H'): 1,
#  ('C12P', 'C07K'): 1,
#  ('C12P', 'C08F'): 1,
#  ('C12P', 'C08G'): 1,
#  ('C12P', 'C12M'): 1,
#  ('C12Q', 'A01H'): 0,
#  ('C12Q', 'B01F'): 0,
#  ('C12Q', 'B05D'): 1,
#  ('C12Q', 'B82Y'): 1,
#  ('C12Q', 'C07D'): 1,
#  ('C12Q', 'C12M'): 1,
#  ('C22C', 'B23K'): 1,
#  ('C22C', 'B23P'): 1,
#  ('C22C', 'B33Y'): 1,
#  ('C22C', 'C04B'): 0,
#  ('C23C', 'B21C'): 1,
#  ('C23C', 'B21D'): 1,
#  ('C23C', 'B32B'): 0,
#  ('C23C', 'C01G'): 0,
#  ('C23C', 'C04B'): 1,
#  ('C23C', 'C08J'): 1,
#  ('C23C', 'C09D'): 0,
#  ('C23C', 'C22C'): 1,
#  ('D04H', 'B29C'): 1,
#  ('D04H', 'B29D'): 0,
#  ('D04H', 'B29K'): 1,
#  ('D06F', 'A47K'): 1,
#  ('D06F', 'B67D'): 1,
#  ('D06F', 'C11D'): 0,
#  ('E03F', 'C02F'): 0,
#  ('E03F', 'E02B'): 0,
#  ('E04B', 'B41J'): 0,
#  ('E04B', 'C04B'): 0,
#  ('E04B', 'C08L'): 1,
#  ('E04B', 'C09J'): 1,
#  ('E21B', 'B01F'): 0,
#  ('E21B', 'B23P'): 0,
#  ('E21B', 'B25B'): 0,
#  ('E21B', 'C04B'): 0,
#  ('E21B', 'C08G'): 0,
#  ('E21B', 'E02F'): 0,
#  ('F01D', 'C04B'): 0,
#  ('F02C', 'B64D'): 0,
#  ('F04B', 'B60T'): 0,
#  ('F04B', 'C12M'): 1,
#  ('F04D', 'B23C'): 0,
#  ('F16B', 'B25B'): 1,
#  ('F16B', 'B60N'): 0,
#  ('F16C', 'A01G'): 0,
#  ('F16C', 'B27B'): 0,
#  ('F16C', 'B41J'): 0,
#  ('F16C', 'B65H'): 0,
#  ('F16D', 'B25J'): 1,
#  ('F16D', 'B60B'): 0,
#  ('F16H', 'F01N'): 0,
#  ('F16K', 'F01D'): 0,
#  ('F17C', 'C08J'): 0,
#  ('F17C', 'C08L'): 0,
#  ('F21V', 'B60R'): 0,
#  ('F21V', 'B62D'): 0,
#  ('F21V', 'C08F'): 0,
#  ('F21V', 'C09J'): 0,
#  ('F21Y', 'C08F'): 0,
#  ('F21Y', 'C08L'): 0,
#  ('F24J', 'C01D'): 0,
#  ('F25D', 'B29C'): 1,
#  ('F28D', 'B23K'): 0,
#  ('F28D', 'B33Y'): 0,
#  ('F28D', 'B64D'): 0,
#  ('F28D', 'B64F'): 0,
#  ('F28F', 'B23K'): 0,
#  ('F41H', 'B82Y'): 0,
#  ('F41H', 'C08J'): 0,
#  ('F41H', 'C08K'): 0,
#  ('G01C', 'B60K'): 0,
#  ('G01C', 'B60L'): 0,
#  ('G01C', 'B64D'): 0,
#  ('G01D', 'B60K'): 1,
#  ('G01F', 'B33Y'): 1,
#  ('G01F', 'B64D'): 0,
#  ('G01F', 'B64F'): 0,
#  ('G01L', 'G01B'): 1,
#  ('G01M', 'B23C'): 0,
#  ('G01M', 'F04D'): 0,
#  ('G01N', 'A01K'): 1,
#  ('G01N', 'A61L'): 1,
#  ('G01N', 'B05D'): 1,
#  ('G01N', 'B25J'): 1,
#  ('G01N', 'B65D'): 1,
#  ('G01N', 'B82Y'): 1,
#  ('G01N', 'C07C'): 1,
#  ('G01N', 'C07H'): 1,
#  ('G01N', 'G01B'): 1,
#  ('G01R', 'B60L'): 0,
#  ('G01R', 'B60R'): 0,
#  ('G01S', 'B60L'): 1,
#  ('G01S', 'B60R'): 0,
#  ('G02B', 'B32B'): 1,
#  ('G02B', 'B60R'): 1,
#  ('G02B', 'B64D'): 1,
#  ('G02B', 'B64F'): 0,
#  ('G02B', 'C07C'): 1,
#  ('G02B', 'C08G'): 1,
#  ('G02B', 'C08J'): 1,
#  ('G02B', 'C09J'): 0,
#  ('G02B', 'C12Q'): 1,
#  ('G02B', 'F21V'): 0,
#  ('G02F', 'C07C'): 0,
#  ('G02F', 'C08F'): 0,
#  ('G02F', 'F21V'): 0,
#  ('G05B', 'B23C'): 0,
#  ('G05B', 'B23K'): 1,
#  ('G05B', 'B33Y'): 1,
#  ('G05B', 'B60R'): 0,
#  ('G05D', 'B60R'): 0,
#  ('G05D', 'B62D'): 0,
#  ('G05D', 'E02F'): 0,
#  ('G06F', 'B60R'): 0,
#  ('G06F', 'B62D'): 0,
#  ('G06F', 'C08F'): 0,
#  ('G06F', 'C08G'): 1,
#  ('G06F', 'C09J'): 1,
#  ('G06K', 'B60R'): 0,
#  ('G06K', 'E02F'): 0,
#  ('G06Q', 'B64D'): 1,
#  ('G06Q', 'B65D'): 1,
#  ('G06Q', 'G05D'): 1,
#  ('G06T', 'B23C'): 0,
#  ('G06T', 'B33Y'): 1,
#  ('G06T', 'B60R'): 0,
#  ('G06T', 'G05B'): 1,
#  ('G08B', 'B60L'): 1,
#  ('G08B', 'B60R'): 0,
#  ('G09B', 'B60N'): 1,
#  ('G09F', 'B60B'): 0,
#  ('G09F', 'B60R'): 0,
#  ('G09G', 'C08F'): 0,
#  ('G09G', 'C08G'): 1,
#  ('G09G', 'C09J'): 0,
#  ('H01B', 'B60R'): 0,
#  ('H01F', 'B05D'): 1,
#  ('H01F', 'B60L'): 0,
#  ('H01F', 'B82Y'): 0,
#  ('H01L', 'B82Y'): 1,
#  ('H01L', 'C07F'): 0,
#  ('H01L', 'C08F'): 1,
#  ('H01L', 'C08G'): 0,
#  ('H01L', 'C08J'): 1,
#  ('H01L', 'C08L'): 1,
#  ('H01L', 'C09D'): 0,
#  ('H01L', 'F21V'): 0,
#  ('H01L', 'G02F'): 0,
#  ('H01M', 'B60R'): 0,
#  ('H01M', 'C08K'): 1,
#  ('H01R', 'B60L'): 0,
#  ('H02J', 'A47B'): 1,
#  ('H02J', 'B23Q'): 0,
#  ('H02J', 'B25H'): 0,
#  ('H02J', 'B60L'): 0,
#  ('H02J', 'B60R'): 0,
#  ('H02J', 'B64D'): 1,
#  ('H02J', 'G01R'): 1,
#  ('H02J', 'G01V'): 1,
#  ('H02J', 'H01M'): 1,
#  ('H02K', 'B60L'): 0,
#  ('H02K', 'C08K'): 0,
#  ('H02K', 'F16H'): 0,
#  ('H02N', 'B41J'): 0,
#  ('H04B', 'B60R'): 0,
#  ('H04B', 'G05B'): 1,
#  ('H04N', 'B60R'): 0,
#  ('H04R', 'H01L'): 0,
#  ('H05B', 'B29C'): 1,
#  ('H05B', 'B29D'): 1,
#  ('H05B', 'B41J'): 1,
#  ('H05B', 'B60S'): 1,
#  ('H05B', 'B64D'): 0,
#  ('H05B', 'F26B'): 1,
#  ('H05K', 'B23K'): 1,
#  ('H05K', 'B60L'): 0,
#  ('H05K', 'B60R'): 0,
#  ('H05K', 'C08G'): 0,
#  ('H05K', 'C08J'): 0,
#  ('H05K', 'C08K'): 1,
#  ('H05K', 'C08L'): 0,
#  ('H05K', 'C09D'): 0,
#  ('H05K', 'F16H'): 0}
