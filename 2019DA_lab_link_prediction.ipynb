# %% [markdown]
# # DA lab 6주차 링크프레딕션: networkx 라이브러리의 활용

# %% [markdown]
# ## Link Prediction

# %% [markdown]
# ### Contents
# * 데이터 준비(두 개의 분석구간)
# * 링크 예측
# * 성능 검증

# %% [markdown]
# ### Used Library
# * networkx
# * pandas
# * pickle

# %%
import pandas as pd
import networkx as nx
import pickle

# %% [markdown]
# ### Link Prediction 알고리즘
# * resource_allocation_index
# * jaccard_coefficient
# * adamic_adar_index
# * preferential_attachment
# * cn_soundarajan_hopcroft
# * ra_index_soundarajan_hopcroft
# * within_inter_cluster

# %%
with open('ipc_nx_list(1).pickle','rb') as f:
    data_first=pickle.load(f)
with open('ipc_nx_list(2).pickle','rb') as d:
    data_second=pickle.load(d)

# %% [markdown]
# ### 2가지 분석구간의 데이터 준비

# %%
data_first
# Out:
# [('A61C', 'A61B', 5),
#  ('G01B', 'C08F', 1),
#  ('B65D', 'B43M', 1),
#  ('B65G', 'A01B', 1),
#  ('C12N', 'C11B', 1),
#  ('G01L', 'G01K', 1),
#  ('H04Q', 'G09B', 1),
#  ('G01F', 'F17D', 2),
#  ('C22C', 'B32B', 1),
#  ('A61K', 'A45D', 1),
#  ('F21V', 'A01K', 1),
#  ('A61N', 'A61C', 1),
#  ('A42B', 'A41D', 1),
#  ('G01N', 'A61M', 2),
#  ('H04B', 'G01F', 1),
#  ('G09F', 'G01N', 1),
#  ('H04Q', 'H04B', 1),
#  ('C21D', 'B23K', 2),
#  ('H04N', 'A63B', 2),
#  ('G08B', 'G05D', 1),
#  ('F25D', 'A47G', 1),
#  ('B23K', 'A61L', 2),
#  ('B31B', 'A47G', 1),
#  ('H04N', 'G09F', 1),
#  ('B27B', 'A61B', 1),
#  ('B08B', 'A61M', 1),
#  ('B29C', 'A63B', 3),
#  ('B29C', 'A61F', 2),
#  ('A61M', 'A61J', 1),
#  ('B05C', 'A61F', 2),
#  ('G01M', 'F17D', 1),
#  ('C08F', 'A61L', 1),
#  ('A42B', 'A01M', 1),
#  ('H02N', 'G08B', 1),
#  ('C02F', 'A61L', 1),
#  ('C12Q', 'A61B', 1),
#  ('A47J', 'A23L', 3),
#  ('F02D', 'B01J', 1),
#  ('C12N', 'A01G', 1),
#  ('G03B', 'A63J', 1),
#  ('C23C', 'B23P', 1),
#  ('G08B', 'G06F', 3),
#  ('H01B', 'B82Y', 1),
#  ('G06F', 'A61G', 2),
#  ('B29C', 'A61M', 2),
#  ('B65B', 'B05B', 1),
#  ('H01F', 'B21D', 1),
#  ('A61K', 'A61B', 5),
#  ('A63G', 'A63B', 1),
#  ('G08C', 'A63F', 1),
#  ('C01G', 'B32B', 1),
#  ('G01N', 'C12N', 2),
#  ('B33Y', 'B23K', 1),
#  ('A61K', 'A23L', 3),
#  ('H05B', 'A23L', 1),
#  ('G01N', 'A61N', 1),
#  ('F17C', 'B01D', 1),
#  ('C04B', 'B23K', 1),
#  ('H01M', 'B01J', 2),
#  ('H04B', 'A62C', 1),
#  ('A62B', 'A61M', 1),
#  ('C08F', 'B05D', 1),
#  ('G07C', 'A61G', 1),
#  ('C08J', 'C08F', 1),
#  ('G01M', 'G01F', 1),
#  ('A61L', 'A61B', 5),
#  ('F17D', 'F16K', 1),
#  ('G06F', 'A63B', 5),
#  ('A47J', 'A23D', 1),
#  ('A61H', 'A46B', 1),
#  ('G01K', 'G01C', 1),
#  ('A47L', 'A47F', 1),
#  ('B64D', 'A47B', 1),
#  ('B25D', 'A62B', 1),
#  ('F04B', 'F03C', 1),
#  ('A47G', 'A47F', 1),
#  ('G08B', 'A61G', 1),
#  ('H05B', 'E21B', 1),
#  ('F16J', 'F16C', 1),
#  ('A61N', 'A61K', 5),
#  ('G01L', 'A01C', 1),
#  ('F41H', 'A42B', 1),
#  ('H02K', 'H01F', 1),
#  ('H01L', 'H01B', 1),
#  ('F21Y', 'F16B', 1),
#  ('B01D', 'A47J', 1),
#  ('C07D', 'A01N', 1),
#  ('H04N', 'G02B', 1),
#  ('B32B', 'B29L', 1),
#  ('G01D', 'A61B', 1),
#  ('B24B', 'B08B', 1),
#  ('A61M', 'A61L', 2),
#  ('G06F', 'B60N', 1),
#  ('B21F', 'A61F', 2),
#  ('G01K', 'A61B', 1),
#  ('G06F', 'G01N', 1),
#  ('G09G', 'G06F', 1),
#  ('B65G', 'A47G', 1),
#  ('B01J', 'A61K', 1),
#  ('B29C', 'A47C', 1),
#  ('B65D', 'B31B', 1),
#  ('B29C', 'A24F', 1),
#  ('B32B', 'A47J', 1),
#  ('G01L', 'B33Y', 1),
#  ('B32B', 'B05C', 1),
#  ('C01D', 'B01D', 1),
#  ('B07B', 'B02C', 1),
#  ('G01B', 'C23C', 1),
#  ('C08L', 'C08K', 1),
#  ('G06T', 'A61N', 1),
#  ('H04B', 'E03B', 1),
#  ('B60P', 'A01B', 1),
#  ('E06B', 'A01M', 1),
#  ('G08B', 'B64F', 1),
#  ('G01N', 'B01J', 1),
#  ('H04Q', 'G06K', 1),
#  ('A23K', 'A23D', 1),
#  ('B03D', 'B03B', 1),
#  ('G09F', 'G01F', 2),
#  ('C21D', 'A61L', 2),
#  ('G06Q', 'G01N', 1),
#  ('C07C', 'B01D', 1),
#  ('G07C', 'G06F', 1),
#  ('A01F', 'A01B', 1),
#  ('H04B', 'G06K', 1),
#  ('G01N', 'C07K', 6),
#  ('F02D', 'B01D', 1),
#  ('H04W', 'G06K', 1),
#  ('H01F', 'B23P', 1),
#  ('A61G', 'A61F', 1),
#  ('B23Q', 'B23B', 1),
#  ('H04N', 'B33Y', 1),
#  ('B26D', 'B26B', 1),
#  ('E04B', 'B21K', 1),
#  ('B01L', 'B01J', 1),
#  ('A23L', 'A01H', 1),
#  ('F24J', 'A01K', 1),
#  ('G09B', 'G06K', 1),
#  ('F25B', 'B01D', 1),
#  ('B65D', 'A23L', 1),
#  ('B05D', 'B01F', 1),
#  ('C07C', 'C01D', 1),
#  ('H04N', 'G06K', 2),
#  ('C08F', 'B01J', 1),
#  ('G01S', 'A01C', 1),
#  ('G02B', 'A61B', 5),
#  ('G21G', 'A61N', 1),
#  ('F27B', 'B22D', 1),
#  ('A61M', 'A61G', 1),
#  ('C23C', 'B05B', 1),
#  ('C07C', 'A61K', 1),
#  ('H04N', 'A47B', 1),
#  ('E02B', 'A01G', 1),
#  ('C07K', 'A01K', 1),
#  ('C08L', 'A61B', 1),
#  ('G02B', 'A61N', 1),
#  ('F16L', 'B01D', 1),
#  ('B32B', 'A63B', 1),
#  ('C12M', 'A61N', 1),
#  ('B29D', 'A61M', 1),
#  ('B29C', 'B01J', 1),
#  ('F21Y', 'F21V', 2),
#  ('F16L', 'B65D', 1),
#  ('B65D', 'A61M', 2),
#  ('C25B', 'B29C', 1),
#  ('H04W', 'G08B', 1),
#  ('C08L', 'B29L', 1),
#  ('C12N', 'C07K', 5),
#  ('H02K', 'B23P', 1),
#  ('A61M', 'A61H', 2),
#  ('G01D', 'A61L', 1),
#  ('C08J', 'A61B', 1),
#  ('C12Q', 'B01L', 1),
#  ('E01H', 'A01G', 1),
#  ('A23P', 'A23G', 1),
#  ('B07B', 'B03B', 1),
#  ('B29C', 'A61L', 1),
#  ('B05B', 'A62C', 2),
#  ('F03C', 'C23C', 1),
#  ('C12Q', 'A61K', 3),
#  ('F16D', 'A61B', 1),
#  ('G08G', 'B64D', 1),
#  ('F24F', 'B08B', 1),
#  ('G03B', 'A61B', 2),
#  ('G08G', 'G06F', 1),
#  ('A61L', 'A01N', 1),
#  ('C08B', 'A61K', 2),
#  ('G01D', 'F17D', 1),
#  ('G09F', 'B65D', 2),
#  ('C02F', 'B01D', 5),
#  ('H04W', 'A42B', 1),
#  ('H01L', 'B08B', 1),
#  ('B25H', 'A45F', 1),
#  ('E04B', 'B65D', 1),
#  ('C01B', 'B82Y', 1),
#  ('H04W', 'G01L', 1),
#  ('G01F', 'F04B', 1),
#  ('A01D', 'A01B', 1),
#  ('C12N', 'A23C', 2),
#  ('H01L', 'C09J', 1),
#  ('A46B', 'A45D', 2),
#  ('A63G', 'A63C', 1),
#  ('C08J', 'B29C', 1),
#  ('A47D', 'A47C', 1),
#  ('B82Y', 'A61J', 1),
#  ('F16C', 'F03C', 1),
#  ('B05C', 'B01F', 1),
#  ('F25D', 'A23G', 1),
#  ('B25J', 'A61B', 1),
#  ('A61K', 'A61C', 1),
#  ('H02N', 'H01L', 1),
#  ('B25J', 'B05C', 1),
#  ('H05B', 'H02J', 1),
#  ('B60N', 'A61G', 2),
#  ('C09J', 'B32B', 1),
#  ('G06Q', 'A47G', 1),
#  ('C08J', 'A61L', 2),
#  ('C11B', 'A23K', 1),
#  ('H04N', 'A63F', 1),
#  ('B29L', 'A63B', 3),
#  ('C23F', 'A61L', 2),
#  ('G05D', 'A63H', 1),
#  ('G05D', 'A61G', 1),
#  ('B21D', 'B21C', 1),
#  ('F26B', 'A61L', 1),
#  ('H04N', 'A61B', 6),
#  ('G01B', 'B08B', 1),
#  ('G09F', 'B01L', 1),
#  ('A24F', 'A24B', 2),
#  ('A47G', 'A45F', 2),
#  ('B01F', 'A61J', 1),
#  ('G09B', 'G01L', 1),
#  ('G01N', 'A61K', 10),
#  ('B65G', 'A47B', 1),
#  ('F01M', 'B01D', 1),
#  ('C12P', 'C11B', 1),
#  ('B01J', 'A01N', 1),
#  ('H04W', 'H04L', 1),
#  ('A61G', 'A61B', 1),
#  ('F16M', 'A01K', 1),
#  ('B09B', 'B01J', 1),
#  ('C08L', 'B29C', 1),
#  ('F01B', 'C23C', 1),
#  ('F21W', 'A47L', 1),
#  ('F16N', 'F02C', 1),
#  ('A41F', 'A41D', 1),
#  ('B29L', 'A61L', 1),
#  ('G08B', 'B64D', 1),
#  ('E01H', 'A47L', 1),
#  ('A41D', 'A01M', 1),
#  ('B60T', 'A61G', 1),
#  ('C12N', 'A01N', 2),
#  ('E21B', 'C22C', 1),
#  ('H01C', 'A24F', 1),
#  ('H04Q', 'H02J', 1),
#  ('B65G', 'B21C', 1),
#  ('F16C', 'B22F', 1),
#  ('F16L', 'A47J', 1),
#  ('A23L', 'A01J', 1),
#  ('A62B', 'A61B', 1),
#  ('C08K', 'B01J', 1),
#  ('A01K', 'A01J', 1),
#  ('B23K', 'A24F', 1),
#  ('F16K', 'A62C', 1),
#  ('H04B', 'A63F', 1),
#  ('H04L', 'G06K', 1),
#  ('C12R', 'A61K', 1),
#  ('B29C', 'A61B', 1),
#  ('F16H', 'A47C', 1),
#  ('G09B', 'A63F', 1),
#  ('E04B', 'B01D', 1),
#  ('H04L', 'G08C', 2),
#  ('G06Q', 'A61M', 1),
#  ('F04D', 'A47J', 1),
#  ('F16J', 'C23C', 1),
#  ('A47J', 'A47F', 1),
#  ('A42B', 'A24F', 1),
#  ('A23C', 'A01J', 1),
#  ('A01G', 'A01B', 1),
#  ('H04B', 'F16K', 1),
#  ('D04H', 'A61F', 1),
#  ('C03C', 'B01J', 1),
#  ('G01F', 'A24F', 2),
#  ('H01B', 'C08L', 1),
#  ('F04B', 'C23C', 1),
#  ('G01L', 'A61B', 3),
#  ('H05B', 'H01R', 1),
#  ('C08B', 'A23L', 1),
#  ('G01N', 'B04B', 1),
#  ('H04Q', 'G08C', 2),
#  ('B65D', 'A47G', 4),
#  ('B65D', 'A24F', 4),
#  ('B29L', 'B29D', 2),
#  ('H04B', 'G01L', 1),
#  ('H05B', 'A47J', 2),
#  ('F16M', 'A47G', 2),
#  ('H01M', 'C25B', 1),
#  ('H01M', 'A24F', 1),
#  ('C07D', 'C07C', 1),
#  ('F16H', 'B23D', 1),
#  ('G05B', 'A61B', 3),
#  ('B25J', 'B05B', 1),
#  ('H04W', 'G09B', 1),
#  ('B29K', 'B29C', 4),
#  ('B65D', 'B01F', 1),
#  ('B25C', 'A61B', 2),
#  ('H04N', 'G06F', 2),
#  ('H01M', 'B29C', 1),
#  ('H02J', 'B65D', 2),
#  ('B05B', 'A61F', 2),
#  ('A45F', 'A44C', 1),
#  ('B60R', 'B25D', 1),
#  ('G07C', 'G05D', 1),
#  ('G06F', 'A61B', 13),
#  ('C12N', 'A61K', 12),
#  ('B26B', 'B23D', 1),
#  ('F24C', 'A21D', 1),
#  ('B32B', 'B29C', 1),
#  ('C12P', 'A23D', 1),
#  ('C03C', 'A61J', 1),
#  ('B04B', 'A61M', 1),
#  ('H04Q', 'G06F', 2),
#  ('H04N', 'H04L', 1),
#  ('G08G', 'B64F', 1),
#  ('A47L', 'A47G', 2),
#  ('H01R', 'A62B', 1),
#  ('B65B', 'A23L', 1),
#  ('A21D', 'A21B', 1),
#  ('H02J', 'G01F', 2),
#  ('H04L', 'G01L', 1),
#  ('A61G', 'A47D', 1),
#  ('A61K', 'A01N', 10),
#  ('G06K', 'B33Y', 1),
#  ('B01F', 'A23L', 1),
#  ('B22D', 'B21D', 2),
#  ('G05B', 'A61H', 1),
#  ('B23K', 'B05B', 1),
#  ('G08G', 'G07C', 1),
#  ('C11B', 'A23D', 1),
#  ('B60K', 'A63B', 1),
#  ('F16C', 'B05D', 1),
#  ('B23K', 'B23B', 1),
#  ('B60N', 'A61M', 1),
#  ('A61N', 'A61F', 7),
#  ('A61K', 'A61F', 5),
#  ('H04W', 'H04Q', 1),
#  ('H04Q', 'A63B', 2),
#  ('E02F', 'B07B', 2),
#  ('B07B', 'A01B', 1),
#  ('C02F', 'B29C', 1),
#  ('C21D', 'B21D', 1),
#  ('B41J', 'A45F', 1),
#  ('B65D', 'A47F', 1),
#  ('C22F', 'C22C', 1),
#  ('F16L', 'A61M', 1),
#  ('G03B', 'A61N', 1),
#  ('B67D', 'A47J', 1),
#  ('A47G', 'A47B', 1),
#  ('H01M', 'C02F', 1),
#  ('G06F', 'A47G', 1),
#  ('H01C', 'A61M', 1),
#  ('C08L', 'B32B', 1),
#  ('G08C', 'G06T', 2),
#  ('A61G', 'A47C', 1),
#  ('B60S', 'B08B', 1),
#  ('C12Q', 'C08L', 1),
#  ('G01F', 'G01D', 1),
#  ('E06B', 'B01D', 1),
#  ('F21W', 'F21V', 1),
#  ('B60P', 'A01F', 1),
#  ('G01F', 'A61M', 3),
#  ('C09J', 'C01G', 1),
#  ('B60R', 'A62B', 1),
#  ('H01L', 'C01G', 1),
#  ('G06T', 'G06K', 3),
#  ('E04B', 'B21D', 1),
#  ('B82Y', 'B22F', 1),
#  ('H05H', 'A61L', 1),
#  ('A61M', 'A47G', 1),
#  ('B04B', 'B03D', 1),
#  ('E21B', 'B22D', 1),
#  ('B21K', 'A47J', 1),
#  ('B60L', 'B60K', 1),
#  ('G06F', 'B64D', 1),
#  ('C08G', 'A61K', 1),
#  ('F21V', 'B25B', 1),
#  ('B08B', 'A47K', 1),
#  ('F16N', 'F01M', 1),
#  ('E03F', 'B25B', 1),
#  ('B23K', 'B21F', 2),
#  ('G01N', 'C08G', 1),
#  ('G06F', 'F25D', 1),
#  ('B01D', 'A61B', 1),
#  ('B65D', 'B32B', 1),
#  ('G06F', 'A61N', 1),
#  ('F24F', 'A01K', 1),
#  ('B60B', 'A61G', 1),
#  ('B08B', 'A61J', 1),
#  ('H05B', 'B21D', 1),
#  ('F16M', 'A61B', 1),
#  ('G01G', 'A61G', 1),
#  ('A61H', 'A61G', 3),
#  ('E04B', 'A47J', 1),
#  ('C08L', 'C08B', 2),
#  ('C08L', 'C08G', 2),
#  ('C01C', 'B01J', 1),
#  ('A45F', 'A01M', 1),
#  ('E02F', 'A01B', 1),
#  ('G06F', 'B60K', 1),
#  ('F25B', 'A23L', 1),
#  ('A61N', 'A41D', 1),
#  ('H04Q', 'G06T', 1),
#  ('C12P', 'C07D', 1),
#  ('B60L', 'A61G', 1),
#  ('A61M', 'A61B', 29),
#  ('A63B', 'A61B', 3),
#  ('G02C', 'F41H', 1),
#  ('H01L', 'G08B', 1),
#  ('H02N', 'A63F', 1),
#  ('C07K', 'A61K', 18),
#  ('C22C', 'B21C', 1),
#  ('B65D', 'A61L', 1),
#  ('D06F', 'A47L', 1),
#  ('C12Q', 'C07K', 1),
#  ('G01N', 'A61B', 6),
#  ('G02B', 'C11D', 1),
#  ('H04L', 'H04B', 1),
#  ('H01L', 'B24B', 1),
#  ('D04H', 'A61L', 1),
#  ('A61F', 'A61B', 47),
#  ('H04L', 'A61B', 2),
#  ('F16N', 'B01D', 1),
#  ('B65B', 'A47J', 1),
#  ('A61M', 'A47L', 1),
#  ('B04B', 'B01D', 1),
#  ('H01J', 'B01J', 1),
#  ('H04L', 'A63F', 5),
#  ('A47L', 'A47K', 1),
#  ('G08G', 'A61G', 1),
#  ('C12P', 'A23L', 1),
#  ('G08B', 'A42B', 1),
#  ('G01B', 'B60S', 1),
#  ('B23P', 'B23B', 2),
#  ('G06T', 'A61C', 1),
#  ('G06Q', 'A63F', 1),
#  ('F16K', 'A61M', 1),
#  ('G09F', 'A47B', 1),
#  ('B60K', 'A61B', 1),
#  ('G06T', 'A63F', 3),
#  ('G08B', 'A61B', 2),
#  ('H04W', 'G06T', 1),
#  ('B33Y', 'A61F', 1),
#  ('H02J', 'A61B', 1),
#  ('G01R', 'A61N', 2),
#  ('G06T', 'A63B', 2),
#  ('F25D', 'A47F', 1),
#  ('G06T', 'G01N', 1),
#  ('G08B', 'B60K', 1),
#  ('C12M', 'A61K', 1),
#  ('G08C', 'A61B', 5),
#  ('F16J', 'B05D', 1),
#  ('A61N', 'A43B', 1),
#  ('B23B', 'B21C', 1),
#  ('G01F', 'E03B', 1),
#  ('H04Q', 'G05B', 1),
#  ('F16B', 'B21D', 1),
#  ('G06K', 'G06F', 3),
#  ('B29D', 'A43B', 1),
#  ('G06F', 'A63F', 7),
#  ('G06F', 'A61C', 2),
#  ('A01N', 'A01M', 1),
#  ('G01M', 'F16K', 1),
#  ('C10G', 'B01J', 1),
#  ('F02C', 'F01D', 1),
#  ('B60S', 'B05B', 1),
#  ('C25D', 'B82Y', 1),
#  ('H01J', 'A61L', 2),
#  ('F16C', 'C22C', 1),
#  ('C12P', 'A61K', 1),
#  ('C01B', 'B01J', 3),
#  ('A61Q', 'A01N', 2),
#  ('B66F', 'A01B', 1),
#  ('B25B', 'A01K', 1),
#  ('C05G', 'A01G', 1),
#  ('F16L', 'B32B', 1),
#  ('F16B', 'A01K', 1),
#  ('B01F', 'A21D', 1),
#  ('B32B', 'A61F', 1),
#  ('G08B', 'A01K', 1),
#  ('B60P', 'A01D', 1),
#  ('B05B', 'B01J', 1),
#  ('B29L', 'A47C', 1),
#  ('B29C', 'A45F', 1),
#  ('B65D', 'A61D', 1),
#  ('C25B', 'C02F', 1),
#  ('A23L', 'A23K', 2),
#  ('C21D', 'B21F', 2),
#  ('D06F', 'B65D', 1),
#  ('B65G', 'A47J', 1),
#  ('H01B', 'C07C', 1),
#  ('G01F', 'B65B', 2),
#  ('H01B', 'B01J', 2),
#  ('B21F', 'A61L', 2),
#  ('G01M', 'E03B', 1),
#  ('B66F', 'A01G', 1),
#  ('A63C', 'A43B', 1),
#  ('B22D', 'B21C', 1),
#  ('G09G', 'A61B', 1),
#  ('B43M', 'A45D', 1),
#  ('G02B', 'A61K', 1),
#  ('H04W', 'B33Y', 1),
#  ('H04Q', 'G08B', 1),
#  ('A63G', 'A43B', 1),
#  ('G01B', 'A63B', 1),
#  ('G02C', 'A61B', 1),
#  ('C08F', 'A61K', 1),
#  ('H04L', 'B33Y', 1),
#  ('B65B', 'B01F', 1),
#  ('H04N', 'F16M', 2),
#  ('B65B', 'A24F', 2),
#  ('B01J', 'B01D', 8),
#  ('H05B', 'B23K', 1),
#  ('A61N', 'A61B', 19),
#  ('B23K', 'A61N', 1),
#  ('C22C', 'A61L', 1),
#  ('A61M', 'A24F', 4),
#  ('A47J', 'A47G', 1),
#  ('G06F', 'B64F', 1),
#  ('B05D', 'A61M', 1),
#  ('C23C', 'B23B', 2),
#  ('B29K', 'A45F', 1),
#  ('B05C', 'B05B', 4),
#  ('A61N', 'A61H', 2),
#  ('B60K', 'B60B', 1),
#  ('A47L', 'A47J', 1),
#  ('F28F', 'F25B', 1),
#  ('G21F', 'C02F', 1),
#  ('C12P', 'A23K', 1),
#  ('B29K', 'A61B', 1),
#  ('C12M', 'B01L', 2),
#  ('F28D', 'B01D', 1),
#  ('E06B', 'B62D', 1),
#  ('G06K', 'A61F', 1),
#  ('F16H', 'A61M', 1),
#  ('B65D', 'A46B', 1),
#  ('G08C', 'G06F', 1),
#  ('G06F', 'A61H', 1),
#  ('H04N', 'G01K', 1),
#  ('B60B', 'A63B', 1),
#  ('A47J', 'A47B', 1),
#  ('F01N', 'B01D', 7),
#  ('F28F', 'F28D', 1),
#  ('A61K', 'A61J', 3),
#  ('G08B', 'A63F', 1),
#  ('F16C', 'F01B', 1),
#  ('A61L', 'A61F', 14),
#  ('B33Y', 'A63B', 1),
#  ('B65G', 'A01D', 1),
#  ('C22F', 'A61L', 3),
#  ('G05B', 'A61L', 1),
#  ('G05B', 'B21D', 1),
#  ('A61N', 'A61M', 7),
#  ('G01R', 'A41D', 1),
#  ('B64D', 'A62B', 1),
#  ('C11D', 'B01J', 1),
#  ('F03C', 'F01B', 1),
#  ('C08L', 'A23G', 1),
#  ('B32B', 'B29D', 1),
#  ('A61M', 'A61D', 1),
#  ('B26F', 'A61J', 1),
#  ('C25D', 'B03C', 1),
#  ('A63F', 'A63B', 2),
#  ('B08B', 'B01F', 1),
#  ('H04N', 'G09B', 1),
#  ('H04N', 'H04B', 1),
#  ('F16M', 'F16B', 1),
#  ('H02J', 'G05B', 1),
#  ('F27B', 'C21C', 1),
#  ('G01N', 'C12Q', 4),
#  ('C07H', 'A61K', 1),
#  ('B29L', 'A61M', 1),
#  ('A47F', 'A47B', 1),
#  ('G21F', 'B01D', 1),
#  ('C03C', 'A61K', 1),
#  ('G09F', 'B65B', 2),
#  ('C05G', 'A01N', 1),
#  ('C08L', 'A61K', 3),
#  ('G01C', 'B02C', 1),
#  ('H05B', 'H01F', 1),
#  ('A47G', 'A46B', 1),
#  ('C12R', 'C12Q', 1),
#  ('A62B', 'A42B', 1),
#  ('B60T', 'A61H', 1),
#  ('G02F', 'C25D', 1),
#  ('B05C', 'A61M', 1),
#  ('G06F', 'G01L', 1),
#  ('G02C', 'A42B', 1),
#  ('B29D', 'A63B', 1),
#  ('B29C', 'A61K', 1),
#  ('F24J', 'F24F', 1),
#  ('B23K', 'A61F', 3),
#  ('B67C', 'B05B', 1),
#  ('B32B', 'B21D', 1),
#  ('A62B', 'A61L', 2),
#  ('C08L', 'B01J', 2),
#  ('G08B', 'A61D', 1),
#  ('F24F', 'A61J', 1),
#  ('H01L', 'A63F', 1),
#  ('B32B', 'A61G', 1),
#  ('C12Q', 'C08G', 1),
#  ('H04Q', 'H04N', 1),
#  ('G01K', 'G01F', 1),
#  ('A61D', 'A01K', 1),
#  ('B60L', 'B60B', 1),
#  ('A45F', 'A41D', 1),
#  ('H02J', 'B23K', 1),
#  ('C08G', 'A61B', 1),
#  ('B65D', 'A61K', 1),
#  ('B65C', 'A47L', 1),
#  ('C12M', 'A61M', 1),
#  ('H04L', 'G06F', 1),
#  ('B05D', 'B05B', 5),
#  ('H04W', 'A61B', 1),
#  ('B01D', 'A47L', 1),
#  ('H02J', 'A24F', 4),
#  ('C12N', 'A01H', 24),
#  ('B29L', 'A45F', 1),
#  ('F16M', 'A46B', 1),
#  ('G01F', 'F16K', 1),
#  ('B05D', 'B01J', 1),
#  ('A01N', 'A01G', 1),
#  ('B60N', 'A61B', 1),
#  ('H04W', 'A63B', 2),
#  ('G01V', 'A61B', 1),
#  ('F21Y', 'F21W', 1),
#  ('C23F', 'C22F', 2),
#  ('H05B', 'C22C', 1),
#  ('G06F', 'G05D', 2),
#  ('G01V', 'G01R', 1),
#  ('C02F', 'B01J', 2),
#  ('H05B', 'B22D', 1),
#  ('B65D', 'B65B', 4),
#  ('G09F', 'G06Q', 1),
#  ('B08B', 'B05B', 1),
#  ('B29K', 'A61F', 1),
#  ('A61Q', 'A45D', 1),
#  ('B65D', 'A47L', 2),
#  ('A61G', 'A47G', 1),
#  ('G09G', 'G08C', 1),
#  ('G02B', 'A61F', 1),
#  ('G01N', 'B08B', 1),
#  ('F16B', 'A47C', 1),
#  ('F17D', 'A62C', 1),
#  ('G01S', 'A63B', 1),
#  ('H01R', 'A47J', 1),
#  ('A61K', 'A24F', 1),
#  ('C01C', 'B01D', 1),
#  ('C08L', 'A63B', 2),
#  ('B65G', 'B65D', 1),
#  ('C08J', 'B29L', 1),
#  ('H01L', 'C08K', 1),
#  ('C12M', 'A61B', 1),
#  ('C21C', 'B22D', 1),
#  ('A61M', 'A61F', 16),
#  ('F16M', 'A47B', 1),
#  ('G02B', 'A62B', 1),
#  ('H04B', 'F17D', 1),
#  ('H04B', 'G01M', 1),
#  ('H04N', 'A61N', 1),
#  ('B29K', 'A61L', 1),
#  ('B05D', 'B05C', 3),
#  ('F25D', 'A23L', 1),
#  ('F02C', 'B01D', 2),
#  ('C22C', 'B22C', 1),
#  ('H04B', 'A63B', 1),
#  ('B67C', 'B65B', 1),
#  ('A61D', 'A61B', 1),
#  ('F16B', 'B29C', 1),
#  ('G09B', 'A63B', 5),
#  ('G09F', 'F16M', 1),
#  ('G06Q', 'A61B', 1),
#  ('A61H', 'A61F', 3),
#  ('G01R', 'A61B', 2),
#  ('C08K', 'A63B', 2),
#  ('F21V', 'A47G', 1),
#  ('H04L', 'G08B', 1),
#  ('A61H', 'A47C', 1),
#  ('H04B', 'B33Y', 1),
#  ('H01R', 'B25D', 1),
#  ('F26B', 'A23L', 2),
#  ('C07K', 'A23J', 1),
#  ('C08F', 'B05B', 1),
#  ('C22F', 'B23K', 2),
#  ('F16M', 'A45F', 1),
#  ('H02J', 'G08C', 1),
#  ('A47L', 'A47B', 1),
#  ('H05B', 'B05B', 1),
#  ('F17D', 'E03B', 1),
#  ('B05B', 'A01G', 1),
#  ('C07F', 'A61K', 1),
#  ('C08J', 'C08G', 1),
#  ('F21V', 'F16B', 1),
#  ('B82Y', 'B01J', 2),
#  ('B65B', 'A21D', 1),
#  ('B23P', 'B21J', 1),
#  ('F04B', 'B05D', 1),
#  ('A61K', 'A23J', 1),
#  ('B04B', 'B01L', 1),
#  ('C08L', 'A61L', 2),
#  ('B65D', 'A47J', 5),
#  ('B65D', 'A47B', 1),
#  ('A47J', 'A21D', 2),
#  ('F27D', 'C21C', 1),
#  ('G06K', 'G01L', 1),
#  ('B29L', 'B29C', 8),
#  ('H01L', 'B32B', 1),
#  ('G01K', 'A61M', 1),
#  ('F16H', 'B26B', 1),
#  ('B29K', 'A63B', 2),
#  ('C23C', 'C08F', 1),
#  ('H04L', 'G05B', 1),
#  ('E04B', 'B32B', 1),
#  ('F01D', 'B01D', 1),
#  ('A01C', 'A01B', 4),
#  ('E04B', 'A47K', 1),
#  ('F21V', 'A45C', 1),
#  ('C09D', 'A61K', 1),
#  ('C22C', 'B22D', 4),
#  ('H02J', 'G09F', 2),
#  ('G02B', 'A63J', 1),
#  ('G08G', 'G05D', 1),
#  ('F17D', 'A61M', 1),
#  ('D04B', 'A61F', 1),
#  ('B32B', 'B01D', 1),
#  ('B25B', 'A47K', 1),
#  ('A63B', 'A01K', 1),
#  ('C01G', 'B01J', 1),
#  ('A61P', 'A61F', 1),
#  ('F21V', 'A01G', 1),
#  ('H05B', 'A61M', 1),
#  ('H02K', 'A47L', 1),
#  ('B65G', 'A22C', 1),
#  ('F24C', 'A47J', 2),
#  ('B62D', 'A01M', 1),
#  ('A61N', 'A61L', 3),
#  ('G02F', 'B03C', 1),
#  ('B08B', 'A61G', 1),
#  ('F21Y', 'A47G', 1),
#  ('B23D', 'B23B', 2),
#  ('H04W', 'H04B', 1),
#  ('H04Q', 'H04L', 2),
#  ('B65D', 'A61B', 1),
#  ('G08G', 'G08B', 1),
#  ('H04N', 'B02C', 1),
#  ('A43C', 'A43B', 4),
#  ('G01F', 'A62C', 1),
#  ('B65D', 'A01K', 1),
#  ('B23K', 'B05D', 1),
#  ('C07C', 'B01J', 4),
#  ('B65G', 'A47F', 1),
#  ('C11B', 'A23L', 1),
#  ('B65G', 'A01F', 1),
#  ('B08B', 'A47L', 3),
#  ('G01F', 'A61B', 1),
#  ('G09G', 'A63F', 1),
#  ('H01R', 'H01F', 1),
#  ('C12N', 'A23K', 1),
#  ('C08J', 'B01J', 1),
#  ('G01N', 'C07D', 1),
#  ('B01J', 'A61L', 2),
#  ('H04N', 'G05B', 1),
#  ('F16N', 'F01D', 1),
#  ('C12N', 'A23L', 2),
#  ('C11D', 'A61K', 2),
#  ('G09G', 'G06T', 1),
#  ('F04B', 'F01B', 1),
#  ('C08L', 'B82Y', 1),
#  ('B41J', 'B05B', 1),
#  ('B32B', 'A61B', 1),
#  ('C01B', 'B01D', 3),
#  ('H04W', 'H04N', 1),
#  ('G07F', 'A47F', 1),
#  ('B21K', 'B01D', 1),
#  ('B29L', 'A24F', 1),
#  ('B24B', 'B21C', 1),
#  ('B29L', 'A47G', 1),
#  ('B32B', 'B22D', 1),
#  ('A61L', 'A61K', 17),
#  ('B23B', 'B06B', 1),
#  ('C12N', 'A61L', 2),
#  ('G09F', 'A24F', 2),
#  ('F25B', 'A23G', 1),
#  ('H01L', 'A61N', 1),
#  ('C23F', 'A61F', 2),
#  ('G06F', 'A45C', 1),
#  ('C09J', 'B01J', 1),
#  ('A43D', 'A43B', 2),
#  ('F04B', 'A61M', 3),
#  ('H02J', 'B65B', 2),
#  ('B24B', 'B23P', 1),
#  ('A61J', 'A61B', 1),
#  ('A61P', 'A61K', 2),
#  ('G09B', 'A61K', 1),
#  ('A63H', 'A01K', 1),
#  ('C08K', 'B32B', 1),
#  ('G05D', 'B64F', 1),
#  ('H05B', 'H01C', 1),
#  ('G10L', 'A63F', 1),
#  ('B65G', 'B60P', 1),
#  ('F02D', 'F01N', 1),
#  ('H01F', 'A47J', 1),
#  ('G05B', 'A61C', 1),
#  ('A63H', 'A63F', 2),
#  ('B33Y', 'B22F', 1),
#  ('F21V', 'A47L', 1),
#  ('B29L', 'A61F', 2),
#  ('B29D', 'A43C', 1),
#  ('B65C', 'B08B', 1),
#  ('H04B', 'G10L', 1),
#  ('G01L', 'A01B', 2),
#  ('F16B', 'A24F', 1),
#  ('B24B', 'B23D', 1),
#  ('G01N', 'G01D', 1),
#  ('H04N', 'G01L', 1),
#  ('B01F', 'A21C', 1),
#  ('B65D', 'A21D', 1),
#  ('G21K', 'A61N', 1),
#  ('G06T', 'G01S', 1),
#  ('H04R', 'A61C', 1),
#  ('G07C', 'B64D', 1),
#  ('F27D', 'F27B', 1),
#  ('B32B', 'A47L', 1),
#  ('G08B', 'G05B', 1),
#  ('H04R', 'A61B', 1),
#  ('C07H', 'A23L', 1),
#  ('G05B', 'A61G', 1),
#  ('H02K', 'F04D', 1),
#  ('F16C', 'C23C', 1),
#  ('B82Y', 'A61Q', 1),
#  ('G06F', 'A61M', 7),
#  ('C11D', 'A01N', 1),
#  ('A47J', 'A21C', 1),
#  ('B65G', 'A01C', 1),
#  ('B04B', 'B03B', 1),
#  ('B23K', 'B22F', 1),
#  ('G06K', 'G01S', 1),
#  ('C23C', 'B05D', 2),
#  ('G01N', 'C12M', 2),
#  ('H04L', 'A63B', 1),
#  ('C08L', 'B29D', 1),
#  ('B01F', 'A47J', 1),
#  ('B24B', 'B23B', 2),
#  ('B60K', 'A61G', 1),
#  ('D04D', 'A44C', 1),
#  ('B26D', 'A47J', 1),
#  ('G05B', 'A61K', 1),
#  ('H01M', 'C01B', 1),
#  ('D04D', 'B65H', 1),
#  ('G01D', 'E03B', 1),
#  ('H04B', 'G01D', 1),
#  ('B65D', 'A63B', 1),
#  ('C01B', 'A61K', 1),
#  ('A61Q', 'A61K', 15),
#  ('B04C', 'A47L', 1),
#  ('B65G', 'A47L', 1),
#  ('A61H', 'A61C', 1),
#  ('B26B', 'A47J', 1),
#  ('B29K', 'A47C', 1),
#  ('G01B', 'B05D', 1),
#  ('F16J', 'F04B', 1),
#  ('F04D', 'A47L', 1),
#  ('B05D', 'A61F', 2),
#  ('H04W', 'G06F', 2),
#  ('H04B', 'G06F', 1),
#  ('H05K', 'A61N', 1),
#  ('C08J', 'A61K', 1),
#  ('C03C', 'B09B', 1),
#  ('G01N', 'B01L', 6),
#  ('A01F', 'A01D', 3),
#  ('A61B', 'A47G', 1),
#  ('H05K', 'A47B', 2),
#  ('C12N', 'A01K', 1),
#  ('G21K', 'A61B', 1),
#  ('A47C', 'A45F', 1),
#  ('C07F', 'C07D', 1),
#  ('G01B', 'B05B', 2),
#  ('B08B', 'A61B', 1),
#  ('G06K', 'A61B', 6),
#  ('A45F', 'A42B', 1),
#  ('A21D', 'A21C', 2),
#  ('G06T', 'G06F', 3),
#  ('H04N', 'G06T', 1),
#  ('C08L', 'C08J', 2),
#  ('A62D', 'A61L', 1),
#  ('C04B', 'A61N', 1),
#  ('A47G', 'A47C', 1),
#  ('B01J', 'A62D', 1),
#  ('C08J', 'A61F', 1),
#  ('G09B', 'B33Y', 1),
#  ('H04N', 'G01S', 2),
#  ('C12P', 'C12N', 1),
#  ('G01N', 'B01D', 1),
#  ('G06K', 'A63B', 2),
#  ('C08L', 'C08F', 1),
#  ('F16J', 'F01B', 1),
#  ('B43M', 'A46B', 1),
#  ('B25J', 'A61M', 1),
#  ('B08B', 'A47G', 1),
#  ('A63C', 'A63B', 1),
#  ('H04N', 'G09G', 1),
#  ('E02B', 'A01N', 1),
#  ('C25B', 'B01J', 1),
#  ('G05B', 'G01D', 1),
#  ('H04N', 'G01C', 1),
#  ('A61B', 'A41D', 1),
#  ('C07K', 'A61M', 1),
#  ('B32B', 'B21K', 1),
#  ('B29C', 'A47G', 1),
#  ('F01M', 'F01D', 1),
#  ('B32B', 'B01J', 1),
#  ('E21B', 'B22C', 1),
#  ('A61H', 'A47K', 1),
#  ('F16C', 'F04B', 1),
#  ('C07D', 'A61K', 14),
#  ('B64F', 'A61G', 1),
#  ('G01K', 'B02C', 1),
#  ('A61B', 'A47L', 1),
#  ('G06F', 'A63H', 1),
#  ('H02J', 'A61M', 1),
#  ('C23F', 'B21F', 2),
#  ('G01S', 'A61B', 2),
#  ('C22C', 'B21D', 2),
#  ('G21F', 'B01J', 1),
#  ('C22F', 'B21F', 2),
#  ('B64F', 'B64D', 1),
#  ('A01H', 'A01G', 1),
#  ('E02B', 'C05G', 1),
#  ('A43D', 'A43C', 1),
#  ('B22D', 'B22C', 1),
#  ('F04D', 'A61M', 1),
#  ('C08G', 'A61Q', 1),
#  ('A61N', 'A24F', 1),
#  ('C12N', 'A23D', 1),
#  ('B65D', 'A45D', 2),
#  ('G09B', 'A61B', 1),
#  ('H05K', 'H01L', 1),
#  ('B65D', 'A61J', 4),
#  ('F03C', 'B05D', 1),
#  ('H01L', 'B01J', 2),
#  ('C08J', 'B29K', 1),
#  ('A61K', 'A23K', 2),
#  ('A61F', 'A41D', 1),
#  ('H04N', 'G03B', 1),
#  ('H04B', 'A61B', 1),
#  ('H02J', 'G08B', 1),
#  ('C08L', 'A61Q', 2),
#  ('B33Y', 'A61B', 1),
#  ('A61M', 'A61K', 6),
#  ('C08B', 'A61L', 1),
#  ('F21Y', 'A47L', 1),
#  ('B01D', 'A61M', 3),
#  ('B65D', 'B01D', 1),
#  ('G01B', 'C08K', 1),
#  ('B29D', 'B29C', 2),
#  ('A61J', 'A47G', 1),
#  ('G06Q', 'G06F', 3),
#  ('G08C', 'G08B', 1),
#  ('G08C', 'G05B', 1),
#  ('F16J', 'F03C', 1),
#  ('G03B', 'G02B', 2),
#  ('C22F', 'A61F', 3),
#  ('G06Q', 'F25D', 1),
#  ('A23L', 'A23C', 1),
#  ('A23L', 'A23G', 2),
#  ('B29K', 'A47G', 1),
#  ('G06T', 'A61B', 11),
#  ('H01R', 'B60R', 1),
#  ('C09D', 'C08B', 1),
#  ('G03B', 'G01S', 1),
#  ('G07C', 'B64F', 1),
#  ('B29L', 'B29K', 4),
#  ('B32B', 'A61M', 1),
#  ('H04L', 'G09B', 2),
#  ('F16L', 'A62C', 1),
#  ('C22C', 'B22F', 1),
#  ('B05B', 'A61M', 1),
#  ('F16L', 'E04B', 1),
#  ('B23P', 'B21D', 1),
#  ('F16L', 'B21K', 1),
#  ('H04Q', 'G01L', 1),
#  ('G01M', 'G01D', 1),
#  ('C23C', 'B23K', 1),
#  ('E03F', 'A47K', 1),
#  ('G02F', 'B82Y', 1),
#  ('C09D', 'C08L', 1),
#  ('B65D', 'B21K', 1),
#  ('C22F', 'C21D', 2),
#  ('F16K', 'E03B', 1),
#  ('C12Q', 'B01J', 1),
#  ('A61K', 'A01K', 1),
#  ...]

# %%
data_second
# Out:
# [('C11B', 'C07D', 1),
#  ('C10B', 'B09B', 1),
#  ('F16L', 'B62D', 1),
#  ('G03F', 'B41C', 1),
#  ('G06F', 'C08C', 1),
#  ('F02B', 'C01B', 1),
#  ('B32B', 'A61F', 1),
#  ('F16C', 'B61F', 1),
#  ('C03B', 'A61J', 1),
#  ('B62K', 'B60Q', 1),
#  ('B64D', 'B60R', 2),
#  ('C07D', 'C04B', 1),
#  ('B60Q', 'A01B', 1),
#  ('C09G', 'B24D', 1),
#  ('G01N', 'B01J', 2),
#  ('G02F', 'B32B', 1),
#  ('B62D', 'B60P', 4),
#  ('G02B', 'B64F', 1),
#  ('G02B', 'C07C', 1),
#  ('G02F', 'C08F', 1),
#  ('B67B', 'B65D', 1),
#  ('F02D', 'C12N', 1),
#  ('G06T', 'B29C', 1),
#  ('G01N', 'B82Y', 2),
#  ('C05C', 'C05B', 1),
#  ('B62D', 'B60R', 10),
#  ('B60J', 'B32B', 2),
#  ('H01B', 'B82Y', 1),
#  ('G02F', 'G02B', 2),
#  ('G06F', 'B29C', 1),
#  ('C07J', 'A61K', 1),
#  ('H01L', 'C08G', 2),
#  ('B65B', 'A61B', 2),
#  ('F16B', 'B30B', 1),
#  ('B62L', 'B62J', 1),
#  ('C04B', 'B23K', 1),
#  ('C08F', 'B05D', 2),
#  ('F16H', 'B60W', 1),
#  ('B60W', 'B60R', 3),
#  ('C10M', 'B32B', 1),
#  ('G01V', 'G01S', 1),
#  ('B62D', 'B60L', 1),
#  ('C10H', 'C07C', 1),
#  ('B61L', 'B61C', 2),
#  ('F16B', 'B23P', 1),
#  ('C22B', 'B01D', 1),
#  ('G02B', 'F21V', 1),
#  ('G05B', 'B29C', 1),
#  ('B44C', 'B30B', 1),
#  ('F28C', 'B01D', 2),
#  ('C07D', 'A01N', 6),
#  ('C08J', 'C04B', 1),
#  ('C09D', 'B63B', 1),
#  ('F16C', 'F04C', 1),
#  ('C09J', 'B44F', 1),
#  ('F02C', 'C10J', 1),
#  ('F02K', 'C06B', 1),
#  ('G06F', 'G01N', 1),
#  ('C05F', 'C02F', 1),
#  ('G07C', 'A01B', 1),
#  ('C07F', 'B01D', 1),
#  ('D21F', 'D04H', 1),
#  ('B23K', 'B23D', 1),
#  ('C04B', 'B60C', 1),
#  ('B65G', 'B21B', 1),
#  ('G02B', 'G01N', 1),
#  ('E04B', 'C09J', 1),
#  ('C22B', 'B29B', 1),
#  ('G09G', 'G01D', 1),
#  ('B60N', 'B29D', 1),
#  ('B29K', 'A44B', 1),
#  ('H01M', 'B62K', 1),
#  ('E21B', 'E02F', 1),
#  ('G10K', 'B41J', 1),
#  ('B26F', 'B25J', 1),
#  ('F16G', 'B29C', 1),
#  ('B64D', 'B60K', 1),
#  ('D06F', 'B41F', 1),
#  ('C09J', 'B29L', 1),
#  ('B44B', 'B30B', 1),
#  ('B63B', 'B60F', 1),
#  ('B60R', 'B60D', 1),
#  ('C40B', 'B01L', 1),
#  ('H01M', 'B60L', 8),
#  ('H01L', 'B81C', 7),
#  ('G01N', 'C09K', 1),
#  ('F16C', 'B27B', 1),
#  ('B32B', 'A61M', 1),
#  ('B60R', 'B60J', 2),
#  ('D21H', 'C09J', 1),
#  ('B65D', 'B23P', 1),
#  ('C11B', 'A61K', 1),
#  ('G07D', 'B41F', 1),
#  ('C23C', 'B21D', 1),
#  ('D21B', 'B29B', 1),
#  ('G06T', 'B25J', 1),
#  ('B65D', 'A62C', 1),
#  ('G05B', 'B23K', 1),
#  ('C07D', 'A61K', 34),
#  ('F28C', 'C01D', 1),
#  ('C08F', 'B01J', 1),
#  ('G10K', 'E04B', 1),
#  ('C08L', 'B29K', 5),
#  ('G08G', 'B64C', 2),
#  ('C07D', 'A61N', 1),
#  ('B64C', 'B32B', 1),
#  ('C05F', 'C05B', 1),
#  ('C07K', 'A01K', 3),
#  ('F16B', 'B44B', 1),
#  ('C02F', 'B05D', 1),
#  ('F25B', 'B60H', 1),
#  ('H02K', 'B60L', 1),
#  ('H02J', 'F02N', 1),
#  ('B65D', 'A61M', 2),
#  ('H01M', 'H01G', 1),
#  ('B42D', 'A45C', 1),
#  ('C08L', 'B29L', 2),
#  ('B62M', 'B62L', 1),
#  ('B29D', 'A43D', 1),
#  ('C12N', 'C08F', 1),
#  ('F16L', 'B60B', 1),
#  ('B60C', 'B32B', 2),
#  ('C12Q', 'A61K', 3),
#  ('D01D', 'C07D', 1),
#  ('D01H', 'B65H', 1),
#  ('A61N', 'A61K', 4),
#  ('G08G', 'G06F', 1),
#  ('G06F', 'B32B', 1),
#  ('C09J', 'B44C', 1),
#  ('C08J', 'A62D', 1),
#  ('C02F', 'B01D', 8),
#  ('H05K', 'H05B', 1),
#  ('F21V', 'C09J', 1),
#  ('C09D', 'C03C', 1),
#  ('C09C', 'B22F', 1),
#  ('H05B', 'B29D', 1),
#  ('B62D', 'B32B', 1),
#  ('B62K', 'B29C', 1),
#  ('B66C', 'B64B', 1),
#  ('B60J', 'A47C', 1),
#  ('C04B', 'B22F', 1),
#  ('C08J', 'B01D', 2),
#  ('B65D', 'B29L', 4),
#  ('B65B', 'B31B', 1),
#  ('B25J', 'A61B', 1),
#  ('C09G', 'B24B', 2),
#  ('G05B', 'B33Y', 1),
#  ('F15B', 'B62D', 1),
#  ('B33Y', 'B29C', 6),
#  ('C08J', 'C03C', 1),
#  ('C08J', 'A61L', 1),
#  ('H05K', 'B32B', 2),
#  ('C09K', 'A62D', 1),
#  ('G05B', 'A61B', 1),
#  ('B65D', 'B44D', 1),
#  ('E04H', 'A47C', 1),
#  ('G06T', 'B23Q', 1),
#  ('G09F', 'B42D', 1),
#  ('F04C', 'B67D', 1),
#  ('B29C', 'B05C', 2),
#  ('B63C', 'B63B', 2),
#  ('G01M', 'F16D', 1),
#  ('B23Q', 'B23D', 1),
#  ('E04C', 'B32B', 1),
#  ('D06M', 'B32B', 1),
#  ('B65H', 'B65G', 1),
#  ('C09K', 'C01F', 1),
#  ('B60B', 'B44C', 1),
#  ('B29C', 'A43D', 1),
#  ('C08G', 'A62D', 1),
#  ('H02G', 'B60R', 1),
#  ('G05D', 'A01B', 1),
#  ('F28F', 'B21D', 1),
#  ('H01L', 'C08F', 2),
#  ('B66F', 'B60P', 1),
#  ('C09K', 'C03C', 1),
#  ('C09K', 'C08J', 4),
#  ('B65D', 'B32B', 1),
#  ('B05D', 'B01J', 1),
#  ('B27B', 'A01G', 1),
#  ('F16L', 'B23K', 1),
#  ('B29K', 'B29D', 2),
#  ('F16B', 'B60N', 1),
#  ('H02J', 'G01S', 1),
#  ('G01R', 'B60L', 1),
#  ('B31B', 'B23P', 1),
#  ('G01J', 'B61L', 1),
#  ('B65D', 'A47G', 1),
#  ('B62J', 'B29L', 1),
#  ('B29L', 'A44B', 1),
#  ('H02J', 'H01Q', 1),
#  ('C08J', 'C02F', 1),
#  ('H01L', 'C07D', 1),
#  ('B30B', 'B28B', 1),
#  ('B29K', 'B29C', 22),
#  ('B65D', 'B01F', 1),
#  ('G06F', 'G01D', 1),
#  ('E04F', 'B65G', 1),
#  ('C10H', 'C10B', 1),
#  ('D04H', 'B29D', 1),
#  ('G01N', 'B65D', 1),
#  ('H04N', 'B25J', 1),
#  ('H05K', 'B60K', 1),
#  ('G06F', 'C09J', 1),
#  ('G01L', 'G01B', 1),
#  ('G06F', 'A61B', 1),
#  ('B28C', 'B01F', 1),
#  ('H01L', 'G01N', 1),
#  ('C12P', 'C08G', 2),
#  ('C09D', 'B41J', 1),
#  ('B64C', 'B60R', 1),
#  ('G01R', 'B60R', 1),
#  ('G07D', 'B65H', 1),
#  ('G01C', 'B60W', 1),
#  ('C09J', 'C08L', 3),
#  ('C07K', 'C07H', 5),
#  ('F01D', 'B22F', 1),
#  ('B25G', 'B25B', 1),
#  ('F16B', 'A44B', 1),
#  ('G01L', 'B81C', 1),
#  ('G01V', 'B60R', 1),
#  ('B62D', 'B61B', 1),
#  ('A61K', 'A01N', 7),
#  ('F16G', 'E02F', 1),
#  ('G01S', 'B60W', 1),
#  ('G01N', 'G01L', 1),
#  ('C12N', 'A01K', 2),
#  ('F01D', 'B64C', 2),
#  ('C08K', 'B60C', 6),
#  ('B63G', 'B62D', 1),
#  ('H05B', 'F26B', 1),
#  ('E04B', 'C08L', 1),
#  ('B44C', 'B23K', 1),
#  ('C08L', 'C08B', 3),
#  ('C08L', 'B60C', 6),
#  ('F21Y', 'C08F', 1),
#  ('B65D', 'B62B', 1),
#  ('B60N', 'A47B', 1),
#  ('C08K', 'A41D', 1),
#  ('H01L', 'C08L', 2),
#  ('B65B', 'A61J', 2),
#  ('B65D', 'B05B', 1),
#  ('G01F', 'B64D', 1),
#  ('F02B', 'B63H', 1),
#  ('D06F', 'B67D', 1),
#  ('E02F', 'B64D', 1),
#  ('F04C', 'F01C', 1),
#  ('B64C', 'B23Q', 2),
#  ('B65D', 'B29C', 4),
#  ('G01C', 'B64D', 1),
#  ('G01V', 'B60L', 1),
#  ('C09J', 'C08G', 5),
#  ('C08G', 'B01J', 2),
#  ('B62D', 'B60H', 1),
#  ('B82Y', 'B29K', 1),
#  ('C08L', 'B32B', 7),
#  ('E06B', 'E05F', 1),
#  ('H01M', 'C01G', 2),
#  ('B64D', 'A62C', 1),
#  ('G10K', 'B60R', 1),
#  ('H05B', 'B60S', 1),
#  ('B60K', 'A01D', 1),
#  ('B25H', 'B23Q', 1),
#  ('C12P', 'C07H', 5),
#  ('C08G', 'B32B', 7),
#  ('G01N', 'A01K', 2),
#  ('G06Q', 'B64C', 1),
#  ('B29C', 'A47L', 1),
#  ('G06T', 'B60R', 1),
#  ('H02H', 'G08B', 1),
#  ('B32B', 'B29C', 14),
#  ('C30B', 'B82Y', 1),
#  ('C08G', 'A61K', 2),
#  ('C07C', 'A61Q', 1),
#  ('C08K', 'B82Y', 1),
#  ('C22C', 'B24D', 1),
#  ('C09J', 'B29C', 3),
#  ('H01F', 'G11B', 1),
#  ('C11B', 'C08J', 1),
#  ('G10K', 'B32B', 1),
#  ('F02K', 'B64G', 1),
#  ('H02J', 'B60R', 3),
#  ('C12N', 'A23G', 1),
#  ('H01M', 'C09D', 1),
#  ('C02F', 'B09C', 1),
#  ('F02C', 'C01B', 1),
#  ('G01C', 'B64G', 1),
#  ('C08F', 'C07F', 2),
#  ('C08K', 'C07D', 3),
#  ('G05D', 'B61L', 2),
#  ('B60C', 'B29C', 1),
#  ('C08L', 'C08G', 12),
#  ('F28F', 'B32B', 1),
#  ('G05D', 'B61C', 1),
#  ('B60R', 'B60N', 5),
#  ('H01L', 'C01B', 1),
#  ('F21V', 'B64D', 1),
#  ('C08F', 'C07C', 2),
#  ('C12P', 'A01N', 1),
#  ('A61M', 'A61B', 1),
#  ('F02B', 'C10L', 1),
#  ('C07K', 'A61K', 44),
#  ('C22C', 'B21C', 1),
#  ('D06F', 'A47L', 2),
#  ('B60K', 'B60H', 1),
#  ('C09D', 'C04B', 3),
#  ('C12P', 'C01B', 1),
#  ('G09F', 'B65C', 2),
#  ('B29D', 'B29B', 1),
#  ('F16B', 'B64C', 1),
#  ('C12M', 'C07D', 1),
#  ('C08K', 'C07B', 1),
#  ('F04D', 'B23C', 1),
#  ('A47L', 'A47K', 1),
#  ('C04B', 'B28B', 1),
#  ('C07J', 'B01J', 1),
#  ('B32B', 'A47L', 1),
#  ('C01G', 'B82Y', 2),
#  ('E21B', 'C04B', 2),
#  ('B23P', 'B22F', 2),
#  ('C22B', 'C10B', 1),
#  ('H04M', 'H04B', 1),
#  ('C08G', 'C03C', 1),
#  ('B29C', 'B28D', 1),
#  ('H01L', 'B24B', 2),
#  ('F01D', 'B64D', 3),
#  ('C09B', 'C07D', 1),
#  ('B44F', 'B32B', 1),
#  ('H01L', 'F21Y', 1),
#  ('B64C', 'B60T', 1),
#  ('C12P', 'A61K', 4),
#  ('B33Y', 'B29L', 1),
#  ('C07J', 'C07F', 1),
#  ('H01B', 'C01G', 1),
#  ('G09G', 'B32B', 1),
#  ('F41H', 'B29C', 1),
#  ('C07K', 'C07F', 1),
#  ('C09D', 'B05D', 2),
#  ('H04W', 'G05D', 1),
#  ('B25H', 'B23B', 1),
#  ('C08K', 'B29D', 1),
#  ('C08G', 'C07F', 1),
#  ('B81B', 'B01J', 1),
#  ('B29C', 'B05D', 1),
#  ('C07F', 'C07B', 4),
#  ('D06F', 'B65D', 1),
#  ('H01F', 'B41M', 1),
#  ('C09J', 'C04B', 2),
#  ('F21V', 'B60Q', 1),
#  ('G08C', 'B60C', 1),
#  ('H01L', 'C09G', 3),
#  ('C08F', 'B29C', 1),
#  ('D06F', 'A47K', 1),
#  ('B67D', 'A47L', 1),
#  ('B33Y', 'B29K', 1),
#  ('G08B', 'B60Q', 2),
#  ('C08K', 'B29K', 3),
#  ('E05F', 'B62D', 1),
#  ('B65G', 'B05C', 1),
#  ('F16K', 'F15B', 1),
#  ('F16D', 'B60K', 1),
#  ('G08B', 'G07C', 1),
#  ('B44C', 'B32B', 1),
#  ('C12Q', 'B01F', 1),
#  ('B65C', 'B60B', 1),
#  ('C08K', 'C08F', 6),
#  ('A61J', 'A61B', 1),
#  ('F21V', 'B60R', 1),
#  ('B29K', 'B23P', 1),
#  ('H01S', 'G01N', 1),
#  ('F02B', 'C23F', 1),
#  ('F01B', 'B60K', 1),
#  ('F16H', 'B66B', 1),
#  ('F16B', 'B25B', 1),
#  ('C22B', 'C10K', 1),
#  ('F16F', 'B60N', 2),
#  ('F41H', 'B29K', 1),
#  ('H01L', 'H01B', 1),
#  ('G02F', 'F21V', 1),
#  ('C12Q', 'C07H', 5),
#  ('D21F', 'D21B', 1),
#  ('G05D', 'B60W', 2),
#  ('C25D', 'C09D', 1),
#  ('H01Q', 'G01V', 1),
#  ('B44C', 'B29C', 2),
#  ('H04L', 'B25J', 1),
#  ('C07F', 'A61M', 1),
#  ('F21V', 'B64F', 1),
#  ('C12P', 'A61L', 1),
#  ('G01P', 'F28D', 1),
#  ('H01F', 'B82Y', 1),
#  ('C07B', 'B01J', 1),
#  ('F04C', 'B27B', 1),
#  ('B44B', 'B41K', 1),
#  ('F01N', 'B60K', 2),
#  ('C40B', 'C12Q', 1),
#  ('G01M', 'B25J', 1),
#  ('H02H', 'H01M', 1),
#  ('F01D', 'B23P', 1),
#  ('C01B', 'B82Y', 1),
#  ('H01Q', 'B60L', 1),
#  ('B25J', 'B05C', 1),
#  ('H02P', 'B65D', 1),
#  ('C07H', 'A61K', 7),
#  ('B32B', 'B29K', 3),
#  ('C11C', 'C10B', 1),
#  ('C09K', 'C01B', 1),
#  ('C08L', 'A61K', 1),
#  ('C12N', 'B09C', 1),
#  ('A61M', 'A61L', 1),
#  ('G01N', 'B25J', 1),
#  ('C09K', 'B82Y', 1),
#  ('B27C', 'B23B', 1),
#  ('G06T', 'G02B', 1),
#  ('B65C', 'B32B', 1),
#  ('H01M', 'H01L', 1),
#  ('F16K', 'B29C', 1),
#  ('B32B', 'B21D', 1),
#  ('C22C', 'B33Y', 1),
#  ('C08K', 'A61K', 1),
#  ('B66D', 'B64D', 1),
#  ('G08B', 'B60R', 1),
#  ('C07B', 'A61K', 2),
#  ('C25D', 'C08G', 1),
#  ('G08G', 'G06K', 1),
#  ('B01J', 'B01F', 2),
#  ('C07C', 'A01N', 1),
#  ('G01N', 'B66C', 1),
#  ('C08L', 'B05D', 3),
#  ('G01N', 'G01B', 1),
#  ('G08G', 'G06Q', 1),
#  ('B60J', 'B25H', 1),
#  ('G09F', 'B32B', 1),
#  ('B26B', 'A61B', 1),
#  ('G02F', 'C08G', 1),
#  ('C10K', 'B29B', 1),
#  ('B63H', 'B60F', 1),
#  ('C12N', 'A01H', 2),
#  ('B65D', 'B64D', 1),
#  ('C08K', 'C04B', 2),
#  ('C08F', 'B60C', 2),
#  ('C01B', 'A01N', 1),
#  ('G06F', 'B65D', 1),
#  ('C01F', 'C01B', 1),
#  ('C09K', 'C08G', 4),
#  ('B67D', 'B05B', 1),
#  ('G06F', 'G05D', 6),
#  ('B29C', 'B28B', 2),
#  ('H04W', 'B60W', 1),
#  ('B41N', 'B41F', 1),
#  ('C09J', 'C09D', 2),
#  ('F04B', 'C12M', 1),
#  ('C23F', 'C09G', 1),
#  ('G09F', 'B60B', 1),
#  ('B64D', 'B25J', 1),
#  ('F21K', 'C09K', 1),
#  ('E04F', 'E04C', 1),
#  ('G05D', 'B25J', 2),
#  ('G09G', 'G06F', 2),
#  ('G07F', 'G06F', 1),
#  ('D04B', 'B65H', 1),
#  ('C08J', 'B29L', 4),
#  ('G09G', 'C08G', 1),
#  ('B60C', 'B29D', 1),
#  ('H02K', 'C09K', 1),
#  ('B66D', 'B63C', 1),
#  ('C10H', 'C01B', 1),
#  ('C08G', 'C08F', 5),
#  ('G01M', 'B23P', 1),
#  ('H02K', 'B60K', 1),
#  ('F16D', 'B60B', 1),
#  ('G05D', 'B60L', 3),
#  ('F21V', 'C08F', 1),
#  ('F16M', 'B42F', 1),
#  ('G05D', 'B60R', 2),
#  ('F25D', 'B29C', 1),
#  ('C08L', 'C07F', 1),
#  ('F02K', 'B64D', 1),
#  ('B66C', 'B63B', 1),
#  ('B60N', 'B29L', 2),
#  ('C07K', 'A23L', 2),
#  ('H05B', 'B41M', 1),
#  ('B42D', 'B41M', 1),
#  ('B60Q', 'B60N', 1),
#  ('G01V', 'B63G', 1),
#  ('H05B', 'B05B', 1),
#  ('G01N', 'C07C', 1),
#  ('B23Q', 'B23C', 2),
#  ('C10M', 'C07C', 1),
#  ('G07C', 'B60W', 1),
#  ('C09D', 'A41D', 1),
#  ('B82Y', 'B01J', 1),
#  ('G08B', 'G01R', 1),
#  ('C23C', 'C22C', 2),
#  ('H01L', 'F21K', 1),
#  ('G05G', 'B25J', 1),
#  ('H04R', 'B81B', 1),
#  ('F41H', 'C08J', 1),
#  ('B42D', 'B05D', 1),
#  ('C12Q', 'C12M', 4),
#  ('B82Y', 'B29L', 1),
#  ('G01L', 'B81B', 1),
#  ('D04H', 'B29B', 1),
#  ('C09D', 'B43L', 1),
#  ('F04C', 'A01G', 1),
#  ('C12P', 'C12M', 4),
#  ('C09D', 'C08K', 12),
#  ('G06T', 'G05B', 2),
#  ('E21F', 'B65G', 1),
#  ('B67D', 'A47K', 2),
#  ('H01L', 'C23F', 1),
#  ('B32B', 'B01D', 1),
#  ('H01M', 'B62J', 1),
#  ('F02N', 'B60Q', 1),
#  ('B63B', 'A47C', 1),
#  ('B29K', 'B28D', 1),
#  ('C11D', 'A47L', 1),
#  ('B29C', 'A61J', 1),
#  ('G08G', 'B60L', 1),
#  ('B60C', 'A61L', 1),
#  ('G01L', 'B66C', 1),
#  ('G05B', 'B25J', 3),
#  ('H01F', 'B05D', 1),
#  ('C12M', 'C07H', 2),
#  ('C09K', 'C04B', 3),
#  ('B65D', 'A61B', 1),
#  ('F16H', 'F16D', 1),
#  ('C08K', 'C08G', 6),
#  ('E02F', 'E02D', 1),
#  ('C09D', 'C07D', 2),
#  ('C10K', 'B01D', 1),
#  ('B63B', 'B60J', 1),
#  ('C08L', 'B65G', 1),
#  ('B60C', 'A61M', 1),
#  ('B62D', 'B25H', 1),
#  ('F16C', 'F15B', 1),
#  ('E21F', 'E21C', 1),
#  ('F01D', 'B23K', 1),
#  ('F16D', 'B66B', 1),
#  ('G01N', 'C07D', 1),
#  ('C07D', 'B01J', 6),
#  ('D06F', 'C11D', 1),
#  ('B60R', 'B60Q', 5),
#  ('C11D', 'A61K', 2),
#  ('F16K', 'F01D', 1),
#  ('B60P', 'B60J', 1),
#  ('C02F', 'B01F', 1),
#  ('G06K', 'B60R', 1),
#  ('D04H', 'B29K', 1),
#  ('F02B', 'B60K', 1),
#  ('F28D', 'C22C', 1),
#  ('C05B', 'C02F', 1),
#  ('C08L', 'B29D', 1),
#  ('A61N', 'A01N', 1),
#  ('F04B', 'B01J', 1),
#  ('F24J', 'B01D', 1),
#  ('B64C', 'B29C', 2),
#  ('H04L', 'B60L', 1),
#  ('B62D', 'B25J', 1),
#  ('A61P', 'A61K', 1),
#  ('B66C', 'B25J', 2),
#  ('D21F', 'B29C', 1),
#  ('F02B', 'C10J', 1),
#  ('G05B', 'B23Q', 1),
#  ('B01F', 'B01D', 1),
#  ('G06F', 'F04C', 1),
#  ('B65G', 'B25J', 1),
#  ('F16C', 'B65H', 1),
#  ('B66C', 'B62D', 1),
#  ('B33Y', 'B22F', 2),
#  ('G09B', 'F16F', 1),
#  ('F16K', 'B23P', 1),
#  ('B64F', 'B60C', 1),
#  ('B64F', 'B23B', 2),
#  ('C12Q', 'C07D', 1),
#  ('B67C', 'B65G', 1),
#  ('B61F', 'B61B', 1),
#  ('B05D', 'B01D', 1),
#  ('B29B', 'B01D', 1),
#  ('B63H', 'B63G', 1),
#  ('B65H', 'B65B', 1),
#  ('C08J', 'B82Y', 1),
#  ('B23K', 'B21D', 1),
#  ('B65G', 'B65B', 1),
#  ('C11D', 'C07C', 1),
#  ('E21B', 'B23P', 1),
#  ('B64D', 'B29L', 1),
#  ('C07H', 'A23L', 1),
#  ('G06K', 'B64D', 2),
#  ('G08G', 'G05D', 2),
#  ('B60N', 'B29C', 2),
#  ('B65G', 'A01C', 1),
#  ('C09K', 'C03B', 1),
#  ('G06K', 'G01S', 1),
#  ('H01R', 'B60R', 1),
#  ('H01M', 'B82Y', 1),
#  ('G05D', 'G05B', 1),
#  ('B29L', 'B23D', 1),
#  ('H02J', 'G01V', 1),
#  ('G05D', 'F15B', 1),
#  ('E02D', 'B66D', 1),
#  ('B64D', 'B29K', 1),
#  ('H01M', 'C01B', 1),
#  ('G05G', 'B60K', 1),
#  ('G02B', 'B60R', 1),
#  ('B29C', 'B29B', 5),
#  ('F02K', 'F01D', 1),
#  ('A61Q', 'A61K', 2),
#  ('H05K', 'B60Q', 1),
#  ('B23Q', 'B23K', 1),
#  ('B66D', 'B66B', 1),
#  ('C08L', 'C08C', 1),
#  ('H05K', 'H02K', 1),
#  ('C08J', 'B32B', 10),
#  ('C12M', 'B01J', 1),
#  ('E02B', 'C02F', 1),
#  ('B60R', 'A44B', 1),
#  ('C09D', 'C01G', 1),
#  ('H02J', 'B60L', 9),
#  ('F16L', 'B60R', 1),
#  ('C10K', 'C10B', 1),
#  ('F17C', 'B32B', 1),
#  ('G01N', 'B01L', 2),
#  ('B65D', 'A61J', 3),
#  ('H05B', 'B41J', 1),
#  ('G01S', 'B60Q', 1),
#  ('H01L', 'B24D', 1),
#  ('H04N', 'B60R', 1),
#  ('F15B', 'B64D', 1),
#  ('B60T', 'B60R', 1),
#  ('B60N', 'A44B', 1),
#  ('B60N', 'B32B', 1),
#  ('C07C', 'A61L', 2),
#  ('F02N', 'B64C', 1),
#  ('C08K', 'C08C', 2),
#  ('C12N', 'C08B', 1),
#  ('F16G', 'B29D', 1),
#  ('E04B', 'C04B', 1),
#  ('C08L', 'C08J', 17),
#  ('B44C', 'A47B', 1),
#  ('B31B', 'B29K', 1),
#  ('B60C', 'B60B', 1),
#  ('F28C', 'F28B', 1),
#  ('F26B', 'B41M', 1),
#  ('C12P', 'C12N', 17),
#  ('C22C', 'B32B', 2),
#  ('F21V', 'C09K', 1),
#  ('F16D', 'B64C', 1),
#  ('G06K', 'B41J', 1),
#  ('C23C', 'C04B', 1),
#  ('G08B', 'G06N', 1),
#  ('C05F', 'C05C', 1),
#  ('F16D', 'B60W', 2),
#  ('D06M', 'C08K', 1),
#  ('D07B', 'B60C', 1),
#  ('D21B', 'B29K', 1),
#  ('C09C', 'C01G', 1),
#  ('C09K', 'B28C', 1),
#  ('C04B', 'B01J', 1),
#  ('H04N', 'H01Q', 1),
#  ('B30B', 'B29C', 1),
#  ('C10G', 'B01D', 1),
#  ('B63C', 'A41D', 1),
#  ('C23F', 'B63H', 1),
#  ('B01L', 'A61M', 1),
#  ('H02H', 'G01R', 1),
#  ('H01L', 'B65G', 1),
#  ('C12N', 'C12M', 4),
#  ('F28F', 'C22C', 1),
#  ('C04B', 'B32B', 3),
#  ('C09K', 'C09G', 2),
#  ('G03F', 'C08F', 1),
#  ('H01L', 'B01J', 2),
#  ('C10B', 'C07C', 1),
#  ('E01B', 'A63G', 1),
#  ('C23C', 'B23H', 1),
#  ('C08K', 'C08J', 11),
#  ('H02J', 'G08B', 1),
#  ('G08B', 'B60W', 2),
#  ('B33Y', 'A61B', 1),
#  ('G06F', 'B60L', 3),
#  ('G01S', 'B60L', 1),
#  ('B64D', 'B60C', 1),
#  ('B65C', 'B44C', 1),
#  ('E02F', 'B66D', 1),
#  ('B29L', 'A61J', 1),
#  ('G06F', 'C08G', 1),
#  ('C09J', 'B05C', 1),
#  ('H01L', 'B29C', 1),
#  ('C08C', 'B32B', 1),
#  ('H04B', 'B60R', 1),
#  ('H01M', 'C10J', 1),
#  ('H02P', 'H02K', 1),
#  ('A23L', 'A23G', 1),
#  ('C22C', 'B23H', 1),
#  ('B65B', 'B01J', 1),
#  ('F16B', 'B42F', 1),
#  ('B01J', 'B01D', 3),
#  ('F15B', 'B23P', 1),
#  ('H04M', 'B60L', 1),
#  ('D04B', 'D01H', 1),
#  ('B62D', 'B60K', 3),
#  ('H01M', 'B60K', 1),
#  ('C08J', 'A43D', 1),
#  ('C01B', 'B01F', 1),
#  ('B23P', 'B21D', 1),
#  ('C10K', 'B09B', 1),
#  ('G05B', 'E05B', 1),
#  ('F16B', 'B60K', 1),
#  ('B64F', 'B29K', 1),
#  ('B64F', 'B29L', 2),
#  ('A61K', 'A01K', 2),
#  ('B23K', 'B23C', 1),
#  ('D21H', 'B32B', 1),
#  ('G06T', 'G05G', 1),
#  ('B62D', 'B60D', 3),
#  ('B32B', 'A61L', 1),
#  ('C08K', 'C01G', 1),
#  ('C08K', 'B29L', 2),
#  ('F02C', 'F02B', 1),
#  ('B65B', 'B01L', 3),
#  ('H01M', 'H01B', 1),
#  ('B64C', 'B29L', 2),
#  ('B29L', 'A61L', 1),
#  ('B26F', 'A61F', 1),
#  ('C08G', 'B29K', 2),
#  ('C09J', 'C08K', 2),
#  ('B29C', 'B01D', 1),
#  ('G01C', 'B60K', 2),
#  ('F15B', 'A62B', 1),
#  ('B61C', 'B60L', 2),
#  ('D01D', 'B01J', 1),
#  ('C08K', 'C07C', 1),
#  ('C09D', 'B01J', 1),
#  ('C05G', 'C05F', 1),
#  ('G11B', 'B82Y', 1),
#  ('F16F', 'B60G', 2),
#  ('B65D', 'A47K', 2),
#  ('C12P', 'C07K', 5),
#  ('D21C', 'C12M', 1),
#  ('B63C', 'B25J', 1),
#  ('H02M', 'B60L', 1),
#  ('F16H', 'F01N', 1),
#  ('C04B', 'B29B', 1),
#  ('G06F', 'B60W', 3),
#  ('F41H', 'B82Y', 1),
#  ('G07C', 'B60C', 1),
#  ('H01F', 'B60L', 1),
#  ('F24J', 'C01D', 1),
#  ('G01H', 'B65H', 1),
#  ('B60Q', 'B60C', 1),
#  ('H04N', 'G05G', 1),
#  ('C09D', 'B60C', 1),
#  ('C08G', 'B29C', 3),
#  ('B01L', 'A61J', 1),
#  ('G08G', 'B60H', 1),
#  ('D04H', 'B29C', 1),
#  ('F15B', 'B25J', 1),
#  ('C03C', 'B65D', 1),
#  ('B60R', 'B60L', 4),
#  ('C08F', 'A61Q', 1),
#  ('B62D', 'B60F', 1),
#  ('B29D', 'B05C', 1),
#  ('C07D', 'C07B', 4),
#  ('H01M', 'G08B', 1),
#  ('B23H', 'B21C', 1),
#  ('C22C', 'B23P', 1),
#  ('B60W', 'B60T', 1),
#  ('D01F', 'B01J', 1),
#  ('B29K', 'A43D', 1),
#  ('B62J', 'B60R', 1),
#  ('B41K', 'B30B', 1),
#  ('H02P', 'H01M', 1),
#  ('B27M', 'B23B', 1),
#  ('B62L', 'B62K', 1),
#  ('C10G', 'B01J', 2),
#  ('C07F', 'C07D', 9),
#  ('C09C', 'C04B', 1),
#  ('C11D', 'A61Q', 2),
#  ('B60K', 'B60G', 1),
#  ('G06F', 'B33Y', 1),
#  ('F16B', 'B29L', 2),
#  ('C03C', 'B32B', 1),
#  ('B41J', 'B26D', 1),
#  ('B28D', 'B23D', 1),
#  ('C12N', 'C07K', 30),
#  ('B67B', 'B01L', 1),
#  ('C12N', 'C11B', 1),
#  ('F04C', 'B65D', 1),
#  ('B67B', 'B65B', 2),
#  ('C08F', 'C07D', 1),
#  ('G01M', 'F04D', 1),
#  ('C12N', 'B81B', 1),
#  ('D06M', 'C04B', 1),
#  ('G02F', 'C08J', 2),
#  ('B25H', 'A47B', 2),
#  ('G01F', 'F28D', 1),
#  ('H05K', 'C08G', 2),
#  ('H01S', 'C09K', 1),
#  ('F16B', 'B29K', 1),
#  ('G09G', 'C08F', 1),
#  ('C08G', 'C07D', 1),
#  ('B65G', 'B65C', 1),
#  ('F02N', 'B60H', 1),
#  ('A61M', 'A61J', 1),
#  ('C09J', 'B32B', 7),
#  ('G09G', 'B60K', 1),
#  ('B29L', 'B29D', 4),
#  ('C08F', 'A61L', 1),
#  ('B41J', 'B41C', 1),
#  ('B66D', 'B25J', 1),
#  ('C08L', 'C04B', 6),
#  ('F25B', 'C09K', 1),
#  ('C12N', 'A61B', 1),
#  ('C03B', 'A61L', 1),
#  ('B26D', 'B25J', 1),
#  ('G02F', 'F21K', 1),
#  ('G08G', 'F02N', 1),
#  ('H02H', 'B60R', 1),
#  ('G01N', 'C12N', 11),
#  ('G06F', 'B25J', 5),
#  ('C08J', 'B29D', 2),
#  ('A61K', 'A23L', 1),
#  ('G01N', 'A61N', 2),
#  ('G06Q', 'B65D', 1),
#  ('C22C', 'C09C', 1),
#  ('B64D', 'B60N', 1),
#  ('C08J', 'C08F', 3),
#  ('E06B', 'B60J', 3),
#  ('B25B', 'B23Q', 1),
#  ('B05B', 'A47K', 1),
#  ('F28C', 'C02F', 2),
#  ('G01C', 'B61C', 1),
#  ('B32B', 'B23K', 5),
#  ('G06F', 'B60R', 2),
#  ('F21S', 'B60Q', 3),
#  ('F28F', 'F28D', 1),
#  ('E21B', 'B28C', 1),
#  ('B29C', 'B23P', 1),
#  ('C07C', 'B01D', 2),
#  ('G01C', 'B60L', 1),
#  ('B32B', 'B29L', 6),
#  ('H05K', 'B60L', 1),
#  ('B60T', 'B60K', 1),
#  ('C08B', 'C07H', 1),
#  ('C10L', 'A61K', 1),
#  ('B60C', 'B05D', 1),
#  ('H01M', 'B60R', 2),
#  ('C08J', 'B60C', 2),
#  ('C08G', 'C07C', 3),
#  ('G01N', 'A61L', 1),
#  ('F24J', 'B63B', 1),
#  ('B60W', 'B60L', 8),
#  ('B65D', 'B31B', 4),
#  ('C07K', 'C07C', 2),
#  ('E04H', 'B60J', 1),
#  ('B61L', 'B61B', 1),
#  ('G01N', 'C09B', 1),
#  ('C01D', 'B01D', 1),
#  ('C02F', 'B08B', 1),
#  ('D21F', 'B29K', 1),
#  ('C23C', 'B32B', 3),
#  ('C07C', 'C01B', 2),
#  ('B81C', 'B81B', 7),
#  ('H01Q', 'G01S', 1),
#  ('G02F', 'C07C', 1),
#  ('F21Y', 'F21S', 1),
#  ('C01G', 'B05D', 1),
#  ('G07C', 'B66B', 1),
#  ('F28D', 'B23K', 1),
#  ('F28D', 'B64D', 1),
#  ('F02K', 'F02C', 1),
#  ('G06F', 'G01C', 2),
#  ('E21B', 'B24D', 1),
#  ('G06Q', 'G05D', 1),
#  ('E21B', 'E02D', 1),
#  ('H01F', 'B42D', 1),
#  ('G01N', 'C07K', 15),
#  ('B66B', 'B65G', 1),
#  ('H01B', 'B60R', 1),
#  ('G01N', 'C07H', 3),
#  ('F28B', 'C02F', 1),
#  ('B23Q', 'B23B', 4),
#  ('C08F', 'B32B', 2),
#  ('B32B', 'A61J', 1),
#  ('B23P', 'B23K', 2),
#  ('B29L', 'B23K', 1),
#  ('C10L', 'C01B', 1),
#  ('C08J', 'B33Y', 1),
#  ('B32B', 'B26F', 1),
#  ('C12Q', 'C12P', 5),
#  ('C08K', 'B05D', 3),
#  ('C07K', 'A01H', 2),
#  ('H01L', 'G02F', 1),
#  ('C12N', 'C08G', 3),
#  ('G08G', 'B60W', 2),
#  ('C04B', 'B29L', 2),
#  ('B41F', 'B30B', 1),
#  ('B60P', 'B60D', 1),
#  ('B65D', 'B25H', 1),
#  ('F28D', 'C23C', 1),
#  ('B64F', 'B23Q', 2),
#  ('F21Y', 'F21K', 1),
#  ('G07C', 'B64F', 1),
#  ('G01C', 'B61L', 2),
#  ('C07C', 'A61K', 6),
#  ('G06K', 'E02F', 1),
#  ('G01N', 'B05D', 1),
#  ('D01F', 'C07D', 1),
#  ('H01S', 'H01L', 1),
#  ('B29C', 'B22F', 1),
#  ('E21B', 'B01F', 1),
#  ('C12M', 'C09B', 1),
#  ('F21Y', 'F21V', 1),
#  ('B25B', 'B23P', 1),
#  ('F16H', 'B60L', 1),
#  ('B67B', 'B29D', 1),
#  ('C03C', 'A61L', 1),
#  ('B32B', 'B29D', 4),
#  ('B65D', 'B29B', 1),
#  ('C04B', 'B23C', 1),
#  ('E21B', 'C08G', 1),
#  ('C04B', 'B29K', 2),
#  ('F02N', 'B60T', 1),
#  ('F16C', 'B41J', 1),
#  ('C09G', 'C01F', 1),
#  ('C12Q', 'B01L', 2),
#  ('B29C', 'A61L', 1),
#  ('B64D', 'B29C', 1),
#  ('G08G', 'B64D', 1),
#  ('B64C', 'B63H', 1),
#  ('C08B', 'A61K', 2),
#  ('G08G', 'B61L', 1),
#  ('G09G', 'C08C', 1),
#  ('G01N', 'B67B', 1),
#  ('H02N', 'B41J', 1),
#  ('B65B', 'B41J', 2),
#  ('F04B', 'B60T', 1),
#  ('B65G', 'B63B', 1),
#  ('H01L', 'C09J', 2),
#  ('H05K', 'C08J', 1),
#  ('B25F', 'B23D', 1),
#  ('B60G', 'A01D', 1),
#  ('H02P', 'B62B', 1),
#  ('F28F', 'C23C', 1),
#  ('F16M', 'F16B', 1),
#  ('H05B', 'B29C', 1),
#  ('C12N', 'A61N', 2),
#  ('D06M', 'C09D', 2),
#  ('C12M', 'C11B', 1),
#  ('B32B', 'B05D', 3),
#  ('F02C', 'C10L', 1),
#  ('B29C', 'B23D', 1),
#  ('E04H', 'B63B', 2),
#  ('C11D', 'C07D', 1),
#  ('C07C', 'C07B', 2),
#  ('B65D', 'B60S', 1),
#  ('B67D', 'B65B', 1),
#  ('G06K', 'G05D', 1),
#  ('H01L', 'C09K', 4),
#  ('G01N', 'A61K', 14),
#  ('H01M', 'C08K', 1),
#  ('C12P', 'A23G', 1),
#  ('C11B', 'A61L', 1),
#  ('C12P', 'C11B', 1),
#  ('F16H', 'B31D', 1),
#  ('C08L', 'B29C', 7),
#  ('F25D', 'B29B', 1),
#  ('E21B', 'B66D', 1),
#  ('C09D', 'B32B', 5),
#  ('B62B', 'B25H', 1),
#  ('C08G', 'C07K', 1),
#  ('C12N', 'A01N', 2),
#  ('E21B', 'C22C', 1),
#  ('G02B', 'C09J', 1),
#  ('G01P', 'B64F', 1),
#  ('C11D', 'C08F', 1),
#  ('H02J', 'G01R', 1),
#  ('H01M', 'C10L', 1),
#  ('H02H', 'B60L', 2),
#  ('A47J', 'A47B', 1),
#  ('C07K', 'C07D', 3),
#  ('C10G', 'B01F', 1),
#  ('F21K', 'C08F', 1),
#  ('C03B', 'B65D', 1),
#  ('B60R', 'B60K', 2),
#  ('A47J', 'A47F', 1),
#  ('C09J', 'B65G', 1),
#  ('C08G', 'A61L', 1),
#  ('C12Q', 'C09B', 2),
#  ('D21F', 'B29D', 1),
#  ('G08G', 'B60R', 1),
#  ('D21F', 'B29B', 1),
#  ('C08J', 'B29C', 9),
#  ('H05K', 'E05B', 1),
#  ('F15B', 'A01G', 1),
#  ('F28F', 'C10B', 1),
#  ('H02P', 'F16H', 1),
#  ('G02B', 'C12Q', 1),
#  ('B65D', 'B05C', 1),
#  ...]

# %% [markdown]
# ### 쌍대노드 간의 링크 강도 예측

# %%
p=nx.Graph()
p.add_weighted_edges_from(data_first)

# %% [markdown]
# ### adamic-adar 알고리즘의 활용

# %%
preds=nx.adamic_adar_index(p)

# %%
result_dic={}
for u,v,p in preds:
    result_dic[(u,v)]=p

# %%
result_dic
# Out:
# {('B25J', 'A01J'): 0,
#  ('G01C', 'F28F'): 0,
#  ('A01D', 'B60L'): 0,
#  ('A63F', 'C12M'): 0,
#  ('B23B', 'B05B'): 0.7553857282466059,
#  ('B04B', 'C12C'): 0,
#  ('B60N', 'B23B'): 0,
#  ('H04R', 'B60B'): 0,
#  ('F16J', 'B25D'): 0,
#  ('B32B', 'A47C'): 1.3067276426852328,
#  ('F01B', 'B29D'): 0,
#  ('A01K', 'B31B'): 0.2835784920513334,
#  ('A61H', 'B67C'): 0,
#  ('B25B', 'B33Y'): 0,
#  ('C11B', 'A47G'): 0,
#  ('D06F', 'G09B'): 0,
#  ('G01K', 'B25C'): 0.2422988705246811,
#  ('G01S', 'E02F'): 0,
#  ('B65D', 'B23C'): 0,
#  ('F02C', 'G01V'): 0,
#  ('B02C', 'F01N'): 0,
#  ('H01M', 'C08F'): 0.2769378934088574,
#  ('H01J', 'B23Q'): 0,
#  ('B65B', 'B22F'): 0,
#  ('G01S', 'B23K'): 0,
#  ('F17C', 'F21W'): 0,
#  ('B23D', 'A01M'): 0,
#  ('A61C', 'C08J'): 0.5081714561995331,
#  ('B65B', 'B64F'): 0,
#  ('G01R', 'F03C'): 0,
#  ('A63G', 'G07C'): 0,
#  ('G01S', 'B60K'): 0.5282985380273555,
#  ('G02C', 'H04W'): 0.6974184838380998,
#  ('H02K', 'F04B'): 0,
#  ('B32B', 'A21D'): 0.5905061684814683,
#  ('E03F', 'C07D'): 0,
#  ('A63C', 'B64D'): 0,
#  ('B25D', 'A23J'): 0,
#  ('G06Q', 'B67D'): 0,
#  ('C07H', 'C08G'): 0.265872585674852,
#  ('A63G', 'D04H'): 0,
#  ('F02C', 'A47L'): 0.2969742043733701,
#  ('B60N', 'B26F'): 0,
#  ('A63G', 'B21J'): 0,
#  ('H01C', 'C08K'): 0,
#  ('G01L', 'A41D'): 0.2422988705246811,
#  ('H02N', 'F04B'): 0,
#  ('A61B', 'F16L'): 1.1482231419034281,
#  ('G01L', 'B43K'): 0,
#  ('F17C', 'C09J'): 0,
#  ('C04B', 'B22C'): 0,
#  ('B01D', 'A21D'): 0.5905061684814683,
#  ('B08B', 'H01C'): 0.26425736993644544,
#  ('G09G', 'G21G'): 0,
#  ('C12P', 'F21V'): 0,
#  ('B22D', 'A62C'): 0,
#  ('A23P', 'A01G'): 0,
#  ('B24B', 'C12M'): 0,
#  ('E04B', 'A47G'): 1.3109516354479935,
#  ('B25C', 'A62B'): 0.2422988705246811,
#  ('A47L', 'B23Q'): 0,
#  ('A01M', 'A01C'): 0,
#  ('A47L', 'G01F'): 0.7901347325124599,
#  ('B64D', 'B60R'): 0.43429448190325176,
#  ('F01N', 'A42B'): 0,
#  ('B23D', 'H04Q'): 0,
#  ('C11B', 'A63J'): 0,
#  ('H04Q', 'B25B'): 0,
#  ('C10G', 'C12M'): 0,
#  ('F16C', 'B67C'): 0,
#  ('B25J', 'A21B'): 0,
#  ('F01M', 'B43M'): 0,
#  ('A63G', 'H04B'): 0.28599966750267436,
#  ('B25C', 'B01L'): 0,
#  ('E06B', 'F24F'): 0,
#  ('H01C', 'B23Q'): 0,
#  ('B07B', 'F04B'): 0,
#  ('A61J', 'B03C'): 0.4170323914242463,
#  ('C12P', 'E21B'): 0,
#  ('B25B', 'G07F'): 0,
#  ('C12C', 'A41D'): 0,
#  ('C01G', 'H04Q'): 0,
#  ('H02K', 'A42B'): 0,
#  ('B22D', 'G03B'): 0,
#  ('C07H', 'C09J'): 0,
#  ('B02C', 'B21J'): 0,
#  ('B60P', 'C01C'): 0,
#  ('B25B', 'H04L'): 0,
#  ('G21F', 'B03B'): 0,
#  ('A47J', 'B24B'): 0,
#  ('B04C', 'B25H'): 0,
#  ('A21D', 'C09D'): 0,
#  ('F17D', 'H04Q'): 0.33380820069533407,
#  ('B26D', 'G07C'): 0,
#  ('H01J', 'G08B'): 0,
#  ('C03C', 'F04B'): 0,
#  ('G09G', 'B23B'): 0,
#  ('B08B', 'F03C'): 0,
#  ('B31B', 'C08K'): 0,
#  ('B25B', 'C21D'): 0,
#  ('B05C', 'A41F'): 0,
#  ('A01F', 'B66F'): 0.43429448190325176,
#  ('A62C', 'A01C'): 0,
#  ('H01F', 'B62D'): 0,
#  ('F16C', 'H04R'): 0,
#  ('B26D', 'B65H'): 0,
#  ('B67C', 'B62D'): 0,
#  ('G06K', 'B06B'): 0,
#  ('B29C', 'G08B'): 0.5282985380273555,
#  ('B60L', 'F16L'): 0,
#  ('F01M', 'G06F'): 0,
#  ('B64D', 'F21W'): 0,
#  ('A61B', 'D04B'): 0.2969742043733701,
#  ('H01R', 'B33Y'): 0,
#  ('F25B', 'B64F'): 0,
#  ('C12P', 'F41H'): 0,
#  ('H05B', 'A23G'): 0.3284587387530511,
#  ('B04C', 'A45F'): 0,
#  ('B23Q', 'D04B'): 0,
#  ('A23P', 'B21C'): 0,
#  ('B29D', 'F21V'): 0,
#  ('G01G', 'B23P'): 0,
#  ('G01L', 'F27B'): 0,
#  ('B82Y', 'B66F'): 0,
#  ('A01K', 'F24C'): 0,
#  ('A63G', 'B25C'): 0,
#  ('A01H', 'B66F'): 0.40242960438184466,
#  ('E03B', 'B60T'): 0,
#  ('F17D', 'H05H'): 0,
#  ('A23C', 'F16L'): 0,
#  ('F25D', 'F16M'): 0.30692767643013485,
#  ('A61P', 'A47G'): 0,
#  ('F01M', 'A43B'): 0,
#  ('A63H', 'A62B'): 0,
#  ('A63C', 'B25J'): 0,
#  ('F24F', 'B02C'): 0,
#  ('C01B', 'B25H'): 0,
#  ('C07D', 'A61P'): 0.265872585674852,
#  ('B60K', 'A01F'): 0,
#  ('B05C', 'A61D'): 0.26425736993644544,
#  ('A22C', 'C07D'): 0,
#  ('A63F', 'B04B'): 0,
#  ('F25B', 'B60L'): 0,
#  ('B67C', 'C21C'): 0,
#  ('A45C', 'C07F'): 0,
#  ('C03C', 'A44C'): 0,
#  ('A61J', 'A46B'): 0.5905061684814683,
#  ('H01J', 'C11D'): 0.2769378934088574,
#  ('B07B', 'E03F'): 0,
#  ('G01N', 'G01K'): 0.5065562404611266,
#  ('F16B', 'C25D'): 0,
#  ('A22C', 'C01G'): 0,
#  ('F16J', 'B65H'): 0,
#  ('H01L', 'D04D'): 0,
#  ('C23F', 'A61P'): 0.2969742043733701,
#  ('E03B', 'A42B'): 0,
#  ('G01S', 'A61P'): 0,
#  ('A21C', 'A61B'): 0,
#  ('B23P', 'C08F'): 0.40242960438184466,
#  ('A61C', 'F25B'): 0,
#  ('G01M', 'C21D'): 0,
#  ('G09F', 'B05D'): 0,
#  ('B60P', 'B06B'): 0,
#  ('A63B', 'G02C'): 0.2422988705246811,
#  ('B22F', 'H01L'): 0,
#  ('G01C', 'A61J'): 0,
#  ('G01S', 'C01C'): 0,
#  ('B08B', 'A63F'): 0.36926937306885504,
#  ('H01B', 'B60T'): 0,
#  ('F02C', 'F24C'): 0,
#  ('B22D', 'A47F'): 0,
#  ('F21V', 'D04B'): 0,
#  ('G01C', 'G01G'): 0,
#  ('A01B', 'H01F'): 0,
#  ('B21K', 'F25B'): 0.2969742043733701,
#  ('B03C', 'G08G'): 0,
#  ('B04C', 'G03B'): 0,
#  ('B29L', 'F01N'): 0,
#  ('G09G', 'G06K'): 1.2088274129032957,
#  ('A45C', 'B60T'): 0,
#  ('A45C', 'C07C'): 0,
#  ('F01M', 'B25J'): 0,
#  ('C05G', 'F16N'): 0,
#  ('F01N', 'C09J'): 0.2769378934088574,
#  ('H01B', 'B22C'): 0,
#  ('C01B', 'A47F'): 0,
#  ('B65G', 'B25B'): 0,
#  ('B26B', 'F27B'): 0,
#  ('G21F', 'E02B'): 0,
#  ('B25B', 'H05K'): 0,
#  ('G01B', 'B64F'): 0,
#  ('C21C', 'A47B'): 0,
#  ('A43C', 'C07C'): 0,
#  ('B24B', 'C12C'): 0,
#  ('F16D', 'E02B'): 0,
#  ('G01L', 'G01G'): 0,
#  ('B43K', 'G01F'): 0,
#  ('A21C', 'B06B'): 0,
#  ('H01B', 'G08G'): 0,
#  ('B08B', 'B62D'): 0,
#  ('C01D', 'F16K'): 0,
#  ('A01G', 'A01K'): 0.8340427950033699,
#  ('B67D', 'C08L'): 0,
#  ('C05G', 'A47F'): 0,
#  ('E06B', 'B23B'): 0,
#  ('C01G', 'E02F'): 0,
#  ('G03B', 'G06M'): 0,
#  ('H02J', 'B01J'): 0,
#  ('A23K', 'B60P'): 0,
#  ('B33Y', 'B23C'): 0,
#  ('G01B', 'C04B'): 0,
#  ('C07F', 'F41H'): 0,
#  ('B09B', 'G07F'): 0,
#  ('B21D', 'F04D'): 0.6213349345596119,
#  ('G02B', 'B23Q'): 0,
#  ('B66F', 'A47G'): 0,
#  ('G08C', 'G05D'): 0.6004533465575299,
#  ('C12Q', 'F01B'): 0,
#  ('B25H', 'F16L'): 0,
#  ('C05G', 'B04C'): 0,
#  ('B65C', 'A23P'): 0,
#  ('C03C', 'B23K'): 0,
#  ('C10G', 'B60K'): 0,
#  ('B29K', 'G01V'): 0.2422988705246811,
#  ('B60L', 'F02D'): 0,
#  ('B26D', 'B33Y'): 0,
#  ('G01N', 'F24F'): 0.35295612386476116,
#  ('G01K', 'B03C'): 0,
#  ('A47K', 'E02F'): 0,
#  ('C01B', 'B26F'): 0,
#  ('A62B', 'C04B'): 0,
#  ('A23P', 'H04Q'): 0,
#  ('H01J', 'B43K'): 0,
#  ('E03B', 'B23C'): 0,
#  ('E03F', 'B64F'): 0,
#  ('F01B', 'H05H'): 0,
#  ('F24C', 'B64F'): 0,
#  ('B08B', 'H05K'): 0.36926937306885504,
#  ('A47D', 'F26B'): 0,
#  ('G01N', 'B64F'): 0.2769378934088574,
#  ('B65B', 'C07D'): 0,
#  ('G06Q', 'A01F'): 0,
#  ('C07H', 'B01L'): 0,
#  ('H01F', 'B60B'): 0,
#  ('C05G', 'B41J'): 0,
#  ('E06B', 'B03C'): 0,
#  ('F16C', 'A47D'): 0,
#  ('H04R', 'B23P'): 0,
#  ('H05K', 'F01N'): 0,
#  ('G01S', 'B08B'): 0.2422988705246811,
#  ('F21Y', 'H05B'): 0,
#  ('B29K', 'F27B'): 0,
#  ('F16J', 'A45F'): 0,
#  ('E21B', 'B31B'): 0,
#  ('G02F', 'F21W'): 0,
#  ('H04R', 'A47F'): 0,
#  ('G02B', 'B01J'): 0.8872075202344638,
#  ('B04C', 'B22C'): 0,
#  ('C07F', 'A47B'): 0,
#  ('B31B', 'C03C'): 0,
#  ('G21K', 'A47C'): 0,
#  ('H02N', 'H04L'): 0.953409470422291,
#  ('B43K', 'B23C'): 0,
#  ('G01S', 'C03C'): 0,
#  ('E06B', 'B43K'): 0,
#  ('A41F', 'G01M'): 0,
#  ('C02F', 'A01M'): 0,
#  ('G06T', 'B66F'): 0,
#  ('C09J', 'B23K'): 0,
#  ('B21D', 'B05D'): 0.36067376022224085,
#  ('H04R', 'B64D'): 0,
#  ('E04B', 'G06K'): 0,
#  ('A21D', 'C12R'): 0,
#  ('A23L', 'B23B'): 0,
#  ('A62D', 'B23C'): 0,
#  ('C11D', 'B60B'): 0,
#  ('A63F', 'A61Q'): 0,
#  ('C21D', 'F01N'): 0,
#  ('G06Q', 'H01B'): 0,
#  ('H05K', 'A01H'): 0,
#  ('B04B', 'D04H'): 0,
#  ('A61F', 'G01D'): 0.5282985380273555,
#  ('A01F', 'A46B'): 0,
#  ('F01M', 'A46B'): 0,
#  ('F17D', 'G05B'): 0.4170323914242463,
#  ('A23D', 'C09J'): 0,
#  ('B01J', 'B33Y'): 0,
#  ('F01M', 'H05H'): 0,
#  ('A21C', 'E02B'): 0,
#  ('C08B', 'B60B'): 0,
#  ('G21K', 'A01D'): 0,
#  ('A24F', 'B64D'): 0,
#  ('F27D', 'B31B'): 0,
#  ('B60S', 'F01B'): 0,
#  ('B67C', 'G06K'): 0,
#  ('G09B', 'G05B'): 1.8171243373326782,
#  ('B43M', 'A47B'): 0.2835784920513334,
#  ('F24C', 'F04B'): 0,
#  ('C07H', 'A47G'): 0,
#  ('A01J', 'B41J'): 0,
#  ('D06F', 'G01M'): 0,
#  ('B04C', 'A23G'): 0,
#  ('A41F', 'H05K'): 0,
#  ('F21W', 'A47G'): 1.3953835367768315,
#  ('F04B', 'G06M'): 0.26425736993644544,
#  ('D06F', 'A63J'): 0,
#  ('B21F', 'H04W'): 0,
#  ('A01J', 'C07D'): 0,
#  ('F17D', 'A47B'): 0,
#  ('G02B', 'A45D'): 0.265872585674852,
#  ('F04D', 'G07F'): 0,
#  ('B64D', 'A47G'): 1.0046377521129095,
#  ('B24B', 'G02C'): 0,
#  ('A43C', 'F16B'): 0,
#  ('C08L', 'G06M'): 0,
#  ('C01B', 'C03C'): 0.5428104790837094,
#  ('F24J', 'B21C'): 0,
#  ('G08B', 'F04B'): 0,
#  ('A47L', 'E04B'): 1.7047917907668682,
#  ('B09B', 'C23F'): 0,
#  ('A47L', 'F02D'): 0.2969742043733701,
#  ('C01B', 'F27D'): 0,
#  ('B26D', 'H05B'): 0.30692767643013485,
#  ('B01D', 'F24J'): 0,
#  ('G06Q', 'G01R'): 0.2422988705246811,
#  ('G09F', 'A63H'): 0,
#  ('B65G', 'B03D'): 0,
#  ('B67C', 'A01C'): 0,
#  ('B01F', 'G01M'): 0,
#  ('F21Y', 'F04D'): 0.318928988903801,
#  ('F28D', 'H05H'): 0,
#  ('A63F', 'A61L'): 0,
#  ('B29C', 'B41J'): 0.3898712452512801,
#  ('F16N', 'A61G'): 0,
#  ('G09F', 'G02C'): 0,
#  ('B01L', 'B82Y'): 0.2769378934088574,
#  ('B66F', 'A61G'): 0,
#  ('A01B', 'B21F'): 0,
#  ('C12R', 'A23G'): 0,
#  ('B09B', 'A61K'): 0.998285413853339,
#  ('C12P', 'G09B'): 0.265872585674852,
#  ('B07B', 'B23P'): 0,
#  ('A22C', 'B07B'): 0,
#  ('F16J', 'C01C'): 0,
#  ('B01D', 'B27B'): 0.2422988705246811,
#  ('H01F', 'B06B'): 0,
#  ('B60K', 'H01B'): 0,
#  ('B05C', 'A61B'): 1.5859921702965762,
#  ('G01C', 'C01G'): 0,
#  ('F28D', 'B01J'): 0.2969742043733701,
#  ('A61M', 'A63J'): 0,
#  ('B01J', 'G06T'): 0.3284587387530511,
#  ('A22C', 'C22F'): 0,
#  ('G02B', 'E06B'): 0,
#  ('B08B', 'G09F'): 0.3284587387530511,
#  ('A01B', 'B60S'): 0,
#  ('C22C', 'A01K'): 0,
#  ('A24F', 'A45D'): 0.5494510777261854,
#  ('C01D', 'B60R'): 0,
#  ('F17C', 'B25C'): 0,
#  ('B29C', 'F21V'): 0.7239600678543812,
#  ('A01C', 'B21C'): 0.3898712452512801,
#  ('A43D', 'F26B'): 0,
#  ('A23L', 'A44C'): 0,
#  ('A01B', 'B29D'): 0,
#  ('B65B', 'C12Q'): 0,
#  ('C12Q', 'C07D'): 0.5943313244279032,
#  ('F01B', 'G21G'): 0,
#  ('F24J', 'G05D'): 0,
#  ('A45D', 'B29C'): 0.265872585674852,
#  ('F17C', 'A61N'): 0,
#  ('B29D', 'A45F'): 0.6891324989752919,
#  ('B65H', 'G01V'): 0,
#  ('A01N', 'G06T'): 0,
#  ('B29K', 'E02F'): 0,
#  ('G21F', 'A45C'): 0,
#  ('B65B', 'H04N'): 0.4170323914242463,
#  ('G21K', 'G02F'): 0,
#  ('C25B', 'A61D'): 0,
#  ('B25B', 'C12M'): 0,
#  ('G09F', 'F21V'): 0,
#  ('C08B', 'F16B'): 0,
#  ('B64F', 'G06K'): 0.2769378934088574,
#  ('C21C', 'E01H'): 0,
#  ('C05G', 'C12N'): 0.8194619958060909,
#  ('B26B', 'F01N'): 0,
#  ('B24B', 'B65D'): 0,
#  ('A24F', 'A45C'): 0,
#  ('F02C', 'B67D'): 0,
#  ('G01K', 'G08C'): 0.2422988705246811,
#  ('A01G', 'G03B'): 0,
#  ('A24B', 'A01C'): 0,
#  ('A41D', 'C08G'): 0.2422988705246811,
#  ('C07K', 'A61G'): 0.26425736993644544,
#  ('A61N', 'A21B'): 0,
#  ('A61Q', 'H01B'): 1.0224290235861548,
#  ('B60S', 'B25H'): 0,
#  ('C05G', 'B21K'): 0,
#  ('A21C', 'C09D'): 0,
#  ('B32B', 'C01D'): 0.2969742043733701,
#  ('B43K', 'C01C'): 0,
#  ('E03F', 'B60B'): 0,
#  ('H02N', 'B62D'): 0,
#  ('F16J', 'F28D'): 0,
#  ('A01J', 'C12Q'): 0,
#  ('A61Q', 'B05B'): 0.2769378934088574,
#  ('B26B', 'E21B'): 0,
#  ('G10L', 'G01D'): 0.33380820069533407,
#  ('H01M', 'H04W'): 0,
#  ('B04B', 'B67C'): 0,
#  ('F02C', 'H04N'): 0,
#  ('C12C', 'A23J'): 0,
#  ('G01N', 'B67D'): 0,
#  ('A01F', 'A01C'): 0.8241657271545318,
#  ('A01C', 'C08G'): 0,
#  ('A63B', 'A41D'): 0.2422988705246811,
#  ('A45D', 'B09B'): 0,
#  ('C22F', 'B66F'): 0,
#  ('B01D', 'F16B'): 0.45511961331341866,
#  ('F02C', 'A47C'): 0,
#  ('H02J', 'B43M'): 0.2835784920513334,
#  ('F25D', 'C25D'): 0,
#  ('A22C', 'H04W'): 0,
#  ('F16C', 'H01M'): 0,
#  ('F01B', 'A47B'): 0,
#  ('A62B', 'A63J'): 0.45511961331341866,
#  ('G03B', 'E02F'): 0,
#  ('H05K', 'B01L'): 0,
#  ('G02B', 'F41H'): 0,
#  ('C08J', 'C07C'): 0.5428104790837094,
#  ('H01C', 'F02D'): 0,
#  ('B64D', 'F16N'): 0,
#  ('C12N', 'C03C'): 0.265872585674852,
#  ('G02B', 'C07D'): 0.265872585674852,
#  ('B67C', 'B60P'): 0,
#  ('B01F', 'B03C'): 0,
#  ('G01F', 'B60T'): 0,
#  ('F02C', 'B31B'): 0,
#  ('A24B', 'C08B'): 0,
#  ('H02N', 'C23F'): 0,
#  ('A01H', 'D04B'): 0,
#  ('A63G', 'H01R'): 0,
#  ('A47J', 'C01G'): 0.30341307554227914,
#  ('F27D', 'G05D'): 0,
#  ('B60K', 'F01B'): 0,
#  ('A24B', 'G06F'): 0,
#  ('C08L', 'B23B'): 0,
#  ('B25J', 'B04C'): 0,
#  ('D04D', 'G02C'): 0,
#  ('A43B', 'H02K'): 0,
#  ('C12Q', 'G01M'): 0,
#  ('F21Y', 'G03B'): 0,
#  ('H04R', 'F27B'): 0,
#  ('G01D', 'B22F'): 0,
#  ('A61M', 'A01C'): 0.36067376022224085,
#  ('C22C', 'A47K'): 0,
#  ('A24B', 'F17C'): 0,
#  ('G01V', 'F16L'): 0,
#  ('B07B', 'F24C'): 0,
#  ('B65G', 'B01L'): 0,
#  ('A41D', 'H04B'): 0.2422988705246811,
#  ('A43C', 'G01M'): 0,
#  ('F25D', 'B23Q'): 0,
#  ('A61N', 'B64D'): 0.2769378934088574,
#  ('C02F', 'G05D'): 0,
#  ('A01B', 'C11D'): 0,
#  ('B60K', 'G09B'): 0.8052364314362128,
#  ('A21B', 'A01N'): 0,
#  ('G01G', 'B03C'): 0,
#  ('A61C', 'A41D'): 0.552966337804487,
#  ('A24B', 'A01H'): 0,
#  ('A47F', 'A45C'): 0,
#  ('C05G', 'B07B'): 0,
#  ('C12R', 'C21D'): 0,
#  ('H01C', 'E02F'): 0,
#  ('B01D', 'B41J'): 0,
#  ('A24B', 'A21D'): 0,
#  ('G01K', 'G08G'): 0,
#  ('E02F', 'A61G'): 0,
#  ('F17D', 'C07D'): 0,
#  ('A61F', 'B31B'): 0,
#  ('G01N', 'A01J'): 0,
#  ('H05K', 'G06F'): 0.679936840348661,
#  ('F16J', 'B23K'): 0.7631033646040855,
#  ('B04B', 'B82Y'): 0,
#  ('C12Q', 'A21D'): 0,
#  ('F16C', 'G01B'): 0.7631033646040855,
#  ('B27B', 'A01G'): 0,
#  ('G01D', 'G03B'): 0.2422988705246811,
#  ('G01D', 'H04R'): 0.2422988705246811,
#  ('B65B', 'C23C'): 0.3459762562611936,
#  ('F28F', 'G02C'): 0,
#  ('A61G', 'C25D'): 0.28599966750267436,
#  ('F21W', 'G01V'): 0,
#  ('A01B', 'F25B'): 0,
#  ('A63G', 'G01L'): 0.28599966750267436,
#  ('A47D', 'B82Y'): 0,
#  ('A61K', 'F04B'): 0.26425736993644544,
#  ('B25J', 'A62B'): 0.5065562404611266,
#  ('B25J', 'B41J'): 0.8010958695746122,
#  ('C07K', 'A21D'): 0,
#  ('B67D', 'B60N'): 0,
#  ('A01C', 'F04B'): 0,
#  ('B25J', 'B29D'): 0.26425736993644544,
#  ('B21D', 'B33Y'): 0,
#  ('B60S', 'G05D'): 0,
#  ('A23D', 'A47G'): 0.30692767643013485,
#  ('B65G', 'A43D'): 0,
#  ('B65C', 'G01F'): 0,
#  ('D04H', 'A63H'): 0,
#  ('B22D', 'F24C'): 0,
#  ('F16D', 'B25C'): 0.2422988705246811,
#  ('B25B', 'B26F'): 0,
#  ('B60P', 'B03B'): 0,
#  ('A23C', 'A61L'): 0.3789231816899512,
#  ('G21F', 'A23J'): 0,
#  ('C11B', 'C08F'): 0,
#  ('F21Y', 'F17C'): 0,
#  ('H04R', 'B23Q'): 0,
#  ('A23C', 'G08B'): 0,
#  ('E03F', 'F41H'): 0,
#  ('B04C', 'C21C'): 0,
#  ('G01M', 'F21V'): 0,
#  ('G01G', 'B60T'): 0.31066746727980593,
#  ('E03F', 'G05B'): 0,
#  ('F17D', 'F02D'): 0,
#  ('A61D', 'B21J'): 0,
#  ('B25B', 'A23J'): 0,
#  ('A43C', 'H01L'): 0,
#  ('B22F', 'C12N'): 0,
#  ('B05C', 'F16L'): 0.5676704454787246,
#  ('F41H', 'F27B'): 0,
#  ('A61F', 'F21V'): 0,
#  ('B25C', 'G05D'): 0,
#  ('B03C', 'G01V'): 0,
#  ('B23D', 'F16D'): 0,
#  ('B22F', 'B24B'): 0,
#  ('B22F', 'B23C'): 0,
#  ('B21D', 'A61M'): 0.66408683576452,
#  ('F41H', 'F04B'): 0,
#  ('G07C', 'C08L'): 0,
#  ('A63B', 'B21J'): 0,
#  ('C09D', 'A47G'): 0,
#  ('F16J', 'A23P'): 0,
#  ('C12P', 'G07C'): 0,
#  ('H05B', 'A43B'): 0,
#  ('C01D', 'A47G'): 0,
#  ('B65G', 'A45F'): 0.30692767643013485,
#  ('A47C', 'A61K'): 0.3284587387530511,
#  ('A61D', 'F01N'): 0,
#  ('E03B', 'H05K'): 0,
#  ('C12P', 'F01N'): 0,
#  ('B60S', 'F04B'): 0,
#  ('A01D', 'F02D'): 0,
#  ('A23D', 'H04R'): 0,
#  ('F02C', 'B03C'): 0,
#  ('D06F', 'B43K'): 0,
#  ('H04R', 'F16L'): 0,
#  ('A23P', 'B65G'): 0,
#  ('G07C', 'F04D'): 0,
#  ('B01F', 'B33Y'): 0,
#  ('C08B', 'A23J'): 0.265872585674852,
#  ('C12N', 'H04L'): 0,
#  ('C12C', 'G01M'): 0,
#  ('C11D', 'B41J'): 0,
#  ('G01S', 'H04L'): 1.2178891869971127,
#  ('C11D', 'F21W'): 0,
#  ('B60K', 'C08L'): 0.5282985380273555,
#  ('A61J', 'F16N'): 0,
#  ('A01G', 'G09F'): 0,
#  ('B65C', 'F28F'): 0,
#  ('H04N', 'F01D'): 0,
#  ('B65B', 'B01L'): 0.4170323914242463,
#  ('G09G', 'H01B'): 0,
#  ('F24C', 'A47K'): 0,
#  ('A47F', 'B33Y'): 0,
#  ('B23Q', 'F01D'): 0,
#  ('B03C', 'B22C'): 0,
#  ('A47F', 'A47D'): 0,
#  ('G01L', 'C23C'): 0,
#  ('B64D', 'C08G'): 0,
#  ('H05K', 'C08G'): 0,
#  ('G01D', 'F21V'): 0,
#  ('B01F', 'G01G'): 0,
#  ('A63G', 'B26D'): 0,
#  ('B01D', 'A42B'): 0,
#  ('H04R', 'G08B'): 0.2422988705246811,
#  ('A41F', 'A47D'): 0,
#  ('G06Q', 'B65G'): 0.30692767643013485,
#  ('A01B', 'B05D'): 0,
#  ('B22D', 'A01F'): 0,
#  ('B25B', 'F16K'): 0,
#  ('B09B', 'F26B'): 0,
#  ('A01N', 'B23K'): 0.28599966750267436,
#  ('C12P', 'B32B'): 0,
#  ('H01L', 'F41H'): 0,
#  ('B64F', 'H01M'): 0,
#  ('B22D', 'B23B'): 0.5138983423697507,
#  ('H02K', 'F16K'): 0,
#  ('B65C', 'H04W'): 0,
#  ('G06Q', 'C21C'): 0,
#  ('B41J', 'C04B'): 0,
#  ('B23D', 'A61G'): 0,
#  ('A62D', 'B23K'): 0.28599966750267436,
#  ('A47J', 'B65H'): 0,
#  ('A23C', 'G03B'): 0,
#  ('A24B', 'A61J'): 0,
#  ('A47F', 'F02D'): 0,
#  ('H01R', 'F04D'): 0.30692767643013485,
#  ('H02K', 'F24C'): 0,
#  ('F17D', 'H01M'): 0,
#  ('A61H', 'A01K'): 0,
#  ('B60K', 'B27B'): 0.2422988705246811,
#  ('B29C', 'G01F'): 0.8595123643258877,
#  ('F21V', 'G07F'): 0,
#  ('H01F', 'A61G'): 0,
#  ('H01F', 'H02J'): 0.36067376022224085,
#  ('F16B', 'A21D'): 0,
#  ('E21B', 'E03B'): 0,
#  ('B01J', 'B31B'): 0,
#  ('A61N', 'B25C'): 0.2422988705246811,
#  ('B27B', 'F27B'): 0,
#  ('G01S', 'C12C'): 0,
#  ('H02N', 'B03D'): 0,
#  ('G01F', 'B06B'): 0,
#  ('B01F', 'B21D'): 0,
#  ('A24F', 'B60R'): 0,
#  ('A47J', 'C08G'): 0,
#  ('B60S', 'F16K'): 0,
#  ('E01H', 'A47G'): 0.318928988903801,
#  ('C12Q', 'F27D'): 0,
#  ('G06K', 'G08G'): 0.2769378934088574,
#  ('B21K', 'G08C'): 0,
#  ('A43B', 'B60S'): 0,
#  ('F24J', 'B29D'): 0,
#  ('C23F', 'F16M'): 0,
#  ('B23D', 'A63C'): 0,
#  ('E21B', 'A23J'): 0,
#  ('C01B', 'F41H'): 0,
#  ('D04H', 'A01D'): 0,
#  ('G21F', 'G21G'): 0,
#  ('C21C', 'C08G'): 0,
#  ('B67C', 'F02D'): 0,
#  ('G01S', 'B27B'): 0.2422988705246811,
#  ('G02B', 'B07B'): 0,
#  ('B64D', 'F04D'): 0,
#  ('B01L', 'B25H'): 0,
#  ('B26D', 'A23G'): 0,
#  ('A61M', 'D04B'): 0.2969742043733701,
#  ('B65C', 'H05H'): 0,
#  ('C22F', 'B01L'): 0,
#  ('F21Y', 'A24B'): 0,
#  ('B26B', 'A23J'): 0,
#  ('C07F', 'E02F'): 0,
#  ('E21B', 'F03C'): 0,
#  ('C23C', 'A62C'): 0.3459762562611936,
#  ('B25J', 'A01K'): 0,
#  ('G09F', 'H04W'): 0.31066746727980593,
#  ('B60S', 'G07F'): 0,
#  ('C22F', 'B23C'): 0,
#  ('A47D', 'G05B'): 0.31066746727980593,
#  ('G01F', 'A01F'): 0,
#  ('E03B', 'G01R'): 0,
#  ('B26B', 'G02F'): 0,
#  ('C23C', 'F24F'): 0,
#  ('C25B', 'C08B'): 0,
#  ('H02N', 'A23G'): 0,
#  ('A63G', 'A47J'): 0,
#  ('C22C', 'F04D'): 0,
#  ('B26D', 'B02C'): 0,
#  ('B65B', 'A23P'): 0,
#  ('A61H', 'A01N'): 0,
#  ('C12P', 'G08B'): 0,
#  ('H05B', 'E01H'): 0,
#  ('A61F', 'G01G'): 0.31066746727980593,
#  ('C08G', 'F16N'): 0,
#  ('G01K', 'B07B'): 0.7213475204444817,
#  ('G09F', 'C08L'): 0.3284587387530511,
#  ('A61H', 'A47G'): 1.7670555594913484,
#  ('C07F', 'F16L'): 0,
#  ('A62B', 'C25D'): 0,
#  ('A45D', 'B21D'): 0,
#  ('F28D', 'B60N'): 0,
#  ('A23C', 'D04H'): 0,
#  ('F16H', 'C25D'): 0,
#  ('B05D', 'F21V'): 0,
#  ('A23D', 'A47B'): 0.30692767643013485,
#  ('A63B', 'B01L'): 0,
#  ('C05G', 'A44C'): 0,
#  ('G09G', 'A44C'): 0,
#  ('B23Q', 'F41H'): 0,
#  ('A45C', 'G02F'): 0,
#  ('C09D', 'A01C'): 0,
#  ('B31B', 'B60T'): 0,
#  ('C07D', 'E01H'): 0,
#  ('C22C', 'F27B'): 0.43429448190325176,
#  ('B22D', 'C25B'): 0,
#  ('A24B', 'G05B'): 0,
#  ('C21C', 'A47G'): 0,
#  ('B60B', 'A47B'): 0,
#  ('B31B', 'B64F'): 0,
#  ('C23F', 'A63J'): 0,
#  ('F24J', 'C08K'): 0,
#  ('B25D', 'F26B'): 0.43429448190325176,
#  ('G01B', 'A47D'): 0,
#  ('A61D', 'H04L'): 0.5658143236733536,
#  ('C23C', 'G06F'): 0,
#  ('A23D', 'G05B'): 0,
#  ('B08B', 'H01M'): 0,
#  ('B26D', 'B04C'): 0,
#  ('G05B', 'F16H'): 0,
#  ('F21Y', 'B27B'): 0,
#  ('E04B', 'C04B'): 0,
#  ('A22C', 'C09J'): 0,
#  ('A01D', 'C01C'): 0,
#  ('B21D', 'G01V'): 0,
#  ('A47F', 'C09J'): 0,
#  ('B66F', 'C01C'): 0,
#  ('H05K', 'A63J'): 0,
#  ('C12C', 'F01D'): 0,
#  ('H01F', 'A47L'): 0.9282626109897467,
#  ('B25J', 'H01C'): 0.26425736993644544,
#  ('B65H', 'B60R'): 0,
#  ('C07K', 'B21C'): 0,
#  ('B26D', 'C08B'): 0,
#  ('B60N', 'F16H'): 0.26425736993644544,
#  ('A43C', 'C02F'): 0,
#  ('B29L', 'A47F'): 0.30692767643013485,
#  ('B41J', 'F04B'): 0,
#  ('G09G', 'G06M'): 0,
#  ('B24B', 'G06M'): 0,
#  ('A62C', 'B22C'): 0,
#  ('B60K', 'E21B'): 0,
#  ('B64F', 'E01H'): 0,
#  ('E06B', 'C01C'): 0.2969742043733701,
#  ('G08G', 'A47B'): 0.45511961331341866,
#  ('F01M', 'B62D'): 0,
#  ('A61C', 'B60P'): 0,
#  ('C07F', 'B25D'): 0,
#  ('G01G', 'A23K'): 0,
#  ('F17C', 'A44C'): 0,
#  ('H05B', 'A61K'): 0.9456722325542577,
#  ('F21Y', 'B64D'): 0,
#  ('E03F', 'G02C'): 0,
#  ('F21Y', 'C07D'): 0,
#  ('B29K', 'B60N'): 0.2422988705246811,
#  ('C11B', 'G01G'): 0,
#  ('G08B', 'B62D'): 0,
#  ('B05D', 'A47B'): 0,
#  ('F21Y', 'B07B'): 0,
#  ('B65C', 'A01H'): 0,
#  ('A23K', 'B23C'): 0,
#  ('G09F', 'G06M'): 0,
#  ('B29K', 'F01D'): 0,
#  ('F17D', 'E01H'): 0,
#  ('A23K', 'F21V'): 0,
#  ('G09B', 'C03C'): 0.265872585674852,
#  ('F16M', 'F01D'): 0,
#  ('C11B', 'F24F'): 0,
#  ('G06Q', 'B23B'): 0,
#  ('C25B', 'H04Q'): 0,
#  ('G01D', 'C10G'): 0,
#  ('F01M', 'C07D'): 0,
#  ('E21B', 'A01F'): 0,
#  ('H05B', 'A01C'): 0,
#  ('G02B', 'B02C'): 0.31066746727980593,
#  ('E02B', 'F21W'): 0,
#  ('G06Q', 'C12M'): 1.3489133215839284,
#  ('B21J', 'A47G'): 0,
#  ('B04B', 'A61P'): 0,
#  ('B64F', 'C01C'): 0,
#  ('B03D', 'H01M'): 0,
#  ('H01F', 'B26F'): 0,
#  ('H01F', 'C08J'): 0,
#  ('B32B', 'F03C'): 0,
#  ('F16M', 'H04L'): 0.552966337804487,
#  ('B21J', 'B22C'): 0,
#  ('B04C', 'C07F'): 0,
#  ('H01L', 'F24J'): 0,
#  ('B03C', 'F03C'): 0,
#  ('A62D', 'H05H'): 0.28599966750267436,
#  ('H01J', 'B25D'): 0,
#  ('B22F', 'E02F'): 0,
#  ('A23C', 'B24B'): 0,
#  ('G05B', 'A45F'): 0,
#  ('B26B', 'C08G'): 0,
#  ('B21J', 'F16L'): 0,
#  ('C12M', 'C01C'): 0,
#  ('A44C', 'A42B'): 0.3898712452512801,
#  ('A01N', 'F25B'): 0,
#  ('G01L', 'B43M'): 0,
#  ('A41D', 'F04B'): 0,
#  ('F01M', 'G01M'): 0,
#  ('A63C', 'B23Q'): 0,
#  ('E02F', 'C01C'): 0,
#  ('A24B', 'A47B'): 0,
#  ('B43M', 'B65H'): 0,
#  ('G21F', 'F17C'): 0.2969742043733701,
#  ('A63H', 'F16K'): 0,
#  ('A63C', 'H04Q'): 0.28599966750267436,
#  ('A21B', 'G06M'): 0,
#  ('A21C', 'G05B'): 0,
#  ('C25B', 'A01M'): 0,
#  ('B01F', 'A61K'): 1.0290696222286306,
#  ('F16C', 'A47G'): 0,
#  ('E03F', 'A47F'): 0,
#  ('A61Q', 'B25H'): 0,
#  ('A23P', 'B21K'): 0,
#  ('F01M', 'B05C'): 0,
#  ('G01G', 'B21C'): 0,
#  ('F16D', 'H04W'): 0.2422988705246811,
#  ('A61P', 'F03C'): 0,
#  ('B67C', 'A23K'): 0,
#  ('F01B', 'B43K'): 0,
#  ('H02N', 'B67C'): 0,
#  ('C12Q', 'A23J'): 0.7797709280446028,
#  ('B23Q', 'F16M'): 0,
#  ('H01L', 'C21D'): 0,
#  ('B29C', 'B21C'): 0,
#  ('A45D', 'A21B'): 0,
#  ('C02F', 'B64D'): 0,
#  ('B29L', 'H04R'): 0.2422988705246811,
#  ('A63C', 'B64F'): 0,
#  ('H01B', 'B23B'): 0,
#  ('A23C', 'C11D'): 0,
#  ('G07F', 'C25D'): 0,
#  ('A63G', 'C07H'): 0,
#  ('A61J', 'B60N'): 0.5065562404611266,
#  ('F17C', 'C12M'): 0,
#  ('B01D', 'G01V'): 0.2422988705246811,
#  ('C01B', 'B05D'): 0.2769378934088574,
#  ('B22D', 'A47L'): 0.30341307554227914,
#  ('C21C', 'B41J'): 0,
#  ('B26D', 'B67C'): 0,
#  ('C11B', 'E21B'): 0,
#  ('B60L', 'F28F'): 0,
#  ('A23P', 'A63H'): 0,
#  ('F16J', 'B29C'): 0,
#  ('B08B', 'A62D'): 0,
#  ('F16C', 'H05B'): 0.7631033646040855,
#  ('A01B', 'C10G'): 0,
#  ('B60S', 'C07C'): 0,
#  ('F16C', 'F16M'): 0,
#  ('B23D', 'C22F'): 0,
#  ('A61H', 'H02K'): 0,
#  ('B43M', 'A61D'): 0.2835784920513334,
#  ('F25D', 'F26B'): 0.3284587387530511,
#  ('G09G', 'E06B'): 0,
#  ('A63G', 'A23L'): 0,
#  ('A61J', 'C12R'): 0.265872585674852,
#  ('F01B', 'B23B'): 0.40242960438184466,
#  ('G01F', 'B23P'): 0,
#  ('H02J', 'H04W'): 1.2871618441178354,
#  ('A01M', 'B03D'): 0,
#  ('A61P', 'F01N'): 0,
#  ('A22C', 'B43M'): 0,
#  ('A47L', 'B26F'): 0,
#  ('A63C', 'B43K'): 0,
#  ('H02K', 'H01M'): 0,
#  ('G10L', 'C25B'): 0,
#  ('B09B', 'F27D'): 0,
#  ('B01F', 'A61B'): 1.053567007340341,
#  ('A45C', 'A63B'): 0.2769378934088574,
#  ('B21K', 'B25D'): 0,
#  ('A23J', 'A42B'): 0,
#  ('F16B', 'B82Y'): 0,
#  ('B65D', 'H04W'): 0.5282985380273555,
#  ('E03B', 'A61K'): 0,
#  ('C07H', 'A61N'): 0.265872585674852,
#  ('C23C', 'C08B'): 0,
#  ('C01B', 'F01B'): 0,
#  ('G10L', 'B22F'): 0,
#  ('E06B', 'A61Q'): 0,
#  ('C01D', 'F24C'): 0,
#  ('A43C', 'A63J'): 0,
#  ('C03C', 'B41J'): 0,
#  ('B25J', 'C09D'): 0,
#  ('B04B', 'E01H'): 0,
#  ('B08B', 'B29D'): 0.5676704454787246,
#  ('D06F', 'A01N'): 0,
#  ('B32B', 'A21C'): 0.30692767643013485,
#  ('B22F', 'F16H'): 0,
#  ('A47D', 'B21C'): 0,
#  ('A43C', 'B23K'): 0,
#  ('B60R', 'A47B'): 0,
#  ('B31B', 'B06B'): 0,
#  ('G01R', 'B31B'): 0,
#  ('A23P', 'C07D'): 0,
#  ('B23P', 'F27B'): 0,
#  ('F16J', 'B60K'): 0,
#  ('E03F', 'A61M'): 0,
#  ('G21K', 'C22F'): 0,
#  ('B04C', 'B23Q'): 0,
#  ('C12Q', 'C25D'): 0,
#  ('B02C', 'C12C'): 0,
#  ('F16D', 'A01H'): 0,
#  ('A22C', 'C08B'): 0,
#  ('B01J', 'B26F'): 0,
#  ('A01B', 'C12M'): 0,
#  ('C11D', 'G03B'): 0.45511961331341866,
#  ('A24F', 'A21C'): 0,
#  ('E06B', 'B60S'): 0,
#  ('A63G', 'H02N'): 0,
#  ('B60K', 'A62C'): 0,
#  ('A61M', 'G01R'): 0.552966337804487,
#  ('B26D', 'G01G'): 0,
#  ('G02B', 'A61Q'): 0.8872075202344638,
#  ('B21D', 'B60P'): 0,
#  ('A61P', 'C01C'): 0,
#  ('H01B', 'B25B'): 0,
#  ('A23P', 'B04C'): 0,
#  ('B01D', 'C12R'): 0,
#  ('B21D', 'C08G'): 0,
#  ('C23C', 'G01M'): 0,
#  ('B02C', 'E02F'): 0.7213475204444817,
#  ('B31B', 'B23C'): 0,
#  ('C08L', 'A41D'): 0.2422988705246811,
#  ('C22F', 'F04B'): 0,
#  ('B67D', 'B29D'): 0,
#  ('G01R', 'F16M'): 0.2422988705246811,
#  ('B26D', 'A23L'): 0.30692767643013485,
#  ('G06F', 'B62D'): 0,
#  ('A61B', 'B21C'): 0,
#  ('H01R', 'F01B'): 0,
#  ('H01R', 'B67C'): 0,
#  ('G06Q', 'A01C'): 0,
#  ('B09B', 'B03C'): 0,
#  ('C07H', 'B41J'): 0,
#  ('G10L', 'A01M'): 0,
#  ('G01S', 'F01B'): 0,
#  ('G01S', 'B32B'): 0.5282985380273555,
#  ('G10L', 'B01D'): 0,
#  ('A01F', 'B23C'): 0,
#  ('G07C', 'B01L'): 0,
#  ('B60P', 'A61G'): 0,
#  ('B02C', 'F16L'): 0,
#  ('F16D', 'A42B'): 0,
#  ('A21C', 'A45D'): 0,
#  ('B05B', 'H05H'): 0,
#  ('C25B', 'B65H'): 0,
#  ('E03F', 'F24J'): 0,
#  ('A23G', 'C21C'): 0,
#  ('B02C', 'A63J'): 0,
#  ('F16C', 'H01B'): 0,
#  ('A21B', 'A61P'): 0,
#  ('B65B', 'F01N'): 0,
#  ('C11B', 'B04B'): 0,
#  ('B21F', 'B60R'): 0,
#  ('A62C', 'C03C'): 0,
#  ('G01S', 'A47G'): 0.2422988705246811,
#  ('C07H', 'F16K'): 0,
#  ('C01D', 'F02D'): 0.2969742043733701,
#  ('G07C', 'G06M'): 0,
#  ('C23C', 'E02B'): 0,
#  ('B01D', 'G09G'): 0.2422988705246811,
#  ('B67D', 'F03C'): 0,
#  ('C23C', 'A23K'): 0,
#  ('A47L', 'B60N'): 0.8172237077409326,
#  ('G01F', 'H04W'): 0.9367808314422561,
#  ('A23P', 'E02B'): 0,
#  ('C07H', 'C07F'): 0.265872585674852,
#  ('H02K', 'G05D'): 0,
#  ('B05D', 'C12R'): 0,
#  ('B60K', 'B22C'): 0,
#  ('B21D', 'C07D'): 0,
#  ('H02N', 'A61J'): 0,
#  ('A47J', 'F17C'): 0.2969742043733701,
#  ('A47K', 'H04W'): 0,
#  ('H05B', 'A44C'): 0,
#  ('B21J', 'G01V'): 0,
#  ('F28D', 'E02B'): 0,
#  ('A45C', 'B06B'): 0,
#  ('F02C', 'H05K'): 0,
#  ('H05B', 'G08G'): 0,
#  ('A47L', 'B66F'): 0.40242960438184466,
#  ('B32B', 'F26B'): 0,
#  ('B05C', 'A01K'): 0,
#  ('B04B', 'C04B'): 0,
#  ('B25B', 'B60B'): 0,
#  ('F25D', 'B03B'): 0,
#  ('G21K', 'G01V'): 0.2422988705246811,
#  ('A47F', 'H01C'): 0,
#  ('A01F', 'F01N'): 0,
#  ('G01R', 'B65H'): 0,
#  ('G07C', 'B02C'): 0,
#  ('G01K', 'C10G'): 0,
#  ('D04B', 'C04B'): 0,
#  ('A01B', 'G05B'): 0,
#  ('A61N', 'C07C'): 0.635141958743707,
#  ('A21D', 'D04D'): 0,
#  ('B33Y', 'F01D'): 0,
#  ('G09B', 'B23K'): 0.3789231816899512,
#  ('A43D', 'A01K'): 0,
#  ('F01M', 'A23G'): 0,
#  ('A23D', 'H01B'): 0,
#  ('H02J', 'B31B'): 0.2835784920513334,
#  ('C12P', 'F04B'): 0,
#  ('H05K', 'C25D'): 0,
#  ('A23L', 'F24F'): 0.4170323914242463,
#  ('A61C', 'A47B'): 0,
#  ...}

# %% [markdown]
# ### 성능 검증

# %%
compare_dic={}

# %%
for row in data_second:
    if(tmp in result_dic ): ##예측 결과와 데이터2링크 겹치는 거 비교
        if(result_dic[tmp]!=0):
            compare_dic[tmp]=1
        else:
            compare_dic[tmp]=0
    else:
        compare_dic[tmp]=0

# %%
compare_dic
# Out:
# {('A61N', 'A01K'): 1,
#  ('A61N', 'A01N'): 1,
#  ('B01L', 'A61B'): 1,
#  ('B22F', 'B21D'): 1,
#  ('B23P', 'B23C'): 1,
#  ('B23P', 'B23K'): 1,
#  ('B23Q', 'A47B'): 0,
#  ('B23Q', 'B23C'): 1,
#  ('B23Q', 'B23K'): 1,
#  ('B25B', 'B23B'): 0,
#  ('B25B', 'B23Q'): 0,
#  ('B25H', 'A47B'): 0,
#  ('B25J', 'A62B'): 1,
#  ('B26B', 'A61B'): 0,
#  ('B26D', 'B25J'): 0,
#  ('B27B', 'A01G'): 0,
#  ('B29C', 'B05D'): 1,
#  ('B29C', 'B23K'): 1,
#  ('B29C', 'B23P'): 0,
#  ('B29K', 'B05D'): 1,
#  ('B29K', 'B23P'): 0,
#  ('B29K', 'B29B'): 0,
#  ('B29K', 'B29D'): 1,
#  ('B29L', 'A43D'): 0,
#  ('B29L', 'A61J'): 1,
#  ('B29L', 'B05D'): 1,
#  ('B29L', 'B23K'): 1,
#  ('B29L', 'B23P'): 0,
#  ('B32B', 'A61J'): 1,
#  ('B32B', 'A61L'): 1,
#  ('B32B', 'B05D'): 1,
#  ('B32B', 'B22F'): 1,
#  ('B32B', 'B23K'): 1,
#  ('B32B', 'B26F'): 0,
#  ('B32B', 'B29K'): 1,
#  ('B60K', 'A01D'): 0,
#  ('B60N', 'A47B'): 0,
#  ('B60N', 'B29D'): 1,
#  ('B60R', 'A47B'): 0,
#  ('B60S', 'B60P'): 0,
#  ('B62D', 'B25H'): 0,
#  ('B62D', 'B60R'): 0,
#  ('B64D', 'B33Y'): 1,
#  ('B64D', 'B60N'): 1,
#  ('B64D', 'B60R'): 1,
#  ('B64F', 'B23B'): 0,
#  ('B64F', 'B33Y'): 1,
#  ('B65B', 'A61B'): 1,
#  ('B65B', 'A61J'): 1,
#  ('B65B', 'A61L'): 1,
#  ('B65B', 'A61M'): 1,
#  ('B65B', 'B01J'): 1,
#  ('B65B', 'B01L'): 1,
#  ('B65B', 'B29C'): 1,
#  ('B65B', 'B29D'): 0,
#  ('B65B', 'B29L'): 1,
#  ('B65B', 'B31B'): 1,
#  ('B65B', 'B41J'): 1,
#  ('B65C', 'B32B'): 1,
#  ('B65C', 'B41J'): 0,
#  ('B65C', 'B60B'): 0,
#  ('B65D', 'A45F'): 1,
#  ('B65D', 'B01L'): 1,
#  ('B65D', 'B05B'): 1,
#  ('B65D', 'B23P'): 0,
#  ('B65D', 'B25H'): 0,
#  ('B65D', 'B29C'): 1,
#  ('B65D', 'B29K'): 1,
#  ('B65D', 'B60R'): 0,
#  ('B65D', 'B64D'): 1,
#  ('B65G', 'B05D'): 0,
#  ('B67D', 'A47K'): 1,
#  ('B67D', 'B05B'): 0,
#  ('C01B', 'A01N'): 1,
#  ('C01B', 'B01F'): 0,
#  ('C01G', 'B05D'): 1,
#  ('C01G', 'B82Y'): 1,
#  ('C02F', 'B01F'): 0,
#  ('C02F', 'B04C'): 0,
#  ('C02F', 'B05D'): 1,
#  ('C02F', 'C01D'): 1,
#  ('C03C', 'A61L'): 1,
#  ('C07D', 'A61Q'): 1,
#  ('C07D', 'B01J'): 1,
#  ('C07D', 'C04B'): 0,
#  ('C07F', 'C07C'): 1,
#  ('C07H', 'A23G'): 1,
#  ('C07H', 'C07D'): 1,
#  ('C07K', 'A01H'): 1,
#  ('C07K', 'A01N'): 1,
#  ('C07K', 'A23G'): 0,
#  ('C07K', 'A61N'): 1,
#  ('C07K', 'A61P'): 1,
#  ('C07K', 'C07C'): 1,
#  ('C07K', 'C07D'): 1,
#  ('C07K', 'C07F'): 1,
#  ('C08F', 'C07C'): 1,
#  ('C08G', 'A61L'): 1,
#  ('C08G', 'C04B'): 0,
#  ('C08G', 'C07C'): 1,
#  ('C08G', 'C08F'): 1,
#  ('C08J', 'B33Y'): 1,
#  ('C08J', 'C04B'): 0,
#  ('C08K', 'C04B'): 0,
#  ('C08K', 'C07C'): 1,
#  ('C08K', 'C08F'): 1,
#  ('C08L', 'B05D'): 1,
#  ('C08L', 'B33Y'): 1,
#  ('C08L', 'C04B'): 0,
#  ('C08L', 'C07C'): 1,
#  ('C09D', 'A41D'): 0,
#  ('C09D', 'B05D'): 0,
#  ('C09D', 'B41J'): 0,
#  ('C09D', 'C03C'): 1,
#  ('C09D', 'C04B'): 0,
#  ('C09D', 'C08F'): 1,
#  ('C09D', 'C08G'): 1,
#  ('C09D', 'C08J'): 1,
#  ('C09D', 'C08K'): 1,
#  ('C09J', 'B23K'): 0,
#  ('C09J', 'C04B'): 0,
#  ('C09J', 'C08F'): 1,
#  ('C10G', 'B01D'): 1,
#  ('C10G', 'B01F'): 0,
#  ('C10G', 'C01B'): 1,
#  ('C10G', 'C07C'): 1,
#  ('C11B', 'A61K'): 1,
#  ('C11B', 'A61L'): 1,
#  ('C11B', 'A61Q'): 0,
#  ('C11B', 'C07C'): 0,
#  ('C11B', 'C07D'): 1,
#  ('C11B', 'C08J'): 0,
#  ('C11D', 'A47L'): 0,
#  ('C11D', 'C07C'): 1,
#  ('C11D', 'C07D'): 1,
#  ('C11D', 'C08F'): 1,
#  ('C11D', 'C11B'): 0,
#  ('C12N', 'A23G'): 1,
#  ('C12N', 'A61B'): 1,
#  ('C12N', 'A61N'): 1,
#  ('C12N', 'B01J'): 1,
#  ('C12N', 'C02F'): 1,
#  ('C12N', 'C07C'): 1,
#  ('C12N', 'C07H'): 1,
#  ('C12N', 'C08B'): 1,
#  ('C12N', 'C08F'): 1,
#  ('C12N', 'C08G'): 1,
#  ('C12N', 'C12M'): 1,
#  ('C12P', 'A01N'): 1,
#  ('C12P', 'A23G'): 1,
#  ('C12P', 'A61L'): 1,
#  ('C12P', 'B01F'): 1,
#  ('C12P', 'B01J'): 1,
#  ('C12P', 'C01B'): 1,
#  ('C12P', 'C07C'): 1,
#  ('C12P', 'C07H'): 1,
#  ('C12P', 'C07K'): 1,
#  ('C12P', 'C08F'): 1,
#  ('C12P', 'C08G'): 1,
#  ('C12P', 'C12M'): 1,
#  ('C12Q', 'A01H'): 0,
#  ('C12Q', 'B01F'): 0,
#  ('C12Q', 'B05D'): 1,
#  ('C12Q', 'B82Y'): 1,
#  ('C12Q', 'C07D'): 1,
#  ('C12Q', 'C12M'): 1,
#  ('C22C', 'B23K'): 1,
#  ('C22C', 'B23P'): 1,
#  ('C22C', 'B33Y'): 1,
#  ('C22C', 'C04B'): 0,
#  ('C23C', 'B21C'): 1,
#  ('C23C', 'B21D'): 1,
#  ('C23C', 'B32B'): 0,
#  ('C23C', 'C01G'): 0,
#  ('C23C', 'C04B'): 1,
#  ('C23C', 'C08J'): 1,
#  ('C23C', 'C09D'): 0,
#  ('C23C', 'C22C'): 1,
#  ('D04H', 'B29C'): 1,
#  ('D04H', 'B29D'): 0,
#  ('D04H', 'B29K'): 1,
#  ('D06F', 'A47K'): 1,
#  ('D06F', 'B67D'): 1,
#  ('D06F', 'C11D'): 0,
#  ('E03F', 'C02F'): 0,
#  ('E03F', 'E02B'): 0,
#  ('E04B', 'B41J'): 0,
#  ('E04B', 'C04B'): 0,
#  ('E04B', 'C08L'): 1,
#  ('E04B', 'C09J'): 1,
#  ('E21B', 'B01F'): 0,
#  ('E21B', 'B23P'): 0,
#  ('E21B', 'B25B'): 0,
#  ('E21B', 'C04B'): 0,
#  ('E21B', 'C08G'): 0,
#  ('E21B', 'E02F'): 0,
#  ('F01D', 'C04B'): 0,
#  ('F02C', 'B64D'): 0,
#  ('F04B', 'B60T'): 0,
#  ('F04B', 'C12M'): 1,
#  ('F04D', 'B23C'): 0,
#  ('F16B', 'B25B'): 1,
#  ('F16B', 'B60N'): 0,
#  ('F16C', 'A01G'): 0,
#  ('F16C', 'B27B'): 0,
#  ('F16C', 'B41J'): 0,
#  ('F16C', 'B65H'): 0,
#  ('F16D', 'B25J'): 1,
#  ('F16D', 'B60B'): 0,
#  ('F16H', 'F01N'): 0,
#  ('F16K', 'F01D'): 0,
#  ('F17C', 'C08J'): 0,
#  ('F17C', 'C08L'): 0,
#  ('F21V', 'B60R'): 0,
#  ('F21V', 'B62D'): 0,
#  ('F21V', 'C08F'): 0,
#  ('F21V', 'C09J'): 0,
#  ('F21Y', 'C08F'): 0,
#  ('F21Y', 'C08L'): 0,
#  ('F24J', 'C01D'): 0,
#  ('F25D', 'B29C'): 1,
#  ('F28D', 'B23K'): 0,
#  ('F28D', 'B33Y'): 0,
#  ('F28D', 'B64D'): 0,
#  ('F28D', 'B64F'): 0,
#  ('F28F', 'B23K'): 0,
#  ('F41H', 'B82Y'): 0,
#  ('F41H', 'C08J'): 0,
#  ('F41H', 'C08K'): 0,
#  ('G01C', 'B60K'): 0,
#  ('G01C', 'B60L'): 0,
#  ('G01C', 'B64D'): 0,
#  ('G01D', 'B60K'): 1,
#  ('G01F', 'B33Y'): 1,
#  ('G01F', 'B64D'): 0,
#  ('G01F', 'B64F'): 0,
#  ('G01L', 'G01B'): 1,
#  ('G01M', 'B23C'): 0,
#  ('G01M', 'F04D'): 0,
#  ('G01N', 'A01K'): 1,
#  ('G01N', 'A61L'): 1,
#  ('G01N', 'B05D'): 1,
#  ('G01N', 'B25J'): 1,
#  ('G01N', 'B65D'): 1,
#  ('G01N', 'B82Y'): 1,
#  ('G01N', 'C07C'): 1,
#  ('G01N', 'C07H'): 1,
#  ('G01N', 'G01B'): 1,
#  ('G01R', 'B60L'): 0,
#  ('G01R', 'B60R'): 0,
#  ('G01S', 'B60L'): 1,
#  ('G01S', 'B60R'): 0,
#  ('G02B', 'B32B'): 1,
#  ('G02B', 'B60R'): 1,
#  ('G02B', 'B64D'): 1,
#  ('G02B', 'B64F'): 0,
#  ('G02B', 'C07C'): 1,
#  ('G02B', 'C08G'): 1,
#  ('G02B', 'C08J'): 1,
#  ('G02B', 'C09J'): 0,
#  ('G02B', 'C12Q'): 1,
#  ('G02B', 'F21V'): 0,
#  ('G02F', 'C07C'): 0,
#  ('G02F', 'C08F'): 0,
#  ('G02F', 'F21V'): 0,
#  ('G05B', 'B23C'): 0,
#  ('G05B', 'B23K'): 1,
#  ('G05B', 'B33Y'): 1,
#  ('G05B', 'B60R'): 0,
#  ('G05D', 'B60R'): 0,
#  ('G05D', 'B62D'): 0,
#  ('G05D', 'E02F'): 0,
#  ('G06F', 'B60R'): 0,
#  ('G06F', 'B62D'): 0,
#  ('G06F', 'C08F'): 0,
#  ('G06F', 'C08G'): 1,
#  ('G06F', 'C09J'): 1,
#  ('G06K', 'B60R'): 0,
#  ('G06K', 'E02F'): 0,
#  ('G06Q', 'B64D'): 1,
#  ('G06Q', 'B65D'): 1,
#  ('G06Q', 'G05D'): 1,
#  ('G06T', 'B23C'): 0,
#  ('G06T', 'B33Y'): 1,
#  ('G06T', 'B60R'): 0,
#  ('G06T', 'G05B'): 1,
#  ('G08B', 'B60L'): 1,
#  ('G08B', 'B60R'): 0,
#  ('G09B', 'B60N'): 1,
#  ('G09F', 'B60B'): 0,
#  ('G09F', 'B60R'): 0,
#  ('G09G', 'C08F'): 0,
#  ('G09G', 'C08G'): 1,
#  ('G09G', 'C09J'): 0,
#  ('H01B', 'B60R'): 0,
#  ('H01F', 'B05D'): 1,
#  ('H01F', 'B60L'): 0,
#  ('H01F', 'B82Y'): 0,
#  ('H01L', 'B82Y'): 1,
#  ('H01L', 'C07F'): 0,
#  ('H01L', 'C08F'): 1,
#  ('H01L', 'C08G'): 0,
#  ('H01L', 'C08J'): 1,
#  ('H01L', 'C08L'): 1,
#  ('H01L', 'C09D'): 0,
#  ('H01L', 'F21V'): 0,
#  ('H01L', 'G02F'): 0,
#  ('H01M', 'B60R'): 0,
#  ('H01M', 'C08K'): 1,
#  ('H01R', 'B60L'): 0,
#  ('H02J', 'A47B'): 1,
#  ('H02J', 'B23Q'): 0,
#  ('H02J', 'B25H'): 0,
#  ('H02J', 'B60L'): 0,
#  ('H02J', 'B60R'): 0,
#  ('H02J', 'B64D'): 1,
#  ('H02J', 'G01R'): 1,
#  ('H02J', 'G01V'): 1,
#  ('H02J', 'H01M'): 1,
#  ('H02K', 'B60L'): 0,
#  ('H02K', 'C08K'): 0,
#  ('H02K', 'F16H'): 0,
#  ('H02N', 'B41J'): 0,
#  ('H04B', 'B60R'): 0,
#  ('H04B', 'G05B'): 1,
#  ('H04N', 'B60R'): 0,
#  ('H04R', 'H01L'): 0,
#  ('H05B', 'B29C'): 1,
#  ('H05B', 'B29D'): 1,
#  ('H05B', 'B41J'): 1,
#  ('H05B', 'B60S'): 1,
#  ('H05B', 'B64D'): 0,
#  ('H05B', 'F26B'): 1,
#  ('H05K', 'B23K'): 1,
#  ('H05K', 'B60L'): 0,
#  ('H05K', 'B60R'): 0,
#  ('H05K', 'C08G'): 0,
#  ('H05K', 'C08J'): 0,
#  ('H05K', 'C08K'): 1,
#  ('H05K', 'C08L'): 0,
#  ('H05K', 'C09D'): 0,
#  ('H05K', 'F16H'): 0}
